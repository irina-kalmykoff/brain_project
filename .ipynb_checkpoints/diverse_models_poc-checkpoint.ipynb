# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Audio, display
from pynwb import NWBHDF5IO
from collections import Counter
import glob
from datetime import datetime

from sklearn.metrics import accuracy_score

import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, IntSlider, FloatSlider, Dropdown, Checkbox

from brain_audio_decoder import BrainAudioDecoder
from custom_decoder import CustomBrainAudioDecoder
from brain_audio_decoder_viz import BrainAudioDecoderViz
from acoustic_change_detector import AcousticChangeDetector
from phoneme_validator import PhonemeValidator
from phonetic_dictionary import PhoneticDictionary
from hybrid_phoneme_models import HybridPhonemeModels
from pipeline import UnifiedPhonemePipeline
from markov_phoneme_model import MarkovPhonemeModel
from markov_children import  GMMHMMModel, HSMMModel
from diverse_models import SimplePhonemeModels

# %%
# Define paths
path_bids = './SingleWordProductionDutch-iBIDS'
path_output = './features'
path_results = './results'

# Create directories if they don't exist
os.makedirs(path_output, exist_ok=True)
os.makedirs(path_results, exist_ok=True)

# %%
# Pipeline creation with PCA components management
use_augmentation = True
feature_extraction_method = 'high_gamma'  # 'multi_band'
optimal_pca_components = 50  # Use your optimal value determined earlier
use_phoneme_groups = True 

# Try to load existing pipeline, otherwise create new one
try:
    # Try loading existing pipeline
    pipeline = UnifiedPhonemePipeline.load_saved(path_results, method=feature_extraction_method)
    print(f"Loaded existing {feature_extraction_method} pipeline")
    
    # Check and update PCA components if needed
    current_pca = getattr(pipeline, 'pca_components', None)
    if current_pca != optimal_pca_components:
        print(f"Updating PCA components from {current_pca} to {optimal_pca_components}")
        pipeline.set_pca_components(optimal_pca_components)
        
        # Re-run data steps with new PCA components
        print("Re-processing data with updated PCA components...")
        pipeline.step4_initialize_detector()    
        pipeline.step5_accumulate_data()
        pipeline.step6_resolve_unknowns()
        pipeline.step7_filter_unknowns()
        
        # Save the updated pipeline
        pipeline.save()
        print(f"Updated and saved {feature_extraction_method} pipeline with {optimal_pca_components} PCA components")
    
except (FileNotFoundError, AttributeError, TypeError) as e:
    # No existing pipeline found, create new one
    print(f"No existing {feature_extraction_method} pipeline found. Creating new one...")
    
    pipeline = UnifiedPhonemePipeline(
        path_bids=path_bids,
        path_output=path_output,
        path_results=path_results,
        feature_extraction_method=feature_extraction_method,
        unknown_keep_ratio=0.1,
        channel_correlation_threshold=0.3,  # ADD THIS
        prioritize_regions=True,  # ADD THIS
        channel_selection='best_correlation',
        pca_components=optimal_pca_components,  # Set optimal PCA components
        debug_mode=False
    )
    
    # Run all steps
    print("Running pipeline steps...")
    pipeline.step1_initialize_decoder()
    pipeline.step2_stratify_participants(
                            channel_correlation_threshold=0.3,
                            prioritize_regions=True)    
    pipeline.step3_create_split()
    pipeline.step4_initialize_detector()    
    pipeline.step5_accumulate_data()
    pipeline.step6_resolve_unknowns()
    pipeline.step7_filter_unknowns()
    
    # Save the pipeline
    pipeline.save()
    print(f"Created and saved new {feature_extraction_method} pipeline with {optimal_pca_components} PCA components")

# The pipeline is now ready to use with optimal PCA components
print(f"Pipeline ready with {feature_extraction_method} features and {optimal_pca_components} PCA components")
# Out:
# Loading newest matching pipeline: pipeline_high_gamma_pca50_20250821_110940.pkl
# PhoneticDictionary: Initialized with DEBUG_MODE=False
# UnifiedPhonemePipeline: Pipeline initialized: high_gamma, PCA=50, groups=True
# UnifiedPhonemePipeline: Loaded high_gamma pipeline with PCA components=50
# UnifiedPhonemePipeline: Train: 160 samples, Test: 96 samples
# Loaded existing high_gamma pipeline
# Pipeline ready with high_gamma features and 50 PCA components

# %%
# # Get training and test data
# train_data = pipeline.get_training_data(filtered=pipeline.get_training_data(filtered=True))
# test_data = pipeline.get_test_data()
    
# # Check if we have data
# if not train_data or 'features' not in train_data or not train_data['features']:
#     print("Error: No training data available")
    
# # Initialize the models
# simple_models = SimplePhonemeModels(debug_mode=True)
    
# # Train on individual phonemes (no need to map to groups)
# training_results = simple_models.train_all_classical(
#         train_data['features'], 
#         train_data['phoneme_labels']
#     )
    
# # Evaluate on test data
# evaluation_results = {}
# for model_name in simple_models.models:
#     try:
#             # Make predictions
#         predictions, _ = simple_models.predict(
#                 test_data['features'], 
#                 model_name
#             )
            
#             # Calculate accuracy
#         accuracy = np.mean(predictions == test_data['phoneme_labels'])
#         evaluation_results[model_name] = accuracy
            
#         print(f"{model_name} test accuracy: {accuracy:.4f}")
#     except Exception as e:
#         print(f"Error evaluating {model_name}: {e}")

# %%
import gc
import traceback

def compare_feature_extraction_methods(pipeline_class, path_bids, path_output, path_results,
                                     methods=None, pca_components=30, 
                                     use_phoneme_groups=True,
                                     debug_mode=True):
    """Compare different feature extraction methods for phoneme classification."""
    
    if methods is None:
        methods = ['high_gamma', 'multi_band', 'spectral', 'wavelet', 'mfcc']
    
    results = {}
    
    # Create a timestamped file for results
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    results_file = os.path.join(path_results, f"feature_extraction_comparison_{timestamp}.txt")
    
    # Write header
    with open(results_file, 'w') as f:
        f.write(f"Feature Extraction Method Comparison - {timestamp}\n")
        f.write(f"PCA Components: {pca_components}\n")
        f.write(f"Use Phoneme Groups: {use_phoneme_groups}\n")
        f.write("="*60 + "\n\n")
    
    # Create base pipeline for common components
    base_pipeline = None
    
    for method in methods:
        print(f"\n{'='*50}")
        print(f"Testing feature extraction method: {method}")
        print(f"{'='*50}\n")
        
        # Log to file
        with open(results_file, 'a') as f:
            f.write(f"\n{'='*50}\n")
            f.write(f"Testing feature extraction method: {method}\n")
            f.write(f"{'='*50}\n\n")
        
        # INITIALIZE VARIABLES BEFORE TRY BLOCK
        train_data = None
        test_data = None
        balanced_train = None
        
        try:
            # 1. CREATE OR LOAD PIPELINE
            pipeline = pipeline_class(
                path_bids=path_bids,
                path_output=path_output,
                path_results=path_results,
                feature_extraction_method=method,
                pca_components=pca_components,
                use_phoneme_groups=use_phoneme_groups,
                channel_correlation_threshold=0.3,  # ADD THIS
                prioritize_regions=True,  # ADD THIS
                channel_selection='best_correlation', 
                debug_mode=debug_mode
            )
            
            # Try to load checkpoint
            checkpoint_loaded = pipeline.try_load_checkpoint()
            
            if checkpoint_loaded:
                print(f"Loaded checkpoint for {method}")
                # Ensure phonetic dictionary exists
                if not hasattr(pipeline, 'phonetic_dict'):
                    from phonetic_dictionary import PhoneticDictionary
                    pipeline.phonetic_dict = PhoneticDictionary()
                    pipeline.phonetic_dict.add_phoneme_groups()
                
                # Ensure filtered data exists
                if not hasattr(pipeline, 'train_filtered'):
                    pipeline.step7_filter_unknowns()
                    
                # IMPORTANT: Run step 8 if using groups and checkpoint was loaded
                if use_phoneme_groups:
                    pipeline.step8_convert_to_groups()
            else:
                # No checkpoint - run pipeline
                if base_pipeline is None:
                    # First method - run full pipeline (includes step 8)
                    print(f"Creating new pipeline for {method}")
                    pipeline.run_all_steps()
                    base_pipeline = pipeline
                else:
                    # Reuse base components for efficiency
                    print(f"Reusing base components for {method}")
                    pipeline.participant_strata = base_pipeline.participant_strata
                    pipeline.split_result = base_pipeline.split_result
                    pipeline.phonetic_dict = base_pipeline.phonetic_dict
                    
                    # Run method-specific steps
                    pipeline.step1_initialize_decoder()
                    if not pipeline.run_steps_4_to_7():
                        raise ValueError(f"Failed to run steps 4-7 for {method}")
                    
                    # Don't forget step 8!
                    if use_phoneme_groups:
                        pipeline.step8_convert_to_groups()
            
            # 2. GET AND VALIDATE DATA
            train_data = pipeline.get_training_data(filtered=True)
            test_data = pipeline.get_test_data()
            
            if not train_data or not train_data.get('features'):
                raise ValueError(f"No training data for {method}")
            if not test_data or not test_data.get('features'):
                raise ValueError(f"No test data for {method}")
            
            # DIAGNOSTIC: Check label distributions
            from collections import Counter
            train_labels_dist = Counter(train_data['phoneme_labels'])
            test_labels_dist = Counter(test_data['phoneme_labels'])
            
            print(f"Train unique labels: {len(train_labels_dist)}")
            print(f"Test unique labels: {len(test_labels_dist)}")
            print(f"Train label sample: {list(train_labels_dist.keys())[:5]}")
            print(f"Test label sample: {list(test_labels_dist.keys())[:5]}")
            
            # Log data info
            print(f"Train: {len(train_data['features'])} samples, "
                  f"Test: {len(test_data['features'])} samples")
            
            with open(results_file, 'a') as f:
                f.write(f"Train data: {len(train_data['features'])} samples\n")
                f.write(f"Test data: {len(test_data['features'])} samples\n")
                f.write(f"Train unique labels: {len(train_labels_dist)}\n")
                f.write(f"Test unique labels: {len(test_labels_dist)}\n\n")
            
            # 3. BALANCE TRAINING DATA
            balanced_train = pipeline.balance_training_data(
                train_data, 
                balance_strategy='oversample'
            )
            print(f"Balanced training data: {len(balanced_train['features'])} samples")
            
            # VERIFY BALANCING
            balanced_dist = Counter(balanced_train['phoneme_labels'])
            print(f"Balanced distribution: {dict(balanced_dist)}")
            
            # Only proceed if balancing succeeded
            if not balanced_train or not balanced_train.get('features'):
                raise ValueError(f"Balancing failed for {method}")
            
            # 4. TRAIN AND EVALUATE MODELS
            # Create fresh model instance to avoid shape conflicts
            simple_models = SimplePhonemeModels(debug_mode=debug_mode)
            # Clear any cached models/scalers/encoders
            simple_models.models = {}
            simple_models.scalers = {}
            simple_models.label_encoders = {}
            
            # Train all models
            print("Training models")
            training_results = simple_models.train_all_models(
                balanced_train['features'], 
                balanced_train['phoneme_labels'], 
                include_neural=True
            )
            
            # Evaluate all models
            print("Evaluating models")
            eval_results = simple_models.evaluate_all_models(
                test_data['features'], 
                test_data['phoneme_labels']
            )
            
            # Get unique labels from the data
            unique_labels = sorted(set(test_data['phoneme_labels']))

            # Create confusion matrices for top models
            for model_name in eval_results.keys():
                if model_name in simple_models.models and eval_results.get(model_name):
                    try:
                        predictions, _ = simple_models.predict(test_data['features'], model_name)
                        cm = confusion_matrix(test_data['phoneme_labels'], predictions, labels=unique_labels)

                        # Plot with labels and numbers
                        plt.figure(figsize=(12, 10))
                        plt.imshow(cm, interpolation='nearest', cmap='Blues')
                        plt.title(f'{method} - {model_name} (Acc: {eval_results[model_name]:.3f})')
                        plt.colorbar()

                        # Add labels
                        tick_marks = np.arange(len(unique_labels))
                        plt.xticks(tick_marks, unique_labels, rotation=45, ha='right')
                        plt.yticks(tick_marks, unique_labels)

                        # Add numbers in cells
                        thresh = cm.max() / 2.
                        for i in range(cm.shape[0]):
                            for j in range(cm.shape[1]):
                                plt.text(j, i, format(cm[i, j], 'd'),
                                        ha="center", va="center",
                                        color="white" if cm[i, j] > thresh else "black")

                        plt.ylabel('True Label')
                        plt.xlabel('Predicted Label')
                        plt.tight_layout()
                        plt.savefig(os.path.join(path_results, f'cm_{method}_{model_name}_{timestamp}.png'))
                        plt.close()  # Close to avoid memory issues

                    except Exception as e:
                        print(f"Could not create confusion matrix for {model_name}: {e}")
            
            
            # DIAGNOSTIC: Check one model's predictions
            if 'naive_bayes' in simple_models.models:
                test_predictions, _ = simple_models.predict(test_data['features'][:10], 'naive_bayes')
                print(f"Sample predictions: {test_predictions}")
                print(f"Sample true labels: {test_data['phoneme_labels'][:10]}")
            
            # 5. RECORD RESULTS
            method_results = {}
            with open(results_file, 'a') as f:
                f.write("Model Evaluation Results:\n")
                f.write("-"*30 + "\n")
                
                for model_name, accuracy in eval_results.items():
                    if accuracy is not None:
                        method_results[model_name] = accuracy
                        print(f"  {model_name}: {accuracy:.4f}")
                        f.write(f"{model_name}: {accuracy:.4f}\n")
                
                # Best model for this method
                if method_results:
                    best_model = max(method_results, key=method_results.get)
                    best_acc = method_results[best_model]
                    f.write(f"\nBest: {best_model} ({best_acc:.4f})\n\n")
                    print(f"Best for {method}: {best_model} ({best_acc:.4f})")
            
            results[method] = method_results
            
            del pipeline
            gc.collect()
            
        except Exception as e:
            print(f"Error processing {method}: {e}")
            
            # Debug info - now these variables exist
            if train_data:
                print(f"  Had training data: {len(train_data.get('features', []))} samples")
            if test_data:
                print(f"  Had test data: {len(test_data.get('features', []))} samples")
            if balanced_train:
                print(f"  Had balanced data: {len(balanced_train.get('features', []))} samples")            
            with open(results_file, 'a') as f:
                f.write(f"Error: {e}\n\n")

            traceback.print_exc()
    
    # 6. FINAL SUMMARY
    print("\n" + "="*60)
    print("FINAL COMPARISON SUMMARY")
    print("="*60)
    
    with open(results_file, 'a') as f:
        f.write("\n" + "="*60 + "\n")
        f.write("FINAL COMPARISON SUMMARY\n")
        f.write("="*60 + "\n")
        
        if results:
            # Find best overall
            best_method = None
            best_model = None
            best_acc = 0
            
            for method, method_results in results.items():
                if method_results:
                    method_best = max(method_results, key=method_results.get)
                    method_acc = method_results[method_best]
                    
                    print(f"{method:10s}: {method_acc:.4f} ({method_best})")
                    f.write(f"{method:10s}: {method_acc:.4f} ({method_best})\n")
                    
                    if method_acc > best_acc:
                        best_acc = method_acc
                        best_method = method
                        best_model = method_best
            
            if best_method:
                print(f"\nOVERALL BEST: {best_method} with {best_model} ({best_acc:.4f})")
                f.write(f"\nOVERALL BEST: {best_method} with {best_model} ({best_acc:.4f})\n")
        else:
            print("No valid results")
            f.write("No valid results\n")
    
    print(f"\nResults saved to: {results_file}")
    return results, results_file

# %%
# Run the comparison
extraction_results = compare_feature_extraction_methods(
    UnifiedPhonemePipeline,
    path_bids=path_bids,
    path_output=path_output,
    path_results=path_results,
    methods = ['high_gamma', 'multi_band', 'spectral', 'wavelet', 'mfcc'], #['high_gamma'], #, 'multi_band', 'spectral', 'wavelet', 'mfcc'], #, 'mfcc'],  'spectral',  # Start with these 3
    pca_components=30,
    debug_mode=False
)
# Out:
# ==================================================
# Testing feature extraction method: high_gamma
# ==================================================
#
# PhoneticDictionary: Initialized with DEBUG_MODE=False
# UnifiedPhonemePipeline: Pipeline initialized: high_gamma, PCA=30, groups=True
# UnifiedPhonemePipeline: No checkpoint found for high_gamma with PCA=30
# Creating new pipeline for high_gamma
# ============================================================
# RUNNING COMPLETE PIPELINE FOR high_gamma
# ============================================================
# UnifiedPhonemePipeline: Running steps 1-6...
# UnifiedPhonemePipeline: No checkpoint found for high_gamma with PCA=30
# UnifiedPhonemePipeline: Step 1: Initializing
# CustomBrainAudioDecoder: Initializing CustomBrainAudioDecoder with debug_mode=False
# Step 1: Decoder initialized with PCA components=30
# UnifiedPhonemePipeline: Step 2: Setting up acoustic change detector
# CustomBrainAudioDecoder:
# Participant stratification results:
# CustomBrainAudioDecoder:   Participants with most relevant channels: 3
# CustomBrainAudioDecoder:   Participants with relevant channels: 4
# CustomBrainAudioDecoder:   Participants with least relevant channels: 3
# CustomBrainAudioDecoder:
# Top participants by channel quality:
# UnifiedPhonemePipeline: Filtered to 0 participants with good coverage
# UnifiedPhonemePipeline: Step 3: Setting up decoder
# CustomBrainAudioDecoder: Segmenting data for sub-01...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'helft': 1 instances
# CustomBrainAudioDecoder:     2. 'hierop': 1 instances
# CustomBrainAudioDecoder:     3. 'stiekem': 1 instances
# CustomBrainAudioDecoder:     4. 'en': 1 instances
# CustomBrainAudioDecoder:     5. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3074, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-02...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'ook': 1 instances
# CustomBrainAudioDecoder:     2. 'als': 1 instances
# CustomBrainAudioDecoder:     3. 'noordenwind': 1 instances
# CustomBrainAudioDecoder:     4. 'vak': 1 instances
# CustomBrainAudioDecoder:     5. 'over': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-03...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'buurt': 1 instances
# CustomBrainAudioDecoder:     2. 'meisjes': 1 instances
# CustomBrainAudioDecoder:     3. '7': 1 instances
# CustomBrainAudioDecoder:     4. 'vogeltje': 1 instances
# CustomBrainAudioDecoder:     5. 'betovering': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3079, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-04...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'vogeltje': 1 instances
# CustomBrainAudioDecoder:     2. 'wel': 1 instances
# CustomBrainAudioDecoder:     3. 'mooi': 1 instances
# CustomBrainAudioDecoder:     4. 'daarna': 1 instances
# CustomBrainAudioDecoder:     5. 'kasteel': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3071, 115)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (299, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-05...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'verlost': 1 instances
# CustomBrainAudioDecoder:     2. 'terugvinden': 1 instances
# CustomBrainAudioDecoder:     3. 'er': 1 instances
# CustomBrainAudioDecoder:     4. 'hem': 1 instances
# CustomBrainAudioDecoder:     5. 'tot': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 60)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-06...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'hoe': 1 instances
# CustomBrainAudioDecoder:     2. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:     3. 'en': 1 instances
# CustomBrainAudioDecoder:     4. 'het': 1 instances
# CustomBrainAudioDecoder:     5. 'smeekte': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3076, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-07...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'zanddak': 1 instances
# CustomBrainAudioDecoder:     2. 'als': 1 instances
# CustomBrainAudioDecoder:     3. 'terugvinden': 1 instances
# CustomBrainAudioDecoder:     4. 'wegpakte': 1 instances
# CustomBrainAudioDecoder:     5. 'onmiddellijk': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3076, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-08...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'de': 1 instances
# CustomBrainAudioDecoder:     2. 'buurt': 1 instances
# CustomBrainAudioDecoder:     3. 'verstijfde': 1 instances
# CustomBrainAudioDecoder:     4. 'zonlicht': 1 instances
# CustomBrainAudioDecoder:     5. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 54)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-09...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'tak': 1 instances
# CustomBrainAudioDecoder:     2. 'veel': 1 instances
# CustomBrainAudioDecoder:     3. 'helemaal': 1 instances
# CustomBrainAudioDecoder:     4. 'van': 1 instances
# CustomBrainAudioDecoder:     5. 'buurt': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3072, 117)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-10...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. '5': 1 instances
# CustomBrainAudioDecoder:     2. 'naar': 1 instances
# CustomBrainAudioDecoder:     3. 'braadde': 1 instances
# CustomBrainAudioDecoder:     4. 'zo': 1 instances
# CustomBrainAudioDecoder:     5. 'onmiddellijk': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3068, 122)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (299, 23)
# CustomBrainAudioDecoder: Total train instances: 796
# CustomBrainAudioDecoder: Total test instances: 199
# CustomBrainAudioDecoder: Train/Test ratio: 0.80/0.20
# CustomBrainAudioDecoder:
# Participants by strata:
# CustomBrainAudioDecoder:   medium_quality: 796 train, 199 test
# CustomBrainAudioDecoder:     Train proportion: 1.00
# CustomBrainAudioDecoder:     Test proportion: 1.00
# UnifiedPhonemePipeline: Step 3: Train/test split created
# UnifiedPhonemePipeline: Step 4: Processing batches
# AcousticChangeDetector: Initialized with DEBUG_MODE=False
# AcousticChangeDetector: Using feature extraction method: high_gamma
# UnifiedPhonemePipeline: Setting up acoustic change detector with method: high_gamma
# UnifiedPhonemePipeline: Step 5: Accumulating data
# AcousticChangeDetector: Accumulating train data from 5 batches...
# AcousticChangeDetector: Processing batch 1/5
# AcousticChangeDetector: Accumulated 32 phoneme segments so far
# AcousticChangeDetector: Processing batch 2/5
# AcousticChangeDetector: Accumulated 64 phoneme segments so far
# AcousticChangeDetector: Processing batch 3/5
# AcousticChangeDetector: Accumulated 96 phoneme segments so far
# AcousticChangeDetector: Processing batch 4/5
# AcousticChangeDetector: Accumulated 128 phoneme segments so far
# AcousticChangeDetector: Processing batch 5/5
# AcousticChangeDetector: Accumulated 160 phoneme segments so far
# AcousticChangeDetector: Accumulated data from 5 batches:
# AcousticChangeDetector: Total phoneme segments: 160
# AcousticChangeDetector: Unique phonemes: 25
# UnifiedPhonemePipeline: Successfully accumulated 160 training samples
# AcousticChangeDetector: Accumulating test data from 3 batches...
# AcousticChangeDetector: Processing batch 1/3
# AcousticChangeDetector: Accumulated 32 phoneme segments so far
# AcousticChangeDetector: Processing batch 2/3
# AcousticChangeDetector: Accumulated 64 phoneme segments so far
# AcousticChangeDetector: Processing batch 3/3
# AcousticChangeDetector: Accumulated 96 phoneme segments so far
# AcousticChangeDetector: Accumulated data from 3 batches:
# AcousticChangeDetector: Total phoneme segments: 96
# AcousticChangeDetector: Unique phonemes: 29
# UnifiedPhonemePipeline: Successfully accumulated 96 test samples
# UnifiedPhonemePipeline: Step 6: Validating phonemes
# PhonemeValidator: Initialized with DEBUG_MODE=False
# PhonemeValidator: Debug mode enabled
# UnifiedPhonemePipeline: ✓ Step 6: Validator initialized
# UnifiedPhonemePipeline: Resolving 99 unknown phonemes in training...
# PhonemeValidator [DEBUG]: Attempting to resolve 99 unknown phonemes
# PhonemeValidator: Resolved phoneme at position 0 in 'dakker' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'dakker' as 'd'
# PhonemeValidator: Resolved phoneme at position 1 in 'dakker' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'dakker' as 'ɑ'
# PhonemeValidator: Resolved phoneme at position 2 in 'dakker' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'dakker' as 'k'
# PhonemeValidator: Resolved phoneme at position 3 in 'dakker' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'dakker' as 'ə'
# PhonemeValidator: Resolved phoneme at position 0 in 'verstijfde' as 'v'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'verstijfde' as 'v'
# PhonemeValidator: Resolved phoneme at position 1 in 'verstijfde' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'verstijfde' as 'ə'
# PhonemeValidator: Resolved phoneme at position 2 in 'verstijfde' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'verstijfde' as 'r'
# PhonemeValidator: Resolved phoneme at position 3 in 'verstijfde' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'verstijfde' as 's'
# PhonemeValidator: Resolved phoneme at position 4 in 'verstijfde' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'verstijfde' as 't'
# PhonemeValidator: Resolved phoneme at position 5 in 'verstijfde' as 'ɛi'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'verstijfde' as 'ɛi'
# PhonemeValidator: Resolved phoneme at position 6 in 'verstijfde' as 'v'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'verstijfde' as 'v'
# PhonemeValidator: Resolved phoneme at position 7 in 'verstijfde' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'verstijfde' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'komt' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'komt' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'komt' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'komt' as 't'
# PhonemeValidator: Resolved phoneme at position 0 in 'bakker' as 'b'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'bakker' as 'b'
# PhonemeValidator: Resolved phoneme at position 1 in 'bakker' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'bakker' as 'ɑ'
# PhonemeValidator: Resolved phoneme at position 2 in 'bakker' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'bakker' as 'k'
# PhonemeValidator: Resolved phoneme at position 3 in 'bakker' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'bakker' as 'ə'
# PhonemeValidator: Resolved phoneme at position 0 in 'redetwisten' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'redetwisten' as 'r'
# PhonemeValidator: Resolved phoneme at position 1 in 'redetwisten' as 'eː'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'redetwisten' as 'eː'
# PhonemeValidator: Resolved phoneme at position 2 in 'redetwisten' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'redetwisten' as 'd'
# PhonemeValidator: Resolved phoneme at position 0 in 'dauwdruppel' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'dauwdruppel' as 'd'
# PhonemeValidator: Resolved phoneme at position 1 in 'dauwdruppel' as 'ɑu'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'dauwdruppel' as 'ɑu'
# PhonemeValidator: Resolved phoneme at position 2 in 'dauwdruppel' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'dauwdruppel' as 'd'
# PhonemeValidator: Resolved phoneme at position 3 in 'dauwdruppel' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'dauwdruppel' as 'r'
# PhonemeValidator: Resolved phoneme at position 4 in 'dauwdruppel' as 'ʏ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'dauwdruppel' as 'ʏ'
# PhonemeValidator: Resolved phoneme at position 5 in 'dauwdruppel' as 'p'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'dauwdruppel' as 'p'
# PhonemeValidator: Resolved phoneme at position 6 in 'dauwdruppel' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'dauwdruppel' as 'ə'
# PhonemeValidator: Resolved phoneme at position 7 in 'dauwdruppel' as 'l'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'dauwdruppel' as 'l'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'aan' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'aan' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'aan' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'komt' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'komt' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'komt' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'komt' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'komt' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'komt' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'komt' as 'm'
# PhonemeValidator: Resolved phoneme at position 0 in 'zich' as 'z'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'zich' as 'z'
# PhonemeValidator: Resolved phoneme at position 1 in 'zich' as 'ɪ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'zich' as 'ɪ'
# PhonemeValidator: Resolved phoneme at position 2 in 'zich' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'zich' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'stilstaan' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'stilstaan' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'stilstaan' as 'i'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'stilstaan' as 'l'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'stilstaan' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'stilstaan' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'stilstaan' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'stilstaan' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 8 in 'stilstaan' as 'n'
# PhonemeValidator: Resolved phoneme at position 0 in 'nachtegalen' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'nachtegalen' as 'n'
# PhonemeValidator: Resolved phoneme at position 1 in 'nachtegalen' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'nachtegalen' as 'ɑ'
# PhonemeValidator: Resolved phoneme at position 2 in 'nachtegalen' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'nachtegalen' as 'x'
# PhonemeValidator: Resolved phoneme at position 3 in 'nachtegalen' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'nachtegalen' as 't'
# PhonemeValidator: Resolved phoneme at position 4 in 'nachtegalen' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'nachtegalen' as 'ə'
# PhonemeValidator: Resolved phoneme at position 5 in 'nachtegalen' as 'ɣ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'nachtegalen' as 'ɣ'
# PhonemeValidator: Resolved phoneme at position 0 in 'redetwisten' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'redetwisten' as 'r'
# PhonemeValidator: Resolved phoneme at position 1 in 'redetwisten' as 'eː'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'redetwisten' as 'eː'
# PhonemeValidator: Resolved phoneme at position 2 in 'redetwisten' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'redetwisten' as 'd'
# PhonemeValidator: Resolved phoneme at position 3 in 'redetwisten' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'redetwisten' as 'ə'
# PhonemeValidator: Resolved phoneme at position 4 in 'redetwisten' as 'tʋ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'redetwisten' as 'tʋ'
# PhonemeValidator: Resolved phoneme at position 5 in 'redetwisten' as 'ɪ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'redetwisten' as 'ɪ'
# PhonemeValidator: Resolved phoneme at position 6 in 'redetwisten' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'redetwisten' as 's'
# PhonemeValidator: Resolved phoneme at position 7 in 'redetwisten' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'redetwisten' as 't'
# PhonemeValidator: Resolved phoneme at position 0 in 'verstijfde' as 'v'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'verstijfde' as 'v'
# PhonemeValidator: Resolved phoneme at position 1 in 'verstijfde' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'verstijfde' as 'ə'
# PhonemeValidator: Resolved phoneme at position 2 in 'verstijfde' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'verstijfde' as 'r'
# PhonemeValidator: Resolved phoneme at position 3 in 'verstijfde' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'verstijfde' as 's'
# PhonemeValidator: Resolved phoneme at position 4 in 'verstijfde' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'verstijfde' as 't'
# PhonemeValidator: Resolved phoneme at position 5 in 'verstijfde' as 'ɛi'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'verstijfde' as 'ɛi'
# PhonemeValidator: Resolved phoneme at position 6 in 'verstijfde' as 'v'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'verstijfde' as 'v'
# PhonemeValidator: Resolved phoneme at position 7 in 'verstijfde' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'verstijfde' as 'd'
# PhonemeValidator: Resolved phoneme at position 0 in 'maantje' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'maantje' as 'm'
# PhonemeValidator: Resolved phoneme at position 1 in 'maantje' as 'aː'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'maantje' as 'aː'
# PhonemeValidator: Resolved phoneme at position 2 in 'maantje' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'maantje' as 'n'
# PhonemeValidator: Resolved phoneme at position 3 in 'maantje' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'maantje' as 't'
# PhonemeValidator: Resolved phoneme at position 4 in 'maantje' as 'j'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'maantje' as 'j'
# PhonemeValidator: Resolved phoneme at position 0 in 'alsof' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'alsof' as 'ɑ'
# PhonemeValidator: Resolved phoneme at position 1 in 'alsof' as 'l'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'alsof' as 'l'
# PhonemeValidator: Resolved phoneme at position 2 in 'alsof' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'alsof' as 's'
# PhonemeValidator: Resolved phoneme at position 3 in 'alsof' as 'ɔ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'alsof' as 'ɔ'
# PhonemeValidator: Resolved phoneme at position 4 in 'alsof' as 'f'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'alsof' as 'f'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'mooie' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'mooie' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'mooie' as 'o'
# PhonemeValidator: Resolved phoneme at position 0 in '`s' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in '`s' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in '`s' as 's'
# PhonemeValidator: Resolved phoneme at position 0 in 'waren' as 'ʋ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'waren' as 'ʋ'
# PhonemeValidator: Resolved phoneme at position 1 in 'waren' as 'aː'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'waren' as 'aː'
# PhonemeValidator: Resolved phoneme at position 2 in 'waren' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'waren' as 'r'
# PhonemeValidator: Resolved phoneme at position 3 in 'waren' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'waren' as 'ə'
# PhonemeValidator [DEBUG]: Resolved 94 out of 99 unknown phonemes
# PhonemeValidator [DEBUG]: Attempting to resolve 30 unknown phonemes
# PhonemeValidator: Resolved phoneme at position 0 in 'nog' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'nog' as 'n'
# PhonemeValidator: Resolved phoneme at position 1 in 'nog' as 'ɔ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'nog' as 'ɔ'
# PhonemeValidator: Resolved phoneme at position 2 in 'nog' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'nog' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'boomstammen' as 'b'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'boomstammen' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'boomstammen' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'boomstammen' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'boomstammen' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'boomstammen' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'boomstammen' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'boomstammen' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 8 in 'boomstammen' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 9 in 'boomstammen' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 10 in 'boomstammen' as 'n'
# PhonemeValidator: Resolved phoneme at position 0 in 'of' as 'ɔ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'of' as 'ɔ'
# PhonemeValidator: Resolved phoneme at position 1 in 'of' as 'f'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'of' as 'f'
# PhonemeValidator: Resolved phoneme at position 0 in 'zanddak' as 'z'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'zanddak' as 'z'
# PhonemeValidator: Resolved phoneme at position 1 in 'zanddak' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'zanddak' as 'ɑ'
# PhonemeValidator: Resolved phoneme at position 2 in 'zanddak' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'zanddak' as 'n'
# PhonemeValidator: Resolved phoneme at position 3 in 'zanddak' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'zanddak' as 'd'
# PhonemeValidator: Resolved phoneme at position 4 in 'zanddak' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'zanddak' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved 21 out of 30 unknown phonemes
# UnifiedPhonemePipeline: Test after resolution: 9 unknown phonemes
# UnifiedPhonemePipeline: WARNING: There are still 5 unknown phonemes in training and 9 in test.
# UnifiedPhonemePipeline: The pipeline will continue, but some phonemes will be treated as the '?' class.
# UnifiedPhonemePipeline: Saving checkpoint after step 6: pipeline_high_gamma_pca30_after_step6_20250821_192116.pkl
# UnifiedPhonemePipeline: Checkpoint saved: pipeline_high_gamma_pca30_after_step6_20250821_192116.pkl (train: 160, test: 96 samples)
# UnifiedPhonemePipeline: Train data: 160 samples
# UnifiedPhonemePipeline: Unique phonemes: 34
# UnifiedPhonemePipeline: Running step 7 and beyond...
# UnifiedPhonemePipeline: Step 7: Resolving unknown phonemes
# UnifiedPhonemePipeline: Filtered training: 155 samples (from 160)
# UnifiedPhonemePipeline: Step 8: Converting phonemes to groups...
# UnifiedPhonemePipeline: Unmapped phonemes: {'tʋ'}
# UnifiedPhonemePipeline: Unmapped phonemes: {'tʋ'}
# UnifiedPhonemePipeline: Train data: 8 groups, {'alveolar': 51, 'back_vowels': 42, 'dorsal': 10, 'labial': 24, 'palatal': 11, 'front_vowels': 14, 'glottal': 2, 'unknown': 6}
# UnifiedPhonemePipeline: Step 8: Conversion to groups complete
#
# ============================================================
# PIPELINE COMPLETE
# ============================================================
# Train unique labels: 8
# Test unique labels: 8
# Train label sample: ['alveolar', 'back_vowels', 'dorsal', 'labial', 'palatal']
# Test label sample: ['alveolar', 'front_vowels', 'labial', 'back_vowels', 'dorsal']
# Train: 155 samples, Test: 96 samples
# UnifiedPhonemePipeline: Working with group labels
# UnifiedPhonemePipeline: Original distribution: {'alveolar': 51, 'back_vowels': 42, 'dorsal': 10, 'labial': 24, 'palatal': 11, 'front_vowels': 14, 'glottal': 2, 'unknown': 1}
# UnifiedPhonemePipeline: Balanced distribution: {'dorsal': 51, 'unknown': 51, 'labial': 51, 'front_vowels': 51, 'back_vowels': 51, 'alveolar': 51, 'glottal': 51, 'palatal': 51}
# Balanced training data: 408 samples
# Balanced distribution: {'dorsal': 51, 'unknown': 51, 'labial': 51, 'front_vowels': 51, 'back_vowels': 51, 'alveolar': 51, 'glottal': 51, 'palatal': 51}
# SimplePhonemeModels: Initialized with DEBUG_MODE=False
# Training models
# SimplePhonemeModels: Training naive_bayes...
# SimplePhonemeModels: naive_bayes training accuracy: 0.6495
# SimplePhonemeModels: Training logistic...
# SimplePhonemeModels: logistic training accuracy: 0.8946
# SimplePhonemeModels: Training lda...
# SimplePhonemeModels: lda training accuracy: 0.8946
# SimplePhonemeModels: Training knn...
# SimplePhonemeModels: knn training accuracy: 0.7843
# SimplePhonemeModels: Training linear_svm...
# SimplePhonemeModels: linear_svm training accuracy: 0.8946
# SimplePhonemeModels: Training random_forest...
# SimplePhonemeModels: random_forest training accuracy: 0.8946
# SimplePhonemeModels: Training gradient_boosting...
# SimplePhonemeModels: gradient_boosting training accuracy: 0.8946
# SimplePhonemeModels: Training lightgbm...
# SimplePhonemeModels: lightgbm training accuracy: 0.8946
# SimplePhonemeModels: Training mlp...
# C:\Users\irina\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# SimplePhonemeModels: mlp training accuracy: 0.6012
# SimplePhonemeModels: mlp training accuracy: 0.6012
# SimplePhonemeModels: mlp validation accuracy: 0.7561
# SimplePhonemeModels: Training cnn...
# C:\Users\irina\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# SimplePhonemeModels: cnn training accuracy: 0.8006
# SimplePhonemeModels: cnn training accuracy: 0.8006
# SimplePhonemeModels: cnn validation accuracy: 0.7073
# SimplePhonemeModels: Training rnn...
# C:\Users\irina\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# SimplePhonemeModels: rnn training accuracy: 0.8466
# SimplePhonemeModels: rnn training accuracy: 0.8466
# SimplePhonemeModels: rnn validation accuracy: 0.6829
# SimplePhonemeModels: Training tcn...
# SimplePhonemeModels: tcn training accuracy: 0.8436
# SimplePhonemeModels: tcn training accuracy: 0.8436
# SimplePhonemeModels: tcn validation accuracy: 0.7195
# Evaluating models
# SimplePhonemeModels: naive_bayes test accuracy: 0.1250
# SimplePhonemeModels: logistic test accuracy: 0.2396
# SimplePhonemeModels: lda test accuracy: 0.1771
# SimplePhonemeModels: knn test accuracy: 0.2500
# SimplePhonemeModels: linear_svm test accuracy: 0.2292
# SimplePhonemeModels: random_forest test accuracy: 0.2812
# SimplePhonemeModels: gradient_boosting test accuracy: 0.2396
# SimplePhonemeModels: lightgbm test accuracy: 0.2708
# SimplePhonemeModels: mlp test accuracy: 0.1562
# SimplePhonemeModels: cnn test accuracy: 0.1771
# SimplePhonemeModels: rnn test accuracy: 0.1458
# SimplePhonemeModels: tcn test accuracy: 0.2188
# Error processing high_gamma: name 'models_for_confusion' is not defined
#   Had training data: 155 samples
#   Had test data: 96 samples
#   Had balanced data: 408 samples
#
# ==================================================
# Testing feature extraction method: multi_band
# ==================================================
#
# PhoneticDictionary: Initialized with DEBUG_MODE=False
# UnifiedPhonemePipeline: Pipeline initialized: multi_band, PCA=30, groups=True
# UnifiedPhonemePipeline: No checkpoint found for multi_band with PCA=30
# Reusing base components for multi_band
# CustomBrainAudioDecoder: Initializing CustomBrainAudioDecoder with debug_mode=False
# Step 1: Decoder initialized with PCA components=30
# UnifiedPhonemePipeline: Step 4: Initializing detector
# AcousticChangeDetector: Initialized with DEBUG_MODE=False
# AcousticChangeDetector: Using feature extraction method: multi_band
# UnifiedPhonemePipeline: Setting up acoustic change detector with method: multi_band
# UnifiedPhonemePipeline: Step 5: Accumulating data
# AcousticChangeDetector: Accumulating train data from 5 batches...
# AcousticChangeDetector: Processing batch 1/5
# Traceback (most recent call last):
#   File "C:\Users\irina\AppData\Local\Temp\ipykernel_17564\2632437683.py", line 172, in compare_feature_extraction_methods
#     for model_name in models_for_confusion: #['random_forest', 'lightgbm', 'gradient_boosting']:  # Top performers
#                       ^^^^^^^^^^^^^^^^^^^^
# NameError: name 'models_for_confusion' is not defined
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 32 phoneme segments so far
# AcousticChangeDetector: Processing batch 2/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 64 phoneme segments so far
# AcousticChangeDetector: Processing batch 3/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 96 phoneme segments so far
# AcousticChangeDetector: Processing batch 4/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 128 phoneme segments so far
# AcousticChangeDetector: Processing batch 5/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 160 phoneme segments so far
# AcousticChangeDetector: Accumulated data from 5 batches:
# AcousticChangeDetector: Total phoneme segments: 160
# AcousticChangeDetector: Unique phonemes: 40
# UnifiedPhonemePipeline: Successfully accumulated 160 training samples
# AcousticChangeDetector: Accumulating test data from 3 batches...
# AcousticChangeDetector: Processing batch 1/3
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 32 phoneme segments so far
# AcousticChangeDetector: Processing batch 2/3
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 64 phoneme segments so far
# AcousticChangeDetector: Processing batch 3/3
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 96 phoneme segments so far
# AcousticChangeDetector: Accumulated data from 3 batches:
# ...
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# DEBUG: custom_feature_extraction called with method: mfcc
# CustomBrainAudioDecoder: python_speech_features not installed. Using high_gamma method instead.
# AcousticChangeDetector: Accumulated 96 phoneme segments so far
# AcousticChangeDetector: Accumulated data from 3 batches:
# AcousticChangeDetector: Total phoneme segments: 96
# AcousticChangeDetector: Unique phonemes: 30
# UnifiedPhonemePipeline: Successfully accumulated 96 test samples
# UnifiedPhonemePipeline: Step 6: Resolving unknowns
# PhonemeValidator: Initialized with DEBUG_MODE=False
# PhonemeValidator: Debug mode enabled
# UnifiedPhonemePipeline: ✓ Step 6: Validator initialized
# UnifiedPhonemePipeline: Resolving 52 unknown phonemes in training...
# PhonemeValidator [DEBUG]: Attempting to resolve 52 unknown phonemes
# PhonemeValidator: Resolved phoneme at position 0 in 'zich' as 'z'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'zich' as 'z'
# PhonemeValidator: Resolved phoneme at position 1 in 'zich' as 'ɪ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'zich' as 'ɪ'
# PhonemeValidator: Resolved phoneme at position 2 in 'zich' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'zich' as 'x'
# PhonemeValidator: Resolved phoneme at position 0 in 'dauwdruppel' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'dauwdruppel' as 'd'
# PhonemeValidator: Resolved phoneme at position 1 in 'dauwdruppel' as 'ɑu'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'dauwdruppel' as 'ɑu'
# PhonemeValidator: Resolved phoneme at position 2 in 'dauwdruppel' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'dauwdruppel' as 'd'
# PhonemeValidator: Resolved phoneme at position 3 in 'dauwdruppel' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'dauwdruppel' as 'r'
# PhonemeValidator: Resolved phoneme at position 4 in 'dauwdruppel' as 'ʏ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'dauwdruppel' as 'ʏ'
# PhonemeValidator: Resolved phoneme at position 5 in 'dauwdruppel' as 'p'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'dauwdruppel' as 'p'
# PhonemeValidator: Resolved phoneme at position 6 in 'dauwdruppel' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'dauwdruppel' as 'ə'
# PhonemeValidator: Resolved phoneme at position 0 in '`s' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in '`s' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in '`s' as 's'
# PhonemeValidator: Resolved phoneme at position 0 in 'zonlicht' as 'z'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'zonlicht' as 'z'
# PhonemeValidator: Resolved phoneme at position 1 in 'zonlicht' as 'ɔ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'zonlicht' as 'ɔ'
# PhonemeValidator: Resolved phoneme at position 2 in 'zonlicht' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'zonlicht' as 'n'
# PhonemeValidator: Resolved phoneme at position 3 in 'zonlicht' as 'l'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'zonlicht' as 'l'
# PhonemeValidator: Resolved phoneme at position 4 in 'zonlicht' as 'ɪ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'zonlicht' as 'ɪ'
# PhonemeValidator: Resolved phoneme at position 5 in 'zonlicht' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'zonlicht' as 'x'
# PhonemeValidator: Resolved phoneme at position 6 in 'zonlicht' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'zonlicht' as 't'
# PhonemeValidator: Resolved phoneme at position 0 in 'waren' as 'ʋ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'waren' as 'ʋ'
# PhonemeValidator: Resolved phoneme at position 1 in 'waren' as 'aː'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'waren' as 'aː'
# PhonemeValidator: Resolved phoneme at position 2 in 'waren' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'waren' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'dichtbij' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'dichtbij' as 'i'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'dichtbij' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'dichtbij' as 'h'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'dichtbij' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'dichtbij' as 'b'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'dichtbij' as 'i'
# PhonemeValidator: Resolved phoneme at position 0 in 'of' as 'ɔ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'of' as 'ɔ'
# PhonemeValidator: Resolved phoneme at position 1 in 'of' as 'f'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'of' as 'f'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'totdat' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'totdat' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'totdat' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'totdat' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'totdat' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'totdat' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'werd' as 'w'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'werd' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'werd' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'werd' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'werd' as 'w'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'werd' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'werd' as 'r'
# PhonemeValidator [DEBUG]: Resolved 44 out of 52 unknown phonemes
# PhonemeValidator [DEBUG]: Attempting to resolve 13 unknown phonemes
# PhonemeValidator: Resolved phoneme at position 0 in 'zich' as 'z'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'zich' as 'z'
# PhonemeValidator: Resolved phoneme at position 1 in 'zich' as 'ɪ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'zich' as 'ɪ'
# PhonemeValidator: Resolved phoneme at position 2 in 'zich' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'zich' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'tak' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'tak' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'tak' as 'k'
# PhonemeValidator: Resolved phoneme at position 0 in '`s' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in '`s' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in '`s' as 's'
# PhonemeValidator: Resolved phoneme at position 0 in 'of' as 'ɔ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'of' as 'ɔ'
# PhonemeValidator: Resolved phoneme at position 1 in 'of' as 'f'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'of' as 'f'
# PhonemeValidator [DEBUG]: Resolved 10 out of 13 unknown phonemes
# UnifiedPhonemePipeline: Test after resolution: 3 unknown phonemes
# UnifiedPhonemePipeline: WARNING: There are still 8 unknown phonemes in training and 3 in test.
# UnifiedPhonemePipeline: The pipeline will continue, but some phonemes will be treated as the '?' class.
# UnifiedPhonemePipeline: Saving checkpoint after step 6: pipeline_mfcc_pca30_after_step6_20250821_193135.pkl
# UnifiedPhonemePipeline: Checkpoint saved: pipeline_mfcc_pca30_after_step6_20250821_193135.pkl (train: 160, test: 96 samples)
# UnifiedPhonemePipeline: Step 7: Filtering unknowns
# UnifiedPhonemePipeline: Filtered training: 153 samples (from 160)
# UnifiedPhonemePipeline: Steps 4-7 completed successfully
# UnifiedPhonemePipeline: Step 8: Converting phonemes to groups...
# UnifiedPhonemePipeline: Unmapped phonemes: {'øː', 'w', 'ʋɑ'}
# UnifiedPhonemePipeline: Unmapped phonemes: {'tʋ', 'ʋɑ'}
# UnifiedPhonemePipeline: Unmapped phonemes: {'øː', 'w', 'ʋɑ'}
# UnifiedPhonemePipeline: Train data: 8 groups, {'labial': 14, 'front_vowels': 23, 'alveolar': 46, 'dorsal': 11, 'back_vowels': 30, 'glottal': 10, 'palatal': 14, 'unknown': 12}
# UnifiedPhonemePipeline: Step 8: Conversion to groups complete
# Train unique labels: 8
# Test unique labels: 8
# Train label sample: ['labial', 'front_vowels', 'alveolar', 'dorsal', 'back_vowels']
# Test label sample: ['glottal', 'front_vowels', 'alveolar', 'back_vowels', 'palatal']
# Train: 153 samples, Test: 96 samples
# UnifiedPhonemePipeline: Working with group labels
# UnifiedPhonemePipeline: Original distribution: {'labial': 14, 'front_vowels': 23, 'alveolar': 46, 'dorsal': 11, 'back_vowels': 30, 'glottal': 10, 'palatal': 14, 'unknown': 5}
# UnifiedPhonemePipeline: Balanced distribution: {'palatal': 46, 'labial': 46, 'dorsal': 46, 'alveolar': 46, 'back_vowels': 46, 'glottal': 46, 'front_vowels': 46, 'unknown': 46}
# Balanced training data: 368 samples
# Balanced distribution: {'palatal': 46, 'labial': 46, 'dorsal': 46, 'alveolar': 46, 'back_vowels': 46, 'glottal': 46, 'front_vowels': 46, 'unknown': 46}
# SimplePhonemeModels: Initialized with DEBUG_MODE=False
# Training models
# SimplePhonemeModels: Training naive_bayes...
# SimplePhonemeModels: naive_bayes training accuracy: 0.6467
# SimplePhonemeModels: Training logistic...
# SimplePhonemeModels: logistic training accuracy: 0.8560
# SimplePhonemeModels: Training lda...
# SimplePhonemeModels: lda training accuracy: 0.8560
# SimplePhonemeModels: Training knn...
# SimplePhonemeModels: knn training accuracy: 0.7038
# SimplePhonemeModels: Training linear_svm...
# SimplePhonemeModels: linear_svm training accuracy: 0.8560
# SimplePhonemeModels: Training random_forest...
# SimplePhonemeModels: random_forest training accuracy: 0.8560
# SimplePhonemeModels: Training gradient_boosting...
# SimplePhonemeModels: gradient_boosting training accuracy: 0.8560
# SimplePhonemeModels: Training lightgbm...
# SimplePhonemeModels: lightgbm training accuracy: 0.8560
# SimplePhonemeModels: Training mlp...
# C:\Users\irina\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# SimplePhonemeModels: mlp training accuracy: 0.5340
# SimplePhonemeModels: mlp training accuracy: 0.5340
# SimplePhonemeModels: mlp validation accuracy: 0.6622
# SimplePhonemeModels: Training cnn...
# C:\Users\irina\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# SimplePhonemeModels: cnn training accuracy: 0.7075
# SimplePhonemeModels: cnn training accuracy: 0.7075
# SimplePhonemeModels: cnn validation accuracy: 0.6757
# SimplePhonemeModels: Training rnn...
# C:\Users\irina\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# SimplePhonemeModels: rnn training accuracy: 0.7857
# SimplePhonemeModels: rnn training accuracy: 0.7857
# SimplePhonemeModels: rnn validation accuracy: 0.7297
# SimplePhonemeModels: Training tcn...
# SimplePhonemeModels: tcn training accuracy: 0.7551
# SimplePhonemeModels: tcn training accuracy: 0.7551
# SimplePhonemeModels: tcn validation accuracy: 0.6757
# Evaluating models
# SimplePhonemeModels: naive_bayes test accuracy: 0.2188
# SimplePhonemeModels: logistic test accuracy: 0.1875
# SimplePhonemeModels: lda test accuracy: 0.2500
# SimplePhonemeModels: knn test accuracy: 0.0938
# SimplePhonemeModels: linear_svm test accuracy: 0.1979
# SimplePhonemeModels: random_forest test accuracy: 0.2083
# SimplePhonemeModels: gradient_boosting test accuracy: 0.2188
# SimplePhonemeModels: lightgbm test accuracy: 0.2396
# SimplePhonemeModels: mlp test accuracy: 0.2083
# SimplePhonemeModels: cnn test accuracy: 0.2812
# SimplePhonemeModels: rnn test accuracy: 0.1771
# SimplePhonemeModels: tcn test accuracy: 0.2812
# Error processing mfcc: name 'models_for_confusion' is not defined
#   Had training data: 153 samples
#   Had test data: 96 samples
#   Had balanced data: 368 samples
#
# ============================================================
# FINAL COMPARISON SUMMARY
# ============================================================
# No valid results
#
# Results saved to: ./results\feature_extraction_comparison_20250821_192051.txt
# Traceback (most recent call last):
#   File "C:\Users\irina\AppData\Local\Temp\ipykernel_17564\2632437683.py", line 172, in compare_feature_extraction_methods
#     for model_name in models_for_confusion: #['random_forest', 'lightgbm', 'gradient_boosting']:  # Top performers
#                       ^^^^^^^^^^^^^^^^^^^^
# NameError: name 'models_for_confusion' is not defined

# %% [markdown]
# #####
