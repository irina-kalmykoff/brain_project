# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Audio, display
from pynwb import NWBHDF5IO

import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, IntSlider, FloatSlider, Dropdown, Checkbox

from brain_audio_decoder import BrainAudioDecoder
from custom_decoder import CustomBrainAudioDecoder
from brain_audio_decoder_viz import BrainAudioDecoderViz
from acoustic_change_detector import AcousticChangeDetector
from phoneme_validator import PhonemeValidator
from phonetic_dictionary import PhoneticDictionary
from feature_vizualizer import PhonemeFeatureVisualizer
from pipeline import UnifiedPhonemePipeline

# %%
# Define paths
path_bids = './SingleWordProductionDutch-iBIDS'  # Path to the BIDS dataset
path_output = './features'  # Path to save extracted features
path_results = './results'  # Path to save results

# %%
visualizer = PhonemeFeatureVisualizer(output_dir='./phoneme_visualizations')

# %%
# Pipeline creation with PCA components management
use_augmentation = True
feature_extraction_method = 'high_gamma' #'high_gamma'  #
optimal_pca_components = 50  # Use your optimal value determined earlier

# Try to load existing pipeline, otherwise create new one
try:
    # Try loading existing pipeline
    pipeline = UnifiedPhonemePipeline.load_saved(path_results, method=feature_extraction_method)
    print(f"Loaded existing {feature_extraction_method} pipeline")
    
    # Check and update PCA components if needed
    current_pca = getattr(pipeline, 'pca_components', None)
    if current_pca != optimal_pca_components:
        print(f"Updating PCA components from {current_pca} to {optimal_pca_components}")
        pipeline.set_pca_components(optimal_pca_components)
        
        # Re-run data steps with new PCA components
        print("Re-processing data with updated PCA components...")
        pipeline.step4_initialize_detector()    
        pipeline.step5_accumulate_data()
        pipeline.step6_resolve_unknowns()
        pipeline.step7_filter_unknowns()
        
        # Save the updated pipeline
        pipeline.save()
        print(f"Updated and saved {feature_extraction_method} pipeline with {optimal_pca_components} PCA components")
    
except (FileNotFoundError, AttributeError, TypeError) as e:
    # No existing pipeline found, create new one
    print(f"No existing {feature_extraction_method} pipeline found. Creating new one...")
    
    pipeline = UnifiedPhonemePipeline(
        path_bids=path_bids,
        path_output=path_output,
        path_results=path_results,
        feature_extraction_method=feature_extraction_method,
        unknown_keep_ratio=0.1,
        channel_correlation_threshold=0.3,  # ADD THIS
        prioritize_regions=True,  # ADD THIS
        channel_selection='best_correlation',
        pca_components=optimal_pca_components,  # Set optimal PCA components
        debug_mode=True
    )
    
    # Run all steps
    print("Running pipeline steps...")
    pipeline.step1_initialize_decoder()
    pipeline.step2_stratify_participants()    
    pipeline.step3_create_split()
    pipeline.step4_initialize_detector()    
    pipeline.step5_accumulate_data()
    pipeline.step6_resolve_unknowns()
    pipeline.step7_filter_unknowns()
    
    # Save the pipeline
    pipeline.save()
    print(f"Created and saved new {feature_extraction_method} pipeline with {optimal_pca_components} PCA components")

# The pipeline is now ready to use with optimal PCA components
print(f"Pipeline ready with {feature_extraction_method} features and {optimal_pca_components} PCA components")
# Out:
# Loading newest matching pipeline: pipeline_high_gamma_pca30_after_step6_20250825_213636.pkl
# PhoneticDictionary: Initialized with DEBUG_MODE=False
# UnifiedPhonemePipeline: Pipeline initialized: high_gamma, PCA=50, groups=True
# C:\Users\irina\anaconda3\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 1.2.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\irina\anaconda3\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator PCA from version 1.2.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# UnifiedPhonemePipeline: Loaded high_gamma pipeline with PCA components=30
# UnifiedPhonemePipeline: Train: 0 samples, Test: 0 samples
# Loaded existing high_gamma pipeline
# Updating PCA components from 30 to 50
# UnifiedPhonemePipeline: Set pipeline PCA components to 50
# Re-processing data with updated PCA components...
# No existing high_gamma pipeline found. Creating new one...
# PhoneticDictionary: Initialized with DEBUG_MODE=True
# UnifiedPhonemePipeline: Pipeline initialized: high_gamma, PCA=50, groups=True
# Running pipeline steps...
# CustomBrainAudioDecoder: Initializing CustomBrainAudioDecoder with debug_mode=True
# CustomBrainAudioDecoder [DEBUG]: Initialized with config: {'pca_components': 50, 'feature_extraction_method': 'high_gamma', 'temporal_context': True, 'standardize': True, 'frameshift': 0.01, 'win_length': 0.05}
# Step 1: Decoder initialized with PCA components=50
# CustomBrainAudioDecoder [DEBUG]: Stratifying participants based on channel quality...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-01...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-02...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-03...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-04...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-05...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-06...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-07...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-08...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-09...
# CustomBrainAudioDecoder [DEBUG]: Analyzing channels for sub-10...
# CustomBrainAudioDecoder:
# Participant stratification results:
# CustomBrainAudioDecoder:   Participants with most relevant channels: 3
# CustomBrainAudioDecoder:   Participants with relevant channels: 4
# CustomBrainAudioDecoder:   Participants with least relevant channels: 3
# CustomBrainAudioDecoder:
# Top participants by channel quality:
# CustomBrainAudioDecoder [DEBUG]:   1. sub-07: 81 relevant channels, mean correlation: 0.3306, quality score: 26.7753
# CustomBrainAudioDecoder [DEBUG]:   2. sub-10: 76 relevant channels, mean correlation: 0.3152, quality score: 23.9535
# CustomBrainAudioDecoder [DEBUG]:   3. sub-08: 49 relevant channels, mean correlation: 0.4765, quality score: 23.3476
# CustomBrainAudioDecoder [DEBUG]:   ...
# CustomBrainAudioDecoder [DEBUG]:   10. sub-01: 5 relevant channels, mean correlation: 0.0481, quality score: 0.2403
# UnifiedPhonemePipeline: Filtered to 0 participants with good coverage
# CustomBrainAudioDecoder: Segmenting data for sub-01...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-01...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307511 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['helft' 'helft' 'helft' 'helft' 'helft' 'helft' 'helft' 'helft' 'helft'
#  'helft']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(0, 'helft'), (3075, 'hierop'), (6149, 'stiekem'), (9228, 'en'), (12300, 'zevenduizend')]
# CustomBrainAudioDecoder [DEBUG]: Warning: Audio segment out of bounds for word 'schold' at index 304435
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'helft': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'hierop': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'stiekem': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'en': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'zevenduizend': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'helft': 1 instances
# CustomBrainAudioDecoder:     2. 'hierop': 1 instances
# CustomBrainAudioDecoder:     3. 'stiekem': 1 instances
# CustomBrainAudioDecoder:     4. 'en': 1 instances
# CustomBrainAudioDecoder:     5. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3074, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-02...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-02...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307516 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['ook' 'ook' 'ook' 'ook' 'ook' 'ook' 'ook' 'ook' 'ook' 'ook']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(0, 'ook'), (3076, 'als'), (6151, 'noordenwind'), (9227, 'vak'), (12301, 'over')]
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'ook': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'als': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'noordenwind': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'vak': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'over': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'ook': 1 instances
# CustomBrainAudioDecoder:     2. 'als': 1 instances
# CustomBrainAudioDecoder:     3. 'noordenwind': 1 instances
# CustomBrainAudioDecoder:     4. 'vak': 1 instances
# CustomBrainAudioDecoder:     5. 'over': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-03...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-03...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307523 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['buurt' 'buurt' 'buurt' 'buurt' 'buurt' 'buurt' 'buurt' 'buurt' 'buurt'
#  'buurt']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(0, 'buurt'), (3080, 'meisjes'), (6153, '7'), (9227, 'vogeltje'), (12303, 'betovering')]
# CustomBrainAudioDecoder [DEBUG]: Warning: Audio segment out of bounds for word 'dak' at index 304447
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'buurt': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'meisjes': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word '7': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'vogeltje': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'betovering': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'buurt': 1 instances
# CustomBrainAudioDecoder:     2. 'meisjes': 1 instances
# CustomBrainAudioDecoder:     3. '7': 1 instances
# CustomBrainAudioDecoder:     4. 'vogeltje': 1 instances
# CustomBrainAudioDecoder:     5. 'betovering': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3079, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-04...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-04...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307521 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['' 'vogeltje' 'vogeltje' 'vogeltje' 'vogeltje' 'vogeltje' 'vogeltje'
#  'vogeltje' 'vogeltje' 'vogeltje']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(1, 'vogeltje'), (3072, 'wel'), (6147, 'mooi'), (9225, 'daarna'), (12302, 'kasteel')]
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'vogeltje': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'wel': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'mooi': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'daarna': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'kasteel': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'vogeltje': 1 instances
# CustomBrainAudioDecoder:     2. 'wel': 1 instances
# CustomBrainAudioDecoder:     3. 'mooi': 1 instances
# CustomBrainAudioDecoder:     4. 'daarna': 1 instances
# CustomBrainAudioDecoder:     5. 'kasteel': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3071, 115)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (299, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-05...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-05...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307497 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['' 'verlost' 'verlost' 'verlost' 'verlost' 'verlost' 'verlost' 'verlost'
#  'verlost' 'verlost']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(1, 'verlost'), (3076, 'terugvinden'), (6152, 'er'), (9225, 'hem'), (12301, 'tot')]
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'verlost': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'terugvinden': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'er': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'hem': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'tot': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'verlost': 1 instances
# CustomBrainAudioDecoder:     2. 'terugvinden': 1 instances
# CustomBrainAudioDecoder:     3. 'er': 1 instances
# CustomBrainAudioDecoder:     4. 'hem': 1 instances
# CustomBrainAudioDecoder:     5. 'tot': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 60)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-06...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-06...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307594 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['hoe' 'hoe' 'hoe' 'hoe' 'hoe' 'hoe' 'hoe' 'hoe' 'hoe' 'hoe']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(0, 'hoe'), (3077, 'zevenduizend'), (6152, 'en'), (9228, 'het'), (12302, 'smeekte')]
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'hoe': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'zevenduizend': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'en': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'het': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'smeekte': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'hoe': 1 instances
# CustomBrainAudioDecoder:     2. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:     3. 'en': 1 instances
# CustomBrainAudioDecoder:     4. 'het': 1 instances
# CustomBrainAudioDecoder:     5. 'smeekte': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3076, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-07...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-07...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307576 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['zanddak' 'zanddak' 'zanddak' 'zanddak' 'zanddak' 'zanddak' 'zanddak'
#  'zanddak' 'zanddak' 'zanddak']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(0, 'zanddak'), (3077, 'als'), (6151, 'terugvinden'), (9231, 'wegpakte'), (12304, 'onmiddellijk')]
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'zanddak': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'als': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'terugvinden': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'wegpakte': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'onmiddellijk': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'zanddak': 1 instances
# CustomBrainAudioDecoder:     2. 'als': 1 instances
# CustomBrainAudioDecoder:     3. 'terugvinden': 1 instances
# CustomBrainAudioDecoder:     4. 'wegpakte': 1 instances
# CustomBrainAudioDecoder:     5. 'onmiddellijk': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3076, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-08...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-08...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307579 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['de' 'de' 'de' 'de' 'de' 'de' 'de' 'de' 'de' 'de']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(0, 'de'), (3076, 'buurt'), (6153, 'verstijfde'), (9231, 'zonlicht'), (12307, 'zevenduizend')]
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'de': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'buurt': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'verstijfde': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'zonlicht': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'zevenduizend': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'de': 1 instances
# CustomBrainAudioDecoder:     2. 'buurt': 1 instances
# CustomBrainAudioDecoder:     3. 'verstijfde': 1 instances
# CustomBrainAudioDecoder:     4. 'zonlicht': 1 instances
# CustomBrainAudioDecoder:     5. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 54)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-09...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-09...
# CustomBrainAudioDecoder [DEBUG]: Loaded 307595 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['tak' 'tak' 'tak' 'tak' 'tak' 'tak' 'tak' 'tak' 'tak' 'tak']
# CustomBrainAudioDecoder [DEBUG]: Found 100 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(0, 'tak'), (3073, 'veel'), (6153, 'helemaal'), (9229, 'van'), (12305, 'buurt')]
# CustomBrainAudioDecoder [DEBUG]: Found 100 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word 'tak': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'veel': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'helemaal': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'van': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'buurt': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 100
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 100
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 99
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 99
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'tak': 1 instances
# CustomBrainAudioDecoder:     2. 'veel': 1 instances
# CustomBrainAudioDecoder:     3. 'helemaal': 1 instances
# CustomBrainAudioDecoder:     4. 'van': 1 instances
# CustomBrainAudioDecoder:     5. 'buurt': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3072, 117)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-10...
# CustomBrainAudioDecoder [DEBUG]: Segmenting data by words for sub-10...
# CustomBrainAudioDecoder [DEBUG]: Loaded 291900 word markers
# CustomBrainAudioDecoder [DEBUG]: First 10 word markers: ['' '5' '5' '5' '5' '5' '5' '5' '5' '5']
# CustomBrainAudioDecoder [DEBUG]: Found 95 word onsets
# CustomBrainAudioDecoder [DEBUG]: First 5 word onsets: [(1, '5'), (3069, 'naar'), (6138, 'braadde'), (9209, 'zo'), (12279, 'onmiddellijk')]
# CustomBrainAudioDecoder [DEBUG]: Found 95 unique words with at least 1 occurrences
# CustomBrainAudioDecoder [DEBUG]: Word '5': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'naar': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'braadde': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'zo': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word 'onmiddellijk': 1 instances
# CustomBrainAudioDecoder [DEBUG]: Word statistics:
# CustomBrainAudioDecoder [DEBUG]:   Total unique words: 95
# CustomBrainAudioDecoder [DEBUG]:   Total word instances: 95
# CustomBrainAudioDecoder [DEBUG]:
# Overlap statistics:
# CustomBrainAudioDecoder [DEBUG]:   Overlapping segments detected: 94
# CustomBrainAudioDecoder [DEBUG]:   Segments adjusted to avoid overlap: 94
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. '5': 1 instances
# CustomBrainAudioDecoder:     2. 'naar': 1 instances
# CustomBrainAudioDecoder:     3. 'braadde': 1 instances
# CustomBrainAudioDecoder:     4. 'zo': 1 instances
# CustomBrainAudioDecoder:     5. 'onmiddellijk': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3068, 122)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (299, 23)
# CustomBrainAudioDecoder: Total train instances: 796
# CustomBrainAudioDecoder: Total test instances: 199
# CustomBrainAudioDecoder: Train/Test ratio: 0.80/0.20
# CustomBrainAudioDecoder:
# Participants by strata:
# CustomBrainAudioDecoder:   medium_quality: 796 train, 199 test
# CustomBrainAudioDecoder:     Train proportion: 1.00
# CustomBrainAudioDecoder:     Test proportion: 1.00
# UnifiedPhonemePipeline: Step 3: Train/test split created
# AcousticChangeDetector: Initialized with DEBUG_MODE=True
# AcousticChangeDetector: Using feature extraction method: high_gamma
# UnifiedPhonemePipeline: Setting up acoustic change detector with method: high_gamma
# UnifiedPhonemePipeline [DEBUG]: Step 4: Detector initialized
# UnifiedPhonemePipeline [DEBUG]: Accumulating training data...
# AcousticChangeDetector: Accumulating train data from 5 batches...
# AcousticChangeDetector: Processing batch 1/5
# AcousticChangeDetector [DEBUG]: Processing batch with 32 instances
# AcousticChangeDetector [DEBUG]: Original batch keys: ['eeg_segments', 'audio_segments', 'words', 'participant_ids', 'metadata', 'spectrogram_segments']
# AcousticChangeDetector [DEBUG]: EEG segments in batch: True
# AcousticChangeDetector [DEBUG]: Spectrogram segments in batch: True
# AcousticChangeDetector [DEBUG]: Processing instance 0/32: dakker
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3078, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: dakker
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'dakker'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'dakker': 5 phonemes but 4 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3071, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: zou
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'zou'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: verstijfde
# AcousticChangeDetector [DEBUG]: Estimated 9 phonemes for 'verstijfde'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'verstijfde': 9 phonemes but 8 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 115)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: braadde
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'braadde'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 60)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: komt
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'komt'
# AcousticChangeDetector [DEBUG]: No transcription for word 'komt'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3080, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: zei
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'zei'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: bakker
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'bakker'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'bakker': 5 phonemes but 4 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: redetwisten
# AcousticChangeDetector [DEBUG]: Estimated 9 phonemes for 'redetwisten'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'redetwisten': 11 phonemes but 8 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3078, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: tussen
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'tussen'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3078, 122)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 11
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for '11'
# AcousticChangeDetector [DEBUG]: Processing instance 10/32: helft
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3072, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: helft
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'helft'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 60)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hierop
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'hierop'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: stiekem
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'stiekem'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'stiekem': 6 phonemes but 5 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3078, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: braadde
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'braadde'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: vloog
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'vloog'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3077, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: werd
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'werd'
# AcousticChangeDetector [DEBUG]: No transcription for word 'werd'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3072, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wegpakte
# AcousticChangeDetector [DEBUG]: Estimated 8 phonemes for 'wegpakte'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wak
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'wak'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3077, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: zich
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'zich'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'zich': 2 phonemes but 3 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 10
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for '10'
# AcousticChangeDetector [DEBUG]: Processing instance 20/32: hem
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hem
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'hem'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 60)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: kin
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'kin'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: bevrijd
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'bevrijd'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: aan
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'aan'
# AcousticChangeDetector [DEBUG]: No transcription for word 'aan'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wel
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'wel'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3080, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: was
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'was'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hoe
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'hoe'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 8
# AcousticChangeDetector [DEBUG]: Estimated 1 phonemes for '8'
# AcousticChangeDetector [DEBUG]: No transcription for word '8'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: groen
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'groen'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 115)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: maantje
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'maantje'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'maantje': 6 phonemes but 5 segments
# AcousticChangeDetector [DEBUG]: Processing instance 30/32: vogelkooitje
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: vogelkooitje
# AcousticChangeDetector [DEBUG]: Estimated 11 phonemes for 'vogelkooitje'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'vogelkooitje': 12 phonemes but 10 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3081, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: juist
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'juist'
# AcousticChangeDetector [DEBUG]: Enhanced batch contains 140 phoneme segments
# AcousticChangeDetector [DEBUG]: Found 34 unique phonemes
# AcousticChangeDetector [DEBUG]: Preparing phoneme training data with PCA components=50
# AcousticChangeDetector [DEBUG]: Successfully imported extractHG function
# AcousticChangeDetector [DEBUG]: Found 32 valid phoneme segments out of 32
# AcousticChangeDetector [DEBUG]: Processing segment 0 with shape (3078, 127)
# AcousticChangeDetector: Error processing segment 0: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 1 with shape (3071, 127)
# AcousticChangeDetector: Error processing segment 1: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 2 with shape (3075, 127)
# AcousticChangeDetector: Error processing segment 2: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 3 with shape (3079, 115)
# AcousticChangeDetector: Error processing segment 3: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 4 with shape (3075, 60)
# AcousticChangeDetector: Error processing segment 4: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 5 with shape (3080, 127)
# AcousticChangeDetector: Error processing segment 5: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 6 with shape (3079, 127)
# AcousticChangeDetector: Error processing segment 6: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 7 with shape (3079, 54)
# AcousticChangeDetector: Error processing segment 7: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 8 with shape (3078, 117)
# AcousticChangeDetector: Error processing segment 8: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 9 with shape (3078, 122)
# AcousticChangeDetector: Error processing segment 9: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 10 with shape (3072, 127)
# AcousticChangeDetector: Error processing segment 10: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 11 with shape (3076, 60)
# AcousticChangeDetector: Error processing segment 11: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 12 with shape (3079, 127)
# AcousticChangeDetector: Error processing segment 12: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 13 with shape (3078, 127)
# AcousticChangeDetector: Error processing segment 13: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 14 with shape (3076, 127)
# AcousticChangeDetector: Error processing segment 14: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 15 with shape (3077, 127)
# AcousticChangeDetector: Error processing segment 15: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 16 with shape (3072, 127)
# AcousticChangeDetector: Error processing segment 16: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 17 with shape (3075, 127)
# AcousticChangeDetector: Error processing segment 17: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 18 with shape (3077, 54)
# AcousticChangeDetector: Error processing segment 18: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 19 with shape (3073, 117)
# AcousticChangeDetector: Error processing segment 19: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 20 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 20: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 21 with shape (3076, 60)
# AcousticChangeDetector: Error processing segment 21: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 22 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 22: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 23 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 23: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 24 with shape (3076, 54)
# AcousticChangeDetector: Error processing segment 24: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 25 with shape (3080, 127)
# AcousticChangeDetector: Error processing segment 25: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 26 with shape (3073, 127)
# AcousticChangeDetector: Error processing segment 26: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 27 with shape (3075, 127)
# AcousticChangeDetector: Error processing segment 27: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 28 with shape (3076, 127)
# AcousticChangeDetector: Error processing segment 28: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 29 with shape (3074, 115)
# AcousticChangeDetector: Error processing segment 29: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 30 with shape (3075, 127)
# AcousticChangeDetector: Error processing segment 30: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 31 with shape (3081, 127)
# AcousticChangeDetector: Error processing segment 31: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processed 0 segments successfully
# AcousticChangeDetector [DEBUG]: Prepared data for 0 phoneme segments
# AcousticChangeDetector [DEBUG]: Found 0 unique phonemes
# AcousticChangeDetector: Accumulated 0 phoneme segments so far
# AcousticChangeDetector: Processing batch 2/5
# AcousticChangeDetector [DEBUG]: Processing batch with 32 instances
# AcousticChangeDetector [DEBUG]: Original batch keys: ['eeg_segments', 'audio_segments', 'words', 'participant_ids', 'metadata', 'spectrogram_segments']
# AcousticChangeDetector [DEBUG]: EEG segments in batch: True
# AcousticChangeDetector [DEBUG]: Spectrogram segments in batch: True
# AcousticChangeDetector [DEBUG]: Processing instance 0/32: 5
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 5
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for '5'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3078, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: dauwdruppel
# AcousticChangeDetector [DEBUG]: Estimated 8 phonemes for 'dauwdruppel'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'dauwdruppel': 9 phonemes but 8 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3077, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: aan
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'aan'
# AcousticChangeDetector [DEBUG]: No transcription for word 'aan'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 115)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: braadde
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'braadde'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 60)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: komt
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'komt'
# AcousticChangeDetector [DEBUG]: No transcription for word 'komt'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: vloog
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'vloog'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3078, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: de
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'de'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: komt
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'komt'
# AcousticChangeDetector [DEBUG]: No transcription for word 'komt'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wat
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'wat'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 122)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: kin
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'kin'
# AcousticChangeDetector [DEBUG]: Processing instance 10/32: helft
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 115)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: helft
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'helft'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 60)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hierop
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'hierop'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: stiekem
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'stiekem'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'stiekem': 6 phonemes but 5 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: braadde
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'braadde'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: vloog
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'vloog'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: werd
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'werd'
# AcousticChangeDetector [DEBUG]: No transcription for word 'werd'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 60)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wegpakte
# AcousticChangeDetector [DEBUG]: Estimated 8 phonemes for 'wegpakte'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3077, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wak
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'wak'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: zich
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'zich'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'zich': 2 phonemes but 3 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3072, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 10
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for '10'
# AcousticChangeDetector [DEBUG]: Processing instance 20/32: hem
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 60)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hem
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'hem'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: kin
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'kin'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: bevrijd
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'bevrijd'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: aan
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'aan'
# AcousticChangeDetector [DEBUG]: No transcription for word 'aan'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wel
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'wel'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3080, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: was
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'was'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3071, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hoe
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'hoe'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 8
# AcousticChangeDetector [DEBUG]: Estimated 1 phonemes for '8'
# AcousticChangeDetector [DEBUG]: No transcription for word '8'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: groen
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'groen'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: maantje
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'maantje'
# AcousticChangeDetector [DEBUG]: Processing instance 30/32: vogelkooitje
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: vogelkooitje
# AcousticChangeDetector [DEBUG]: Estimated 11 phonemes for 'vogelkooitje'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'vogelkooitje': 12 phonemes but 11 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3080, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: juist
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'juist'
# AcousticChangeDetector [DEBUG]: Enhanced batch contains 133 phoneme segments
# AcousticChangeDetector [DEBUG]: Found 32 unique phonemes
# AcousticChangeDetector [DEBUG]: Preparing phoneme training data with PCA components=50
# AcousticChangeDetector [DEBUG]: Successfully imported extractHG function
# AcousticChangeDetector [DEBUG]: Found 32 valid phoneme segments out of 32
# AcousticChangeDetector [DEBUG]: Processing segment 0 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 0: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 1 with shape (3078, 127)
# AcousticChangeDetector: Error processing segment 1: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 2 with shape (3077, 127)
# AcousticChangeDetector: Error processing segment 2: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 3 with shape (3079, 115)
# AcousticChangeDetector: Error processing segment 3: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 4 with shape (3075, 60)
# AcousticChangeDetector: Error processing segment 4: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 5 with shape (3073, 127)
# AcousticChangeDetector: Error processing segment 5: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 6 with shape (3078, 127)
# AcousticChangeDetector: Error processing segment 6: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 7 with shape (3074, 54)
# AcousticChangeDetector: Error processing segment 7: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 8 with shape (3075, 117)
# AcousticChangeDetector: Error processing segment 8: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 9 with shape (3079, 122)
# AcousticChangeDetector: Error processing segment 9: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 10 with shape (3076, 115)
# AcousticChangeDetector: Error processing segment 10: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 11 with shape (3076, 60)
# AcousticChangeDetector: Error processing segment 11: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 12 with shape (3079, 127)
# AcousticChangeDetector: Error processing segment 12: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 13 with shape (3076, 127)
# AcousticChangeDetector: Error processing segment 13: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 14 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 14: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 15 with shape (3075, 117)
# AcousticChangeDetector: Error processing segment 15: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 16 with shape (3075, 60)
# AcousticChangeDetector: Error processing segment 16: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 17 with shape (3077, 127)
# AcousticChangeDetector: Error processing segment 17: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 18 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 18: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 19 with shape (3072, 54)
# AcousticChangeDetector: Error processing segment 19: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 20 with shape (3076, 60)
# AcousticChangeDetector: Error processing segment 20: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 21 with shape (3073, 117)
# AcousticChangeDetector: Error processing segment 21: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 22 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 22: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 23 with shape (3075, 117)
# AcousticChangeDetector: Error processing segment 23: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 24 with shape (3076, 54)
# AcousticChangeDetector: Error processing segment 24: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 25 with shape (3080, 127)
# ...
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: niet
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'niet'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 7
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for '7'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: bakker
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'bakker'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 115)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: dan
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'dan'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 60)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: mooie
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'mooie'
# AcousticChangeDetector [DEBUG]: No transcription for word 'mooie'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: `s
# AcousticChangeDetector [DEBUG]: Estimated 1 phonemes for '`s'
# AcousticChangeDetector [DEBUG]: Mismatch for word '`s': 1 phonemes but 7 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: waren
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'waren'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'waren': 5 phonemes but 4 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3078, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: maantje
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'maantje'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: werd
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'werd'
# AcousticChangeDetector [DEBUG]: No transcription for word 'werd'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3078, 122)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: geen
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'geen'
# AcousticChangeDetector [DEBUG]: Processing instance 10/32: helft
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: helft
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'helft'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 115)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hierop
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'hierop'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: stiekem
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'stiekem'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'stiekem': 6 phonemes but 5 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3079, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: braadde
# AcousticChangeDetector [DEBUG]: Estimated 5 phonemes for 'braadde'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: vloog
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'vloog'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 115)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: werd
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'werd'
# AcousticChangeDetector [DEBUG]: No transcription for word 'werd'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3072, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wegpakte
# AcousticChangeDetector [DEBUG]: Estimated 8 phonemes for 'wegpakte'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3077, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wak
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'wak'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: zich
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'zich'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'zich': 2 phonemes but 3 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3075, 115)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 10
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for '10'
# AcousticChangeDetector [DEBUG]: Processing instance 20/32: hem
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hem
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'hem'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3077, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: kin
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'kin'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3080, 54)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: bevrijd
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'bevrijd'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3077, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: aan
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'aan'
# AcousticChangeDetector [DEBUG]: No transcription for word 'aan'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3076, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: wel
# AcousticChangeDetector [DEBUG]: Estimated 3 phonemes for 'wel'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3080, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: was
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'was'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3071, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: hoe
# AcousticChangeDetector [DEBUG]: Estimated 2 phonemes for 'hoe'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3077, 117)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: 8
# AcousticChangeDetector [DEBUG]: Estimated 1 phonemes for '8'
# AcousticChangeDetector [DEBUG]: No transcription for word '8'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: groen
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'groen'
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3074, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: maantje
# AcousticChangeDetector [DEBUG]: Estimated 6 phonemes for 'maantje'
# AcousticChangeDetector [DEBUG]: Processing instance 30/32: vogelkooitje
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3073, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: vogelkooitje
# AcousticChangeDetector [DEBUG]: Estimated 11 phonemes for 'vogelkooitje'
# AcousticChangeDetector [DEBUG]: Mismatch for word 'vogelkooitje': 12 phonemes but 11 segments
# AcousticChangeDetector [DEBUG]: Added EEG segment with shape (3081, 127)
# AcousticChangeDetector [DEBUG]: Detecting boundaries for word: juist
# AcousticChangeDetector [DEBUG]: Estimated 4 phonemes for 'juist'
# AcousticChangeDetector [DEBUG]: Enhanced batch contains 138 phoneme segments
# AcousticChangeDetector [DEBUG]: Found 34 unique phonemes
# AcousticChangeDetector [DEBUG]: Preparing phoneme training data with PCA components=50
# AcousticChangeDetector [DEBUG]: Successfully imported extractHG function
# AcousticChangeDetector [DEBUG]: Found 32 valid phoneme segments out of 32
# AcousticChangeDetector [DEBUG]: Processing segment 0 with shape (3073, 127)
# AcousticChangeDetector: Error processing segment 0: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 1 with shape (3076, 127)
# AcousticChangeDetector: Error processing segment 1: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 2 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 2: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 3 with shape (3075, 115)
# AcousticChangeDetector: Error processing segment 3: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 4 with shape (3076, 60)
# AcousticChangeDetector: Error processing segment 4: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 5 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 5: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 6 with shape (3076, 127)
# AcousticChangeDetector: Error processing segment 6: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 7 with shape (3078, 54)
# AcousticChangeDetector: Error processing segment 7: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 8 with shape (3075, 117)
# AcousticChangeDetector: Error processing segment 8: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 9 with shape (3078, 122)
# AcousticChangeDetector: Error processing segment 9: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 10 with shape (3076, 127)
# AcousticChangeDetector: Error processing segment 10: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 11 with shape (3073, 115)
# AcousticChangeDetector: Error processing segment 11: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 12 with shape (3079, 127)
# AcousticChangeDetector: Error processing segment 12: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 13 with shape (3079, 54)
# AcousticChangeDetector: Error processing segment 13: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 14 with shape (3073, 54)
# AcousticChangeDetector: Error processing segment 14: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 15 with shape (3075, 115)
# AcousticChangeDetector: Error processing segment 15: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 16 with shape (3072, 127)
# AcousticChangeDetector: Error processing segment 16: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 17 with shape (3077, 127)
# AcousticChangeDetector: Error processing segment 17: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 18 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 18: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 19 with shape (3075, 115)
# AcousticChangeDetector: Error processing segment 19: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 20 with shape (3076, 117)
# AcousticChangeDetector: Error processing segment 20: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 21 with shape (3077, 127)
# AcousticChangeDetector: Error processing segment 21: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 22 with shape (3080, 54)
# AcousticChangeDetector: Error processing segment 22: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 23 with shape (3077, 127)
# AcousticChangeDetector: Error processing segment 23: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 24 with shape (3076, 117)
# AcousticChangeDetector: Error processing segment 24: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 25 with shape (3080, 127)
# AcousticChangeDetector: Error processing segment 25: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 26 with shape (3071, 127)
# AcousticChangeDetector: Error processing segment 26: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 27 with shape (3077, 117)
# AcousticChangeDetector: Error processing segment 27: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 28 with shape (3073, 127)
# AcousticChangeDetector: Error processing segment 28: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 29 with shape (3074, 127)
# AcousticChangeDetector: Error processing segment 29: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 30 with shape (3073, 127)
# AcousticChangeDetector: Error processing segment 30: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processing segment 31 with shape (3081, 127)
# AcousticChangeDetector: Error processing segment 31: name 'eeg' is not defined
# AcousticChangeDetector [DEBUG]: Processed 0 segments successfully
# AcousticChangeDetector [DEBUG]: Prepared data for 0 phoneme segments
# AcousticChangeDetector [DEBUG]: Found 0 unique phonemes
# AcousticChangeDetector: Accumulated 0 phoneme segments so far
# AcousticChangeDetector: Accumulated data from 5 batches:
# AcousticChangeDetector: Total phoneme segments: 0
# AcousticChangeDetector: Unique phonemes: 0
# UnifiedPhonemePipeline: ERROR: Training data accumulation failed - empty or missing features
# PhonemeValidator: Initialized with DEBUG_MODE=False
# PhonemeValidator: Debug mode enabled
# UnifiedPhonemePipeline: ✓ Step 6: Validator initialized
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 20
#      19 print("Re-processing data with updated PCA components...")
# ---> 20 pipeline.step4_initialize_detector()
#      21 pipeline.step5_accumulate_data()
#
# File D:\Documents\UM DACS\bachelor\UM DACS\bachelor\mozg\code\SingleWordProductionDutch\pipeline.py:209, in UnifiedPhonemePipeline.step4_initialize_detector(self)
#     201 """Step 4: Initialize detector with PCA configuration"""
#     203 self.detector = AcousticChangeDetector(
#     204     min_segment_duration=0.03,
#     205     max_segment_duration=0.3,
#     206     distance_metric='cosine',
#     207     smoothing_window=3,
#     208     peak_threshold=0.5,
# --> 209     decoder=self.custom_decoder,  # Passing the decoder with PCA config
#     210     feature_extraction_method=self.feature_extraction_method,
#     211     phonetic_dict=self.phonetic_dict if hasattr(self, 'phonetic_dict') else None,
#     212     debug_mode=self.DEBUG_MODE
#     213 )
#     215 self.log(f"Setting up acoustic change detector with method: {self.feature_extraction_method}")
#
# AttributeError: 'UnifiedPhonemePipeline' object has no attribute 'custom_decoder'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 53
#      51 pipeline.step4_initialize_detector()
#      52 pipeline.step5_accumulate_data()
# ---> 53 pipeline.step6_resolve_unknowns()
#      54 pipeline.step7_filter_unknowns()
#      56 # Save the pipeline
#
# File D:\Documents\UM DACS\bachelor\UM DACS\bachelor\mozg\code\SingleWordProductionDutch\pipeline.py:327, in UnifiedPhonemePipeline.step6_resolve_unknowns(self)
#     324     self.debug(f"Training after resolution: {self.train['phoneme_labels'].count('?')} unknown phonemes")
#     326 # Resolve test data
# --> 327 if self.test['phoneme_labels'].count('?') > 0:
#     328     self.debug(f"Resolving {self.test['phoneme_labels'].count('?')} unknown phonemes in test...")
#     330     test_converted = {
#     331         'phoneme_labels': self.test['phoneme_labels'],
#     332         'phoneme_spectrogram_segments': self.test.get('spectrograms', []),
#    (...)
#     335         'phoneme_participant_ids': self.test.get('phoneme_participant_ids', ['unknown'] * len(self.test['phoneme_labels']))
#     336     }
#
# AttributeError: 'UnifiedPhonemePipeline' object has no attribute 'test'

# %%
phonetic_dict = PhoneticDictionary()
# Get FILTERED data (this is what you feed to the Markov model):
train_data = pipeline.get_training_data(filtered=True)  # or pipeline.train_filtered
# Out:
# PhoneticDictionary: Initialized with DEBUG_MODE=False

# %%
# visualizer.process_batches(train_data, method='high_gamma', band=(70, 150))

# %%
# # You could also visualize other frequency bands
# visualizer.process_batches(train_data, method='theta', band=(4, 8))
# visualizer.process_batches(train_data, method='alpha', band=(8, 13))
# visualizer.process_batches(train_data, method='beta', band=(13, 30))
