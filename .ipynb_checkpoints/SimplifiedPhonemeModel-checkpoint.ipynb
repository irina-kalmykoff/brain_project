# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Audio, display
from pynwb import NWBHDF5IO

import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, IntSlider, FloatSlider, Dropdown, Checkbox

from brain_audio_decoder import BrainAudioDecoder
from custom_decoder import CustomBrainAudioDecoder
from brain_audio_decoder_viz import BrainAudioDecoderViz
from acoustic_change_detector import AcousticChangeDetector
from phoneme_validator import PhonemeValidator
from simplified_phoneme_model import SimplifiedPhonemeModel
from pipeline import UnifiedPhonemePipeline

# %%
# Define paths
path_bids = './SingleWordProductionDutch-iBIDS'  # Path to the BIDS dataset
path_output = './features'  # Path to save extracted features
path_results = './results'  # Path to save results

# %%
# Pipeline creation with PCA components management
use_augmentation = True
feature_extraction_method = 'multi_band' #'high_gamma'  #
optimal_pca_components = 30  # Use your optimal value determined earlier

# Try to load existing pipeline, otherwise create new one
try:
    # Try loading existing pipeline
    pipeline = UnifiedPhonemePipeline.load_saved(path_results, method=feature_extraction_method)
    print(f"Loaded existing {feature_extraction_method} pipeline")
    
    # Check and update PCA components if needed
    current_pca = getattr(pipeline, 'pca_components', None)
    if current_pca != optimal_pca_components:
        print(f"Updating PCA components from {current_pca} to {optimal_pca_components}")
        pipeline.set_pca_components(optimal_pca_components)
        
        # Re-run data steps with new PCA components
        print("Re-processing data with updated PCA components...")
        pipeline.step4_initialize_detector()    
        pipeline.step5_accumulate_data()
        pipeline.step6_resolve_unknowns()
        pipeline.step7_filter_unknowns()
        
        # Save the updated pipeline
        pipeline.save()
        print(f"Updated and saved {feature_extraction_method} pipeline with {optimal_pca_components} PCA components")
    
except (FileNotFoundError, AttributeError, TypeError) as e:
    # No existing pipeline found, create new one
    print(f"No existing {feature_extraction_method} pipeline found. Creating new one...")
    
    pipeline = UnifiedPhonemePipeline(
        path_bids=path_bids,
        path_output=path_output,
        path_results=path_results,
        feature_extraction_method=feature_extraction_method,
        unknown_keep_ratio=0.1,
        channel_correlation_threshold=0.3,  # ADD THIS
        prioritize_regions=True,  # ADD THIS
        channel_selection='best_correlation',
        pca_components=optimal_pca_components,  # Set optimal PCA components
        debug_mode=False
    )
    
    # Run all steps
    print("Running pipeline steps...")
    pipeline.step1_initialize_decoder()
    pipeline.step2_stratify_participants()    
    pipeline.step3_create_split()
    pipeline.step4_initialize_detector()    
    pipeline.step5_accumulate_data()
    pipeline.step6_resolve_unknowns()
    pipeline.step7_filter_unknowns()
    
    # Save the pipeline
    pipeline.save()
    print(f"Created and saved new {feature_extraction_method} pipeline with {optimal_pca_components} PCA components")

# The pipeline is now ready to use with optimal PCA components
print(f"Pipeline ready with {feature_extraction_method} features and {optimal_pca_components} PCA components")
# Out:
# No matching pipelines found for method=multi_band, pca_components=None
# No existing multi_band pipeline found. Creating new one...
# PhoneticDictionary: Initialized with DEBUG_MODE=False
# UnifiedPhonemePipeline: Pipeline initialized: multi_band, PCA=30, groups=True
# Running pipeline steps...
# CustomBrainAudioDecoder: Initializing CustomBrainAudioDecoder with debug_mode=False
# Step 1: Decoder initialized with PCA components=30
# CustomBrainAudioDecoder:
# Participant stratification results:
# CustomBrainAudioDecoder:   Participants with most relevant channels: 3
# CustomBrainAudioDecoder:   Participants with relevant channels: 4
# CustomBrainAudioDecoder:   Participants with least relevant channels: 3
# CustomBrainAudioDecoder:
# Top participants by channel quality:
# UnifiedPhonemePipeline: Filtered to 0 participants with good coverage
# CustomBrainAudioDecoder: Segmenting data for sub-01...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'helft': 1 instances
# CustomBrainAudioDecoder:     2. 'hierop': 1 instances
# CustomBrainAudioDecoder:     3. 'stiekem': 1 instances
# CustomBrainAudioDecoder:     4. 'en': 1 instances
# CustomBrainAudioDecoder:     5. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3074, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-02...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'ook': 1 instances
# CustomBrainAudioDecoder:     2. 'als': 1 instances
# CustomBrainAudioDecoder:     3. 'noordenwind': 1 instances
# CustomBrainAudioDecoder:     4. 'vak': 1 instances
# CustomBrainAudioDecoder:     5. 'over': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-03...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'buurt': 1 instances
# CustomBrainAudioDecoder:     2. 'meisjes': 1 instances
# CustomBrainAudioDecoder:     3. '7': 1 instances
# CustomBrainAudioDecoder:     4. 'vogeltje': 1 instances
# CustomBrainAudioDecoder:     5. 'betovering': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3079, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-04...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'vogeltje': 1 instances
# CustomBrainAudioDecoder:     2. 'wel': 1 instances
# CustomBrainAudioDecoder:     3. 'mooi': 1 instances
# CustomBrainAudioDecoder:     4. 'daarna': 1 instances
# CustomBrainAudioDecoder:     5. 'kasteel': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3071, 115)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (299, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-05...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'verlost': 1 instances
# CustomBrainAudioDecoder:     2. 'terugvinden': 1 instances
# CustomBrainAudioDecoder:     3. 'er': 1 instances
# CustomBrainAudioDecoder:     4. 'hem': 1 instances
# CustomBrainAudioDecoder:     5. 'tot': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 60)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-06...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'hoe': 1 instances
# CustomBrainAudioDecoder:     2. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:     3. 'en': 1 instances
# CustomBrainAudioDecoder:     4. 'het': 1 instances
# CustomBrainAudioDecoder:     5. 'smeekte': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3076, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-07...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'zanddak': 1 instances
# CustomBrainAudioDecoder:     2. 'als': 1 instances
# CustomBrainAudioDecoder:     3. 'terugvinden': 1 instances
# CustomBrainAudioDecoder:     4. 'wegpakte': 1 instances
# CustomBrainAudioDecoder:     5. 'onmiddellijk': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3076, 127)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-08...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'de': 1 instances
# CustomBrainAudioDecoder:     2. 'buurt': 1 instances
# CustomBrainAudioDecoder:     3. 'verstijfde': 1 instances
# CustomBrainAudioDecoder:     4. 'zonlicht': 1 instances
# CustomBrainAudioDecoder:     5. 'zevenduizend': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3075, 54)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-09...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. 'tak': 1 instances
# CustomBrainAudioDecoder:     2. 'veel': 1 instances
# CustomBrainAudioDecoder:     3. 'helemaal': 1 instances
# CustomBrainAudioDecoder:     4. 'van': 1 instances
# CustomBrainAudioDecoder:     5. 'buurt': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3072, 117)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (300, 23)
# CustomBrainAudioDecoder: Segmenting data for sub-10...
# CustomBrainAudioDecoder:
#   Top 5 most frequent words:
# CustomBrainAudioDecoder:     1. '5': 1 instances
# CustomBrainAudioDecoder:     2. 'naar': 1 instances
# CustomBrainAudioDecoder:     3. 'braadde': 1 instances
# CustomBrainAudioDecoder:     4. 'zo': 1 instances
# CustomBrainAudioDecoder:     5. 'onmiddellijk': 1 instances
# CustomBrainAudioDecoder:
# Example EEG segment shape: (3068, 122)
# CustomBrainAudioDecoder: Example spectrogram segment shape: (299, 23)
# CustomBrainAudioDecoder: Total train instances: 796
# CustomBrainAudioDecoder: Total test instances: 199
# CustomBrainAudioDecoder: Train/Test ratio: 0.80/0.20
# CustomBrainAudioDecoder:
# Participants by strata:
# CustomBrainAudioDecoder:   medium_quality: 796 train, 199 test
# CustomBrainAudioDecoder:     Train proportion: 1.00
# CustomBrainAudioDecoder:     Test proportion: 1.00
# UnifiedPhonemePipeline: Step 3: Train/test split created
# AcousticChangeDetector: Initialized with DEBUG_MODE=False
# AcousticChangeDetector: Using feature extraction method: multi_band
# UnifiedPhonemePipeline: Setting up acoustic change detector with method: multi_band
# AcousticChangeDetector: Accumulating train data from 5 batches...
# AcousticChangeDetector: Processing batch 1/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 32 phoneme segments so far
# AcousticChangeDetector: Processing batch 2/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 64 phoneme segments so far
# AcousticChangeDetector: Processing batch 3/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 96 phoneme segments so far
# AcousticChangeDetector: Processing batch 4/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 128 phoneme segments so far
# AcousticChangeDetector: Processing batch 5/5
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 160 phoneme segments so far
# AcousticChangeDetector: Accumulated data from 5 batches:
# AcousticChangeDetector: Total phoneme segments: 160
# AcousticChangeDetector: Unique phonemes: 30
# UnifiedPhonemePipeline: Successfully accumulated 160 training samples
# AcousticChangeDetector: Accumulating test data from 3 batches...
# AcousticChangeDetector: Processing batch 1/3
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 32 phoneme segments so far
# AcousticChangeDetector: Processing batch 2/3
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 64 phoneme segments so far
# AcousticChangeDetector: Processing batch 3/3
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# DEBUG: custom_feature_extraction called with method: multi_band
# AcousticChangeDetector: Accumulated 96 phoneme segments so far
# AcousticChangeDetector: Accumulated data from 3 batches:
# AcousticChangeDetector: Total phoneme segments: 96
# AcousticChangeDetector: Unique phonemes: 30
# UnifiedPhonemePipeline: Successfully accumulated 96 test samples
# PhonemeValidator: Initialized with DEBUG_MODE=False
# PhonemeValidator: Debug mode enabled
# UnifiedPhonemePipeline: ✓ Step 6: Validator initialized
# UnifiedPhonemePipeline: Resolving 84 unknown phonemes in training...
# PhonemeValidator [DEBUG]: Attempting to resolve 84 unknown phonemes
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'dakker' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'dakker' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'dakker' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'dakker' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'verstijfde' as 'v'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'verstijfde' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'verstijfde' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'verstijfde' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'verstijfde' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'verstijfde' as 'ɛi'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'verstijfde' as 'v'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'verstijfde' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'komt' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'komt' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'komt' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'komt' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'bakker' as 'b'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'bakker' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'bakker' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'bakker' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'redetwisten' as 'ˌ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'redetwisten' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'redetwisten' as 'e'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'aan' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'aan' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'aan' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'komt' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'komt' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'komt' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'komt' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'komt' as 'k'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'komt' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'stilstaan' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'stilstaan' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'stilstaan' as 'i'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'stilstaan' as 'l'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'stilstaan' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'stilstaan' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'stilstaan' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'stilstaan' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 8 in 'stilstaan' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'nachtegalen' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'nachtegalen' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'nachtegalen' as 'x'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'nachtegalen' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'nachtegalen' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'nachtegalen' as 'ˌ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'nachtegalen' as 'ɣ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'redetwisten' as 'ˌ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'redetwisten' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'redetwisten' as 'e'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'redetwisten' as 'ː'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'redetwisten' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'redetwisten' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'redetwisten' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'redetwisten' as 'ʋ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 8 in 'redetwisten' as 'ɪ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'verstijfde' as 'v'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'verstijfde' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'verstijfde' as 'r'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'verstijfde' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'verstijfde' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'verstijfde' as 'ɛi'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'verstijfde' as 'v'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'verstijfde' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'maantje' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'maantje' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'maantje' as 'ː'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'maantje' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'maantje' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'mooie' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'mooie' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'mooie' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in '`s' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in '`s' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'waren' as 'ʋ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'waren' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'waren' as 'ː'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'waren' as 'r'
# PhonemeValidator [DEBUG]: Resolved 79 out of 84 unknown phonemes
# PhonemeValidator [DEBUG]: Attempting to resolve 28 unknown phonemes
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'boomstammen' as 'b'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'boomstammen' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'boomstammen' as 'o'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'boomstammen' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'boomstammen' as 's'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 5 in 'boomstammen' as 't'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 6 in 'boomstammen' as 'a'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 7 in 'boomstammen' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 8 in 'boomstammen' as 'm'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 9 in 'boomstammen' as 'ə'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 10 in 'boomstammen' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'of' as 'ɔf'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'of' as 'f'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 0 in 'zanddak' as 'z'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 1 in 'zanddak' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 2 in 'zanddak' as 'n'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 3 in 'zanddak' as 'd'
# PhonemeValidator [DEBUG]: Resolved phoneme at position 4 in 'zanddak' as 'ɑ'
# PhonemeValidator [DEBUG]: Resolved 18 out of 28 unknown phonemes
# UnifiedPhonemePipeline: Test after resolution: 10 unknown phonemes
# UnifiedPhonemePipeline: WARNING: There are still 5 unknown phonemes in training and 10 in test.
# UnifiedPhonemePipeline: The pipeline will continue, but some phonemes will be treated as the '?' class.
# UnifiedPhonemePipeline: Filtered training: 155 samples (from 160)
# UnifiedPhonemePipeline: Saved: pipeline_multi_band_pca30_20250820_201341.pkl
# UnifiedPhonemePipeline: Method: multi_band, PCA: 30
# UnifiedPhonemePipeline: Train: 160 samples, Test: 96 samples
# Created and saved new multi_band pipeline with 30 PCA components
# Pipeline ready with multi_band features and 30 PCA components

# %%
from phonetic_dictionary import PhoneticDictionary
phonetic_dict = PhoneticDictionary()
# Out:
# PhoneticDictionary: Initialized with DEBUG_MODE=False

# %%
# Get FILTERED data (this is what you feed to the Markov model):
train_data = pipeline.get_training_data(filtered=True)  # or pipeline.train_filtered

# Extract all components:
filtered_features = train_data['features']
filtered_labels = train_data['phoneme_labels']
filtered_words = train_data['phoneme_words']
filtered_participants = train_data['phoneme_participant_ids']

test_features = pipeline.test['features']
test_labels = pipeline.test['phoneme_labels']

# %%
# Create a minimal version that doesn't try to reinvent your pipeline
simplified_model = SimplifiedPhonemeModel(
        phonetic_dict=phonetic_dict,
        output_dir=os.path.join(path_results, 'simplified_phoneme_model'),
        debug_mode=True
    )
# Out:
# SimplifiedPhonemeModel: Initialized with DEBUG_MODE=True
# SimplifiedPhonemeModel: Initialized SimplifiedPhonemeModel with 11 phoneme groups
# SimplifiedPhonemeModel [DEBUG]: Phoneme groups: {'alveolar plosive': ['t', 'd'], 'alveolar fricative': ['s', 'z'], 'alveolar other': ['n', 'l'], 'back vowels close': ['u'], 'back vowels mid': ['ɑu', 'œy', 'o', 'ɔ', 'ə'], 'back vowels open': ['a', 'ɑ', 'œy'], 'dorsal': ['k', 'g', 'x', 'ɣ', 'ŋ', 'χ', 'ʁ'], 'front_vowels': ['i', 'ɪ', 'e', 'ɛ', 'ɛi', 'y', 'ʏ'], 'labial': ['p', 'b', 'f', 'v', 'm'], 'palatal': ['ŋ', 'j', 'r', 'tʃ', 'dʒ', 'tɕ', 'dʑ'], 'glottal': ['h', 'ɦ', 'ʔ']}

# %%
# Get FILTERED training data (this is important)
train_data = pipeline.get_training_data(filtered=True)
test_data = pipeline.get_test_data()
train_participant_ids = train_data.get('phoneme_participant_ids', None)
test_participant_ids = test_data.get('phoneme_participant_ids', None)

# First, check if the pipeline has completed the necessary steps
if not hasattr(pipeline, 'phonetic_dict'):
    # The phonetic dict might be in the detector
    if hasattr(pipeline, 'detector') and hasattr(pipeline.detector, 'phonetic_dict'):
        pipeline.phonetic_dict = pipeline.detector.phonetic_dict
    else:
        # Need to initialize it manually
        from phonetic_dictionary import PhoneticDictionary
        pipeline.phonetic_dict = PhoneticDictionary()

# Check if we have data after filtering
if not train_data or 'phoneme_labels' not in train_data or not train_data['phoneme_labels']:
    print("Warning: No data in filtered training set. Using unfiltered data instead.")
    # Fall back to unfiltered data
    train_data = pipeline.get_training_data(filtered=False)

# Map individual phonemes to phoneme groups
train_group_labels = []
for phoneme in train_data['phoneme_labels']:
    # Try to find the phoneme in the phoneme_to_group mapping
    if phoneme in simplified_model.phoneme_to_group:
        group = simplified_model.phoneme_to_group[phoneme]
    else:
        # If not directly mapped, search in the phoneme groups
        group = 'unknown'
        for group_name, phonemes in simplified_model.phoneme_groups.items():
            if phoneme in phonemes:
                group = group_name
                break
    train_group_labels.append(group)

# %%
# Do the same for test data
test_group_labels = []
for phoneme in test_data['phoneme_labels']:
    if phoneme in simplified_model.phoneme_to_group:
        group = simplified_model.phoneme_to_group[phoneme]
    else:
        group = 'unknown'
        for group_name, phonemes in simplified_model.phoneme_groups.items():
            if phoneme in phonemes:
                group = group_name
                break
    test_group_labels.append(group)

# Print the group distribution after mapping
from collections import Counter
group_counts = Counter(train_group_labels)
print("Phoneme group distribution after mapping:")
for group, count in group_counts.most_common():
    print(f"  {group}: {count}")

# Before training, check if we have enough data for each group
# If not, we might need to lower the min_occurrences
min_count = min(group_counts.values()) if group_counts else 0
recommended_min_occurrences = max(1, min(3, min_count))  # Between 1 and 3, but not more than min_count

print(f"Recommended min_occurrences: {recommended_min_occurrences}")
# Out:
# Phoneme group distribution after mapping:
#   alveolar plosive: 22
#   labial: 21
#   back vowels mid: 20
#   back vowels open: 17
#   alveolar other: 15
#   alveolar fricative: 12
#   front_vowels: 12
#   unknown: 11
#   palatal: 10
#   dorsal: 9
#   marker: 4
#   glottal: 2
# Recommended min_occurrences: 2

# %%
# 6. Train using your phoneme groups
results = simplified_model.train_with_grouped_data(
        train_features=train_data['features'],
        train_group_labels=train_group_labels,
        train_participant_ids=train_participant_ids,
        test_features=test_features,
        test_group_labels=test_group_labels,
        min_occurrences=recommended_min_occurrences,  # Use the recommended value
        test_participant_ids=test_participant_ids,
        epochs=50,
        batch_size=32,
        patience=10
    )
# Out:
# SimplifiedPhonemeModel: Training model with pre-processed phoneme group data
# SimplifiedPhonemeModel: Phoneme group distribution before filtering:
# SimplifiedPhonemeModel:   alveolar plosive: 22
# SimplifiedPhonemeModel:   labial: 21
# SimplifiedPhonemeModel:   back vowels mid: 20
# SimplifiedPhonemeModel:   back vowels open: 17
# SimplifiedPhonemeModel:   alveolar other: 15
# SimplifiedPhonemeModel:   alveolar fricative: 12
# SimplifiedPhonemeModel:   front_vowels: 12
# SimplifiedPhonemeModel:   unknown: 11
# SimplifiedPhonemeModel:   palatal: 10
# SimplifiedPhonemeModel:   dorsal: 9
# SimplifiedPhonemeModel:   marker: 4
# SimplifiedPhonemeModel:   glottal: 2
# SimplifiedPhonemeModel: Training with 151 samples (filtered from 155)
# SimplifiedPhonemeModel: Skipped 4 samples with rare or unrecognized group labels
# SimplifiedPhonemeModel: Phoneme group distribution after filtering:
# SimplifiedPhonemeModel:   alveolar plosive: 22
# SimplifiedPhonemeModel:   labial: 21
# SimplifiedPhonemeModel:   back vowels mid: 20
# SimplifiedPhonemeModel:   back vowels open: 17
# SimplifiedPhonemeModel:   alveolar other: 15
# SimplifiedPhonemeModel:   alveolar fricative: 12
# SimplifiedPhonemeModel:   front_vowels: 12
# SimplifiedPhonemeModel:   unknown: 11
# SimplifiedPhonemeModel:   palatal: 10
# SimplifiedPhonemeModel:   dorsal: 9
# SimplifiedPhonemeModel:   glottal: 2
# SimplifiedPhonemeModel: Testing with 96 samples (filtered from 96)
# SimplifiedPhonemeModel: Standardizing feature lengths...
# SimplifiedPhonemeModel: Input shape: (296, 30)
# SimplifiedPhonemeModel: Building model with participant info: True
# SimplifiedPhonemeModel: Building simplified phoneme model
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ eeg_input (InputLayer)        │ (None, 296, 30)           │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 296, 32)           │           4,832 │ eeg_input[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 296, 32)           │             128 │ conv1d[0][0]               │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d (MaxPooling1D)  │ (None, 148, 32)           │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 148, 64)           │          10,304 │ max_pooling1d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 148, 64)           │             256 │ conv1d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_1               │ (None, 74, 64)            │               0 │ batch_normalization_1[0][… │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional (Bidirectional) │ (None, 128)               │          66,048 │ max_pooling1d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128)               │               0 │ bidirectional[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ participant_input             │ (None, 8)                 │               0 │ -                          │
# │ (InputLayer)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64)                │           8,256 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 16)                │             144 │ participant_input[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 64)                │             256 │ dense[0][0]                │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16)                │              64 │ dense_1[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 80)                │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 80)                │               0 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 12)                │             972 │ dropout_1[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 91,260 (356.48 KB)
#  Trainable params: 90,908 (355.11 KB)
#  Non-trainable params: 352 (1.38 KB)
# SimplifiedPhonemeModel: Training model with 151 samples for up to 50 epochs
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 186ms/step - accuracy: 0.0659 - loss: 3.7865 - val_accuracy: 0.1042 - val_loss: 2.5216 - learning_rate: 5.0000e-04
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1082 - loss: 3.2103 - val_accuracy: 0.1042 - val_loss: 2.5140 - learning_rate: 5.0000e-04
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0929 - loss: 3.3277 - val_accuracy: 0.1042 - val_loss: 2.5121 - learning_rate: 5.0000e-04
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1433 - loss: 3.2443 - val_accuracy: 0.1354 - val_loss: 2.5110 - learning_rate: 5.0000e-04
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2051 - loss: 3.1028 - val_accuracy: 0.1354 - val_loss: 2.5118 - learning_rate: 5.0000e-04
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1572 - loss: 3.1000 - val_accuracy: 0.1146 - val_loss: 2.5105 - learning_rate: 5.0000e-04
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1676 - loss: 2.9937 - val_accuracy: 0.1042 - val_loss: 2.5083 - learning_rate: 5.0000e-04
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1410 - loss: 3.0548 - val_accuracy: 0.1042 - val_loss: 2.5032 - learning_rate: 5.0000e-04
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1680 - loss: 3.0623 - val_accuracy: 0.1354 - val_loss: 2.4836 - learning_rate: 5.0000e-04
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2046 - loss: 2.9131 - val_accuracy: 0.1042 - val_loss: 2.4675 - learning_rate: 5.0000e-04
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2029 - loss: 2.5741 - val_accuracy: 0.0729 - val_loss: 2.4613 - learning_rate: 5.0000e-04
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2292 - loss: 2.6170 - val_accuracy: 0.0625 - val_loss: 2.4577 - learning_rate: 5.0000e-04
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2301 - loss: 2.4952 - val_accuracy: 0.0625 - val_loss: 2.4594 - learning_rate: 5.0000e-04
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2051 - loss: 2.4962 - val_accuracy: 0.0625 - val_loss: 2.4653 - learning_rate: 5.0000e-04
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2636 - loss: 2.2649 - val_accuracy: 0.0625 - val_loss: 2.4738 - learning_rate: 5.0000e-04
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2754 - loss: 2.3521 - val_accuracy: 0.0938 - val_loss: 2.4778 - learning_rate: 5.0000e-04
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3747 - loss: 2.2206 - val_accuracy: 0.1146 - val_loss: 2.4684 - learning_rate: 5.0000e-04
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3108 - loss: 2.1919 - val_accuracy: 0.1042 - val_loss: 2.4613 - learning_rate: 2.5000e-04
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2740 - loss: 2.3066 - val_accuracy: 0.1354 - val_loss: 2.4541 - learning_rate: 2.5000e-04
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2935 - loss: 2.2159 - val_accuracy: 0.1354 - val_loss: 2.4524 - learning_rate: 2.5000e-04
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3279 - loss: 2.1281 - val_accuracy: 0.1250 - val_loss: 2.4575 - learning_rate: 2.5000e-04
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2978 - loss: 2.1001 - val_accuracy: 0.1250 - val_loss: 2.4626 - learning_rate: 2.5000e-04
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4493 - loss: 1.8474 - val_accuracy: 0.1146 - val_loss: 2.4682 - learning_rate: 2.5000e-04
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3414 - loss: 2.0284 - val_accuracy: 0.1146 - val_loss: 2.4724 - learning_rate: 2.5000e-04
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3012 - loss: 2.1565 - val_accuracy: 0.1146 - val_loss: 2.4740 - learning_rate: 2.5000e-04
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4174 - loss: 1.8000 - val_accuracy: 0.0938 - val_loss: 2.4758 - learning_rate: 1.2500e-04
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3816 - loss: 2.0953 - val_accuracy: 0.1042 - val_loss: 2.4790 - learning_rate: 1.2500e-04
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3192 - loss: 2.0312 - val_accuracy: 0.0938 - val_loss: 2.4805 - learning_rate: 1.2500e-04
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3387 - loss: 2.2217 - val_accuracy: 0.1042 - val_loss: 2.4808 - learning_rate: 1.2500e-04
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3746 - loss: 1.9327 - val_accuracy: 0.0833 - val_loss: 2.4829 - learning_rate: 1.2500e-04
# SimplifiedPhonemeModel: Model saved to ./results\simplified_phoneme_model\simplified_phoneme_model.keras
# SimplifiedPhonemeModel: Model metadata saved to ./results\simplified_phoneme_model\model_metadata.npz
# SimplifiedPhonemeModel: Training history plot saved to ./results\simplified_phoneme_model\training_history.png
# SimplifiedPhonemeModel: Evaluating model on 96 test samples
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1263 - loss: 2.4392
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 6. Train using your phoneme groups
# ----> 2 results = simplified_model.train_with_grouped_data(
#       3         train_features=train_data['features'],
#       4         train_group_labels=train_group_labels,
#       5         train_participant_ids=train_participant_ids,
#       6         test_features=test_features,
#       7         test_group_labels=test_group_labels,
#       8         min_occurrences=recommended_min_occurrences,  # Use the recommended value
#       9         test_participant_ids=test_participant_ids,
#      10         epochs=50,
#      11         batch_size=32,
#      12         patience=10
#      13     )
#
# File D:\Documents\UM DACS\bachelor\UM DACS\bachelor\mozg\code\SingleWordProductionDutch\simplified_phoneme_model.py:1147, in SimplifiedPhonemeModel.train_with_grouped_data(self, train_features, train_group_labels, train_participant_ids, test_features, test_group_labels, test_participant_ids, include_participant_info, epochs, batch_size, patience, min_occurrences)
#    1144     if test_participants_encoded is not None:
#    1145         test_data['test_participants'] = test_participants_encoded
# -> 1147     evaluation_results = self.evaluate(test_data)
#    1148 else:
#    1149     # Use validation metrics from training
#    1150     evaluation_results = {
#    1151         'accuracy': max(self.history.history['val_accuracy']),
#    1152         'loss': min(self.history.history['val_loss'])
#    1153     }
#
# File D:\Documents\UM DACS\bachelor\UM DACS\bachelor\mozg\code\SingleWordProductionDutch\simplified_phoneme_model.py:470, in SimplifiedPhonemeModel.evaluate(self, prepared_data)
#     467 all_classes = list(self.group_encoder.classes_)
#     469 # Generate classification report
# --> 470 class_report = classification_report(
#     471     true_groups, predicted_groups,
#     472     target_names=all_classes,  # Use the actual classes from the encoder
#     473     output_dict=True
#     474 )
#     476 # Log results
#     477 self.log(f"Test loss: {metrics[0]:.4f}, Test accuracy: {metrics[1]:.4f}")
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:2332, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2326         warnings.warn(
#    2327             "labels size, {0}, does not match size of target_names, {1}".format(
#    2328                 len(labels), len(target_names)
#    2329             )
#    2330         )
#    2331     else:
# -> 2332         raise ValueError(
#    2333             "Number of classes, {0}, does not match size of "
#    2334             "target_names, {1}. Try specifying the labels "
#    2335             "parameter".format(len(labels), len(target_names))
#    2336         )
#    2337 if target_names is None:
#    2338     target_names = ["%s" % l for l in labels]
#
# ValueError: Number of classes, 11, does not match size of target_names, 12. Try specifying the labels parameter

# %%
# Initialize decoder
custom_decoder = CustomBrainAudioDecoder(
    path_bids=path_bids,
    path_output=path_output,
    path_results=path_results,
    win_length=0.05,
    frameshift=0.01,
    model_order=4,
    step_size=5,
    n_components=50
)
# 7. Evaluate performance
print(f"Simplified phoneme group model accuracy: {results['accuracy']:.4f}")
    
# Compare to baseline
baseline_results = custom_decoder.train_test_model(
        participant_id='sub-08',
        save_audio=False
    )
baseline_correlation = np.mean(baseline_results['correlations'])
print(f"Baseline model correlation: {baseline_correlation:.4f}")

# %%
simplified_eval = simplified_model.last_evaluation  

# If you don't have the evaluation results stored, run a quick evaluation
if not simplified_eval:
    # Get test data and evaluate
    test_data = pipeline.get_test_data()
    simplified_eval = simplified_model.evaluate(test_data)

# Just call the pipeline visualization directly
pipeline.visualize_model_results(
    model=simplified_model,
    eval_results=simplified_eval,
    title_prefix="Simplified Phoneme Model"
)

# %%
class_metrics = simplified_model.analyze_class_performance(
        results['true_groups'], 
        results['predicted_groups'],
        results['predictions']
    )

# %%
# # Write out examples of predictions
# examples = simplified_model.analyze_examples(
#         test_data['features'],
#         results['true_groups'],
#         results['predicted_groups'],
#         test_data['phoneme_participant_ids'],
#         max_examples=3
#     )

# %%
# Get FILTERED data (this is what you feed to the Markov model):
balance_strategy = 'weighted' #'undersample'#

train_data = pipeline.get_training_data(filtered=True)  # or pipeline.train_filtered

balanced_train_data = pipeline.balance_training_data(
                    train_data, 
                    balance_strategy = balance_strategy # 'weighted' #'undersample'#
                )

# Extract all components:
balanced_features = balanced_train_data['features']
balanced_labels = balanced_train_data['phoneme_labels']
balanced_words = balanced_train_data['phoneme_words']
balanced_participants = balanced_train_data['phoneme_participant_ids']

# test_features = pipeline.test['features']
# test_labels = pipeline.test['phoneme_labels']


balanced_train_parameters = {
    'features': filtered_features,
    'phoneme_labels': filtered_labels,
    'words': filtered_words,
    'participant_ids': filtered_participants
}

balanced_test_parameters = {
    'features': test_features,
    'true_labels': test_labels,  # Note: evaluate() uses 'true_labels' not 'phoneme_labels'
    'use_viterbi': True
}

# %%
# 6. Train using balanced groups
results = simplified_model.train_with_grouped_data(
        train_features = balanced_features,
        train_group_labels = balanced_labels,
        train_participant_ids = balanced_participants,
        test_features=test_features,
        test_group_labels=test_group_labels,
        min_occurrences=recommended_min_occurrences,  # Use the recommended value
        test_participant_ids=test_participant_ids,
        epochs=50,
        batch_size=32,
        patience=10
    )
