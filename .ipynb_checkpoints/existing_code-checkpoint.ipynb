# %%
from extract_features import extractHG, stackFeatures, extractMelSpecs, downsampleLabels, nameVector

import os
import numpy as np
import pandas as pd
import scipy
import scipy.signal
import scipy.stats
import scipy.io.wavfile
import scipy.fftpack

from pynwb import NWBHDF5IO

import scipy.io.wavfile as wavfile
from scipy.stats import pearsonr
from sklearn.model_selection import KFold
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

import reconstructWave as rW
import MelFilterBank as mel

from reconstruction_minimal import createAudio
import matplotlib.pyplot as plt
import matplotlib

# %%
path_bids = r'./SingleWordProductionDutch-iBIDS'
path_output = r'./features'
feat_path = r'./features'
result_path = r'./results'

# %%
winL = 0.05
frameshift = 0.01
modelOrder = 4
stepSize = 5

# %%
participants = pd.read_csv(os.path.join(path_bids,'participants.tsv'), delimiter='\t')
for p_id, participant in enumerate(participants['participant_id']):
    print(p_id, participant)
# Out:
# 0 sub-01
# 1 sub-02
# 2 sub-03
# 3 sub-04
# 4 sub-05
# 5 sub-06
# 6 sub-07
# 7 sub-08
# 8 sub-09
# 9 sub-10

# %%
# extract features
participants = pd.read_csv(os.path.join(path_bids,'participants.tsv'), delimiter='\t')
for p_id, participant in enumerate(participants['participant_id']):
        
    #Load data
    io = NWBHDF5IO(os.path.join(path_bids,participant,'ieeg',f'{participant}_task-wordProduction_ieeg.nwb'), 'r')
    nwbfile = io.read()
    #sEEG
    eeg = nwbfile.acquisition['iEEG'].data[:]
    eeg_sr = 1024
    #audio
    audio = nwbfile.acquisition['Audio'].data[:]
    audio_sr = 48000
    #words (markers)
    words = nwbfile.acquisition['Stimulus'].data[:]
    words = np.array(words, dtype=str)
    io.close()
    #channels
    channels = pd.read_csv(os.path.join(path_bids,participant,'ieeg',f'{participant}_task-wordProduction_channels.tsv'), delimiter='\t')
    channels = np.array(channels['name'])

    #Extract HG features
    feat = extractHG(eeg,eeg_sr, windowLength=winL,frameshift=frameshift)

    #Stack features
    feat = stackFeatures(feat,modelOrder=modelOrder,stepSize=stepSize)
        
    #Process Audio
    target_SR = 16000
    audio = scipy.signal.decimate(audio,int(audio_sr / target_SR))
    audio_sr = target_SR
    scaled = np.int16(audio/np.max(np.abs(audio)) * 32767)
    os.makedirs(os.path.join(path_output), exist_ok=True)
    scipy.io.wavfile.write(os.path.join(path_output,f'{participant}_orig_audio.wav'),audio_sr,scaled)   

    #Extract spectrogram
    melSpec = extractMelSpecs(scaled,audio_sr,windowLength=winL,frameshift=frameshift)
        
    #Align to EEG features
    words = downsampleLabels(words,eeg_sr,windowLength=winL,frameshift=frameshift)
    words = words[modelOrder*stepSize:words.shape[0]-modelOrder*stepSize]
    melSpec = melSpec[modelOrder*stepSize:melSpec.shape[0]-modelOrder*stepSize,:]
    #adjust length (differences might occur due to rounding in the number of windows)
    if melSpec.shape[0]!=feat.shape[0]:
        tLen = np.min([melSpec.shape[0],feat.shape[0]])
        melSpec = melSpec[:tLen,:]
        feat = feat[:tLen,:]
        
    #Create feature names by appending the temporal shift 
    feature_names = nameVector(channels[:,None], modelOrder=modelOrder)

    #Save everything
#     np.save(os.path.join(path_output,f'{participant}_feat.npy'), feat)
#     np.save(os.path.join(path_output,f'{participant}_procWords.npy'), words)
#     np.save(os.path.join(path_output,f'{participant}_spec.npy'), melSpec)
#     np.save(os.path.join(path_output,f'{participant}_feat_names.npy'), feature_names)

# %%
feature_names
# Out:
# array(['RC1T-4', 'RC2T-4', 'RC3T-4', ..., 'RZ8T4', 'RZ9T4', 'RZ10T4'],
#       dtype='<U10')

# %%
words
# Out:
# array(['5', '5', '5', ..., '', '', ''], dtype='<U12')

# %%
# Plot a few seconds of raw EEG data for a few channels
def plot_raw_eeg(eeg_data, sample_rate, duration=5, channels_to_plot=10):
    # Convert duration to samples
    samples = int(duration * sample_rate)
    
    # Select a subset of channels if there are many
    if eeg_data.shape[1] > channels_to_plot:
        channel_indices = np.linspace(0, eeg_data.shape[1]-1, channels_to_plot, dtype=int)
    else:
        channel_indices = range(eeg_data.shape[1])
    
    plt.figure(figsize=(15, 10))
    for i, ch_idx in enumerate(channel_indices):
        # Offset each channel for visibility
        offset = i * 100  # Adjust based on signal amplitude
        plt.plot(np.arange(samples)/sample_rate, 
                 eeg_data[:samples, ch_idx] + offset, 
                 label=f'Channel {ch_idx}')
    
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude (μV) + offset')
    plt.title('Raw EEG Signals')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_raw_eeg(eeg, eeg_sr)

# %%
# reconstruction minimal
pts = ['sub-%02d'%i for i in range(1,11)]

winLength = 0.05
frameshift = 0.01
audiosr = 16000

nfolds = 10
kf = KFold(nfolds,shuffle=False)
est = LinearRegression(n_jobs=5)
pca = PCA()
numComps = 50
    
#Initialize empty matrices for correlation results, randomized contols and amount of explained variance
allRes = np.zeros((len(pts),nfolds,23))
explainedVariance = np.zeros((len(pts),nfolds))
numRands = 1000
randomControl = np.zeros((len(pts),numRands, 23))

for pNr, pt in enumerate(pts):
    #Load the data
    spectrogram = np.load(os.path.join(feat_path,f'{pt}_spec.npy'))
    data = np.load(os.path.join(feat_path,f'{pt}_feat.npy'))
    labels = np.load(os.path.join(feat_path,f'{pt}_procWords.npy'))
    featName = np.load(os.path.join(feat_path,f'{pt}_feat_names.npy'))
        
#     #Initialize an empty spectrogram to save the reconstruction to
#     rec_spec = np.zeros(spectrogram.shape)
#     #Save the correlation coefficients for each fold
#     rs = np.zeros((nfolds,spectrogram.shape[1]))
#     for k,(train, test) in enumerate(kf.split(data)):
#         #Z-Normalize with mean and std from the training data
#         mu=np.mean(data[train,:],axis=0)
#         std=np.std(data[train,:],axis=0)
#         trainData=(data[train,:]-mu)/std
#         testData=(data[test,:]-mu)/std

#         #Fit PCA to training data
#         pca.fit(trainData)
#         #Get percentage of explained variance by selected components
#         explainedVariance[pNr,k] =  np.sum(pca.explained_variance_ratio_[:numComps])
#         #Tranform data into component space
#         trainData=np.dot(trainData, pca.components_[:numComps,:].T)
#         testData = np.dot(testData, pca.components_[:numComps,:].T)
            
#         #Fit the regression model
#         est.fit(trainData, spectrogram[train, :])
#         #Predict the reconstructed spectrogram for the test data
#         rec_spec[test, :] = est.predict(testData)

#         #Evaluate reconstruction of this fold
#         for specBin in range(spectrogram.shape[1]):
#             if np.any(np.isnan(rec_spec)):
#                 print('%s has %d broken samples in reconstruction' % (pt, np.sum(np.isnan(rec_spec))))
#             r, p = pearsonr(spectrogram[test, specBin], rec_spec[test, specBin])
#             rs[k,specBin] = r

#     #Show evaluation result
#     print('%s has mean correlation of %f' % (pt, np.mean(rs)))
#     allRes[pNr,:,:]=rs

#     #Estimate random baseline
#     for randRound in range(numRands):
#         #Choose a random splitting point at least 10% of the dataset size away
#         splitPoint = np.random.choice(np.arange(int(spectrogram.shape[0]*0.1),int(spectrogram.shape[0]*0.9)))
#         #Swap the dataset on the splitting point 
#         shuffled = np.concatenate((spectrogram[splitPoint:,:],spectrogram[:splitPoint,:]))
#         #Calculate the correlations
#         for specBin in range(spectrogram.shape[1]):
#             if np.any(np.isnan(rec_spec)):
#                 print('%s has %d broken samples in reconstruction' % (pt, np.sum(np.isnan(rec_spec))))
#             r, p = pearsonr(spectrogram[:,specBin], shuffled[:,specBin])
#             randomControl[pNr, randRound,specBin]=r


#     #Save reconstructed spectrogram
#     os.makedirs(os.path.join(result_path), exist_ok=True)
#     np.save(os.path.join(result_path,f'{pt}_predicted_spec.npy'), rec_spec)
        
#     #Synthesize waveform from spectrogram using Griffin-Lim
#     reconstructedWav = createAudio(rec_spec,audiosr=audiosr,winLength=winLength,frameshift=frameshift)
#     wavfile.write(os.path.join(result_path,f'{pt}_predicted.wav'),int(audiosr),reconstructedWav)

#     #For comparison synthesize the original spectrogram with Griffin-Lim
#     origWav = createAudio(spectrogram,audiosr=audiosr,winLength=winLength,frameshift=frameshift)
#     wavfile.write(os.path.join(result_path,f'{pt}_orig_synthesized.wav'),int(audiosr),origWav)

#Save results in numpy arrays          
# np.save(os.path.join(result_path,'linearResults.npy'),allRes)
# np.save(os.path.join(result_path,'randomResults.npy'),randomControl)
# np.save(os.path.join(result_path,'explainedVariance.npy'),explainedVariance)

# %%
labels
# Out:
# array(['5', '5', '5', ..., '', '', ''], dtype='<U12')

# %%
channels_df = pd.read_csv(os.path.join(path_bids, participant, 'ieeg', 
                         f'{participant}_task-wordProduction_channels.tsv'), 
                         delimiter='\t')

# %%
# Get a count of channels by brain region
brain_regions = channels_df['description'].value_counts()
print("Channels by brain region:")
print(brain_regions)

# Look for speech-related areas
speech_related_terms = ['front', 'temporal', 'sylvian', 'wernicke', 'broca', 
                       'inferior', 'superior temporal', 'angular', 'supramarginal']

speech_areas = []
for i, row in channels_df.iterrows():
    desc = str(row['description']).lower()
    if any(term in desc for term in speech_related_terms):
        speech_areas.append((row['name'], row['description']))

print("\nPotential speech-related channels:")
for name, desc in speech_areas:
    print(f"{name}: {desc}")

# Check for left hemisphere channels
left_hemisphere = channels_df[channels_df['name'].str.startswith('L') | 
                              channels_df['description'].str.contains('left|lh')]
print(f"\nNumber of left hemisphere channels: {len(left_hemisphere)}")
# Out:
# Channels by brain region:
# description
# Right-Cerebral-White-Matter         47
# Unknown                             15
# ctx_rh_G_front_sup                   9
# ctx_rh_G_parietal_sup                5
# ctx_rh_S_intrapariet_and_P_trans     5
# ctx_rh_S_temporal_sup                5
# ctx_rh_G_temporal_middle             4
# ctx_rh_S_cingul-Marginalis           4
# ctx_rh_S_subparietal                 4
# ctx_rh_G_temp_sup-Plan_tempo         3
# ctx_rh_G_and_S_cingul-Mid-Ant        3
# Right-Hippocampus                    3
# Right-Lateral-Ventricle              3
# ctx_rh_S_front_sup                   2
# ctx_rh_G_pariet_inf-Angular          2
# ctx_rh_G_pariet_inf-Supramar         2
# ctx_rh_G_front_middle                1
# ctx_rh_G_cingul-Post-dorsal          1
# ctx_rh_G_temp_sup-G_T_transv         1
# ctx_rh_Lat_Fis-post                  1
# ctx_rh_S_postcentral                 1
# ctx_rh_G_and_S_paracentral           1
# Name: count, dtype: int64
#
# Potential speech-related channels:
# RF1: ctx_rh_G_front_sup
# RF2: ctx_rh_G_front_sup
# RF4: ctx_rh_G_front_sup
# RF5: ctx_rh_G_front_sup
# RH6: ctx_rh_S_temporal_sup
# RH7: ctx_rh_S_temporal_sup
# RH8: ctx_rh_S_temporal_sup
# RH10: ctx_rh_G_temporal_middle
# RM1: ctx_rh_G_front_sup
# RM2: ctx_rh_G_front_sup
# RP13: ctx_rh_G_pariet_inf-Angular
# RP14: ctx_rh_G_pariet_inf-Angular
# RQ1: ctx_rh_G_front_sup
# RQ2: ctx_rh_G_front_sup
# RQ4: ctx_rh_G_front_sup
# RT7: ctx_rh_S_temporal_sup
# RT8: ctx_rh_S_temporal_sup
# RT9: ctx_rh_G_temporal_middle
# RT10: ctx_rh_G_temporal_middle
# RT11: ctx_rh_G_temporal_middle
# RW7: ctx_rh_S_front_sup
# RW8: ctx_rh_S_front_sup
# RW10: ctx_rh_G_front_middle
#
# Number of left hemisphere channels: 0

# %%
# Define groups of speech-relevant channels by region
speech_channel_groups = {
    'superior_temporal': ['RH6', 'RH7', 'RH8', 'RT7', 'RT8'],  # Auditory processing
    'middle_temporal': ['RH10', 'RT9', 'RT10', 'RT11'],        # Semantic processing
    'angular_gyrus': ['RP13', 'RP14'],                         # Reading/language integration
    'frontal': ['RF1', 'RF2', 'RF4', 'RF5', 'RM1', 'RM2',      # Executive aspects
                'RQ1', 'RQ2', 'RQ4', 'RW10']
}

# Convert channel names to indices
def get_channel_indices(channel_names, channels_df):
    indices = []
    for name in channel_names:
        matching_rows = channels_df[channels_df['name'] == name]
        if not matching_rows.empty:
            indices.append(matching_rows.index[0])
    return indices

# Get indices for each group
speech_indices = {}
for group_name, channel_names in speech_channel_groups.items():
    speech_indices[group_name] = get_channel_indices(channel_names, channels_df)
    print(f"{group_name}: {len(speech_indices[group_name])} channels")

# Combine all speech-related indices
all_speech_indices = []
for indices in speech_indices.values():
    all_speech_indices.extend(indices)
print(f"Total speech-related channels: {len(all_speech_indices)}")
# Out:
# superior_temporal: 5 channels
# middle_temporal: 4 channels
# angular_gyrus: 2 channels
# frontal: 10 channels
# Total speech-related channels: 21

# %%
def analyze_individual_channels(eeg_data, spectrogram, channels_df, 
                               windowLength=0.05, frameshift=0.01, 
                               modelOrder=4, stepSize=5, numComps=10):
    """
    Analyze each channel individually to see its contribution to speech reconstruction
    
    Parameters:
    -----------
    eeg_data : numpy array
        EEG data with shape [samples, channels]
    spectrogram : numpy array
        Target spectrogram to reconstruct
    channels_df : pandas DataFrame
        Dataframe containing channel information
    
    Returns:
    --------
    channel_results : dict
        Dictionary with channel names as keys and correlation values as values
    """
    print("Analyzing individual channel contributions...")
    
    # Setup for cross-validation
    nfolds = 5  # Using fewer folds for speed
    kf = KFold(nfolds, shuffle=False)
    est = LinearRegression()
    pca = PCA()
    
    # Store results
    channel_results = {}
    
    # Loop through each channel
    for chan_idx in range(eeg_data.shape[1]):
        # Get channel name
        if chan_idx < len(channels_df):
            chan_name = channels_df.iloc[chan_idx]['name']
            chan_region = channels_df.iloc[chan_idx]['description']
        else:
            chan_name = f"Channel_{chan_idx}"
            chan_region = "Unknown"
            
        print(f"Processing {chan_name} ({chan_region})... ", end="")
        
        # Extract single channel data
        single_chan_data = eeg_data[:, [chan_idx]]
        
        # Extract high-gamma features
        try:
            feat = extractHG(single_chan_data, 1024, windowLength=windowLength, frameshift=frameshift)
            
            # Stack features
            feat = stackFeatures(feat, modelOrder=modelOrder, stepSize=stepSize)
            
            # Ensure the feature length matches the spectrogram
            if feat.shape[0] != spectrogram.shape[0]:
                min_len = min(feat.shape[0], spectrogram.shape[0])
                feat = feat[:min_len, :]
                spec_for_analysis = spectrogram[:min_len, :]
            else:
                spec_for_analysis = spectrogram
            
            # Initialize for cross-validation
            rec_spec = np.zeros((feat.shape[0], spec_for_analysis.shape[1]))
            rs = np.zeros((nfolds, spec_for_analysis.shape[1]))
            
            # Run cross-validation
            for k, (train, test) in enumerate(kf.split(feat)):
                # Skip if training set is too small
                if len(train) < 10 or len(test) < 10:
                    continue
                    
                # Normalize
                mu = np.mean(feat[train,:], axis=0)
                std = np.std(feat[train,:], axis=0)
                std[std == 0] = 1  # Avoid division by zero
                trainData = (feat[train,:] - mu) / std
                testData = (feat[test,:] - mu) / std
                
                # Use fewer components for single channel data
                n_components = min(numComps, trainData.shape[1], trainData.shape[0])
                if n_components < 2:
                    # Skip if too few components
                    print("Skipping - insufficient data")
                    continue
                
                # PCA
                try:
                    pca = PCA(n_components=n_components)
                    pca.fit(trainData)
                    trainData = pca.transform(trainData)
                    testData = pca.transform(testData)
                    
                    # Train model
                    est.fit(trainData, spec_for_analysis[train, :])
                    rec_spec[test, :] = est.predict(testData)
                    
                    # Evaluate
                    for specBin in range(spec_for_analysis.shape[1]):
                        r, p = pearsonr(spec_for_analysis[test, specBin], rec_spec[test, specBin])
                        rs[k, specBin] = r
                except Exception as e:
                    print(f"Error in PCA/regression: {e}")
                    continue
            
        except Exception as e:
            print(f"Error processing channel: {e}")
            channel_results[chan_name] = {
                'correlation': np.nan,
                'region': chan_region,
                'index': chan_idx
            }
    
    return channel_results

# %%
eeg_data = eeg
analyze_individual_channels(eeg_data, spectrogram, channels_df, 
                               windowLength=0.05, frameshift=0.01, 
                               modelOrder=4, stepSize=5, numComps=10)
# Out:
# Analyzing individual channel contributions...
# Processing RC1 (ctx_rh_G_cingul-Post-dorsal)... Correlation: 0.189622
# Processing RC2 (Right-Cerebral-White-Matter)... Correlation: 0.209561
# Processing RC3 (Right-Cerebral-White-Matter)... Correlation: 0.316795
# Processing RC4 (Right-Cerebral-White-Matter)... Correlation: 0.398089
# Processing RC5 (Right-Cerebral-White-Matter)... Correlation: 0.386640
# Processing RC7 (Right-Cerebral-White-Matter)... Correlation: 0.438468
# Processing RC8 (Right-Cerebral-White-Matter)... Correlation: 0.444953
# Processing RC9 (Right-Cerebral-White-Matter)... Correlation: 0.423630
# Processing RC10 (Right-Cerebral-White-Matter)... Correlation: 0.406156
# Processing RC11 (Right-Cerebral-White-Matter)... Correlation: 0.402014
# Processing RC12 (ctx_rh_S_postcentral)... Correlation: 0.043879
# Processing RC13 (Right-Cerebral-White-Matter)... Correlation: 0.373134
# Processing RC14 (Right-Cerebral-White-Matter)... Correlation: 0.341527
# Processing RC15 (ctx_rh_G_pariet_inf-Supramar)... Correlation: 0.322426
# Processing RC16 (ctx_rh_G_pariet_inf-Supramar)... Correlation: 0.337601
# Processing RC17 (Unknown)... Correlation: 0.278321
# Processing RC18 (Unknown)... Correlation: 0.213549
# Processing RF1 (ctx_rh_G_front_sup)... Correlation: 0.265504
# Processing RF2 (ctx_rh_G_front_sup)... Correlation: 0.339530
# Processing RF3 (Right-Cerebral-White-Matter)... Correlation: 0.101955
# Processing RF4 (ctx_rh_G_front_sup)... Correlation: 0.354887
# Processing RF5 (ctx_rh_G_front_sup)... Correlation: 0.390165
# Processing RH1 (Right-Hippocampus)... Correlation: 0.035752
# Processing RH2 (Right-Hippocampus)... Correlation: 0.132463
# Processing RH3 (Right-Hippocampus)... Correlation: 0.237118
# Processing RH4 (Right-Cerebral-White-Matter)... Correlation: 0.389610
# Processing RH5 (Right-Cerebral-White-Matter)... Correlation: 0.432937
# Processing RH6 (ctx_rh_S_temporal_sup)... Correlation: 0.440255
# Processing RH7 (ctx_rh_S_temporal_sup)... Correlation: 0.435727
# Processing RH8 (ctx_rh_S_temporal_sup)... Correlation: 0.414479
# Processing RH9 (Right-Cerebral-White-Matter)... Correlation: 0.403873
# Processing RH10 (ctx_rh_G_temporal_middle)... Correlation: 0.387911
# Processing RI1 (ctx_rh_Lat_Fis-post)... Correlation: 0.694073
# Processing RI2 (Right-Cerebral-White-Matter)... Correlation: 0.707020
# Processing RI3 (ctx_rh_G_temp_sup-G_T_transv)... Correlation: 0.657330
# Processing RI4 (ctx_rh_G_temp_sup-Plan_tempo)... Correlation: 0.592710
# Processing RI5 (ctx_rh_G_temp_sup-Plan_tempo)... Correlation: 0.559887
# Processing RI6 (Right-Cerebral-White-Matter)... Correlation: 0.556210
# Processing RI7 (ctx_rh_G_temp_sup-Plan_tempo)... Correlation: 0.481053
# Processing RI8 (Right-Cerebral-White-Matter)... Correlation: 0.386551
# Processing RK1 (Right-Cerebral-White-Matter)... Correlation: 0.202942
# Processing RK2 (Right-Cerebral-White-Matter)... Correlation: 0.123719
# Processing RK4 (Right-Cerebral-White-Matter)... Correlation: 0.075152
# Processing RK5 (Right-Cerebral-White-Matter)... Correlation: 0.189332
# Processing RK6 (Unknown)... Correlation: 0.300298
# Processing RK7 (Unknown)... Correlation: 0.326246
# Processing RK8 (Unknown)... Correlation: 0.351274
# Processing RM1 (ctx_rh_G_front_sup)... Correlation: 0.138509
# Processing RM2 (ctx_rh_G_front_sup)... Correlation: 0.171074
# Processing RM3 (Right-Cerebral-White-Matter)... Correlation: 0.305797
# Processing RM4 (Right-Cerebral-White-Matter)... Correlation: 0.300615
# Processing RM5 (Unknown)... Correlation: 0.170815
# Processing RO1 (Right-Cerebral-White-Matter)... Correlation: 0.256273
# Processing RO2 (Right-Cerebral-White-Matter)... Correlation: 0.313508
# Processing RO3 (Right-Cerebral-White-Matter)... Correlation: 0.349787
# Processing RO4 (Right-Cerebral-White-Matter)... Correlation: 0.383514
# Processing RO5 (Right-Cerebral-White-Matter)... Correlation: 0.397467
# Processing RO6 (Right-Cerebral-White-Matter)... Correlation: 0.397874
# Processing RO7 (Right-Cerebral-White-Matter)... Correlation: 0.377953
# Processing RO8 (Right-Cerebral-White-Matter)... Correlation: 0.362523
# Processing RO9 (Right-Cerebral-White-Matter)... Correlation: 0.370893
# Processing RO10 (Right-Cerebral-White-Matter)... Correlation: 0.335800
# Processing RP1 (ctx_rh_S_subparietal)... Correlation: 0.071204
# Processing RP2 (ctx_rh_S_subparietal)... Correlation: 0.152891
# Processing RP3 (Right-Cerebral-White-Matter)... Correlation: 0.251162
# Processing RP4 (Right-Cerebral-White-Matter)... Correlation: 0.362560
# Processing RP5 (ctx_rh_S_intrapariet_and_P_trans)... Correlation: 0.139303
# Processing RP6 (ctx_rh_S_intrapariet_and_P_trans)... Correlation: 0.108056
# Processing RP7 (ctx_rh_S_intrapariet_and_P_trans)... Correlation: 0.153448
# Processing RP8 (ctx_rh_S_intrapariet_and_P_trans)... Correlation: 0.162649
# Processing RP9 (Unknown)... Correlation: 0.342019
# Processing RP10 (ctx_rh_S_intrapariet_and_P_trans)... Correlation: 0.379412
# Processing RP11 (Right-Cerebral-White-Matter)... Correlation: 0.384614
# Processing RP12 (Right-Cerebral-White-Matter)... Correlation: 0.345682
# Processing RP13 (ctx_rh_G_pariet_inf-Angular)... Correlation: 0.373582
# Processing RP14 (ctx_rh_G_pariet_inf-Angular)... Correlation: 0.371891
# Processing RP15 (Unknown)... Correlation: 0.148947
# Processing RQ1 (ctx_rh_G_front_sup)... Correlation: 0.144840
# Processing RQ2 (ctx_rh_G_front_sup)... Correlation: 0.276602
# Processing RQ3 (Unknown)... Correlation: 0.317657
# Processing RQ4 (ctx_rh_G_front_sup)... Correlation: 0.392473
# Processing RQ5 (Unknown)... Correlation: 0.416237
# Processing RS1 (Unknown)... Correlation: 0.096445
# Processing RS2 (Unknown)... Correlation: 0.118826
# Processing RS3 (Right-Cerebral-White-Matter)... Correlation: 0.236101
# Processing RS4 (ctx_rh_G_parietal_sup)... Correlation: 0.329249
# Processing RS5 (ctx_rh_G_parietal_sup)... Correlation: 0.386241
# Processing RS6 (ctx_rh_G_parietal_sup)... Correlation: 0.411190
# Processing RS7 (ctx_rh_G_parietal_sup)... Correlation: 0.407066
# Processing RS8 (ctx_rh_G_parietal_sup)... Correlation: 0.426744
# Processing RT1 (Right-Lateral-Ventricle)... Correlation: 0.210558
# Processing RT2 (Right-Lateral-Ventricle)... Correlation: 0.263176
# Processing RT3 (Right-Lateral-Ventricle)... Correlation: 0.298943
# Processing RT4 (Right-Cerebral-White-Matter)... Correlation: 0.383841
# Processing RT5 (Right-Cerebral-White-Matter)... Correlation: 0.430586
# Processing RT6 (Right-Cerebral-White-Matter)... Correlation: 0.424313
# Processing RT7 (ctx_rh_S_temporal_sup)... Correlation: 0.399216
# Processing RT8 (ctx_rh_S_temporal_sup)... Correlation: 0.345927
# Processing RT9 (ctx_rh_G_temporal_middle)... Correlation: 0.287829
# Processing RT10 (ctx_rh_G_temporal_middle)... Correlation: 0.267754
# Processing RT11 (ctx_rh_G_temporal_middle)... Correlation: 0.247937
# Processing RT12 (Unknown)... Correlation: 0.119721
# Processing RW1 (ctx_rh_G_and_S_cingul-Mid-Ant)... Correlation: 0.332893
# Processing RW2 (ctx_rh_G_and_S_cingul-Mid-Ant)... Correlation: 0.273450
# Processing RW3 (ctx_rh_G_and_S_cingul-Mid-Ant)... Correlation: 0.230272
# Processing RW4 (Right-Cerebral-White-Matter)... Correlation: 0.334404
# Processing RW5 (Right-Cerebral-White-Matter)... Correlation: 0.436486
# Processing RW6 (Right-Cerebral-White-Matter)... Correlation: 0.422953
# Processing RW7 (ctx_rh_S_front_sup)... Correlation: 0.345492
# Processing RW8 (ctx_rh_S_front_sup)... Correlation: 0.376152
# Processing RW9 (Right-Cerebral-White-Matter)... Correlation: 0.386635
# Processing RW10 (ctx_rh_G_front_middle)... Correlation: 0.383920
# Processing RZ1 (ctx_rh_S_subparietal)... Correlation: 0.107937
# Processing RZ2 (ctx_rh_S_subparietal)... Correlation: 0.070000
# Processing RZ3 (ctx_rh_S_cingul-Marginalis)... Correlation: 0.076183
# Processing RZ4 (Unknown)... Correlation: 0.148798
# Processing RZ5 (ctx_rh_S_cingul-Marginalis)... Correlation: 0.202630
# Processing RZ6 (ctx_rh_S_cingul-Marginalis)... Correlation: 0.283365
# Processing RZ7 (ctx_rh_S_cingul-Marginalis)... Correlation: 0.391560
# Processing RZ8 (Right-Cerebral-White-Matter)... Correlation: 0.383260
# Processing RZ9 (ctx_rh_G_and_S_paracentral)... Correlation: 0.382333
# Processing RZ10 (Unknown)... Correlation: 0.371372
# {'RC1': {'correlation': 0.18962223014373286,
#   'region': 'ctx_rh_G_cingul-Post-dorsal',
#   'index': 0},
#  'RC2': {'correlation': 0.20956062231166633,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 1},
#  'RC3': {'correlation': 0.3167951856419907,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 2},
#  'RC4': {'correlation': 0.3980887050536554,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 3},
#  'RC5': {'correlation': 0.3866403216638172,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 4},
#  'RC7': {'correlation': 0.43846843081376846,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 5},
#  'RC8': {'correlation': 0.4449528621756169,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 6},
#  'RC9': {'correlation': 0.42363040495408566,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 7},
#  'RC10': {'correlation': 0.4061556066994772,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 8},
#  'RC11': {'correlation': 0.40201368853217945,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 9},
#  'RC12': {'correlation': 0.04387904436172694,
#   'region': 'ctx_rh_S_postcentral',
#   'index': 10},
#  'RC13': {'correlation': 0.3731336809772879,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 11},
#  'RC14': {'correlation': 0.3415273006448078,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 12},
#  'RC15': {'correlation': 0.3224257266668071,
#   'region': 'ctx_rh_G_pariet_inf-Supramar',
#   'index': 13},
#  'RC16': {'correlation': 0.33760055065847966,
#   'region': 'ctx_rh_G_pariet_inf-Supramar',
#   'index': 14},
#  'RC17': {'correlation': 0.2783211870459194, 'region': 'Unknown', 'index': 15},
#  'RC18': {'correlation': 0.2135486630021407, 'region': 'Unknown', 'index': 16},
#  'RF1': {'correlation': 0.26550426290594387,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 17},
#  'RF2': {'correlation': 0.3395297432672238,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 18},
#  'RF3': {'correlation': 0.10195514615741333,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 19},
#  'RF4': {'correlation': 0.35488724259608934,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 20},
#  'RF5': {'correlation': 0.3901649063079761,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 21},
#  'RH1': {'correlation': 0.03575201068075861,
#   'region': 'Right-Hippocampus',
#   'index': 22},
#  'RH2': {'correlation': 0.13246307006356925,
#   'region': 'Right-Hippocampus',
#   'index': 23},
#  'RH3': {'correlation': 0.23711833378318706,
#   'region': 'Right-Hippocampus',
#   'index': 24},
#  'RH4': {'correlation': 0.3896100520492228,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 25},
#  'RH5': {'correlation': 0.4329373876434184,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 26},
#  'RH6': {'correlation': 0.4402545424786756,
#   'region': 'ctx_rh_S_temporal_sup',
#   'index': 27},
#  'RH7': {'correlation': 0.43572741409779964,
#   'region': 'ctx_rh_S_temporal_sup',
#   'index': 28},
#  'RH8': {'correlation': 0.41447918768763603,
#   'region': 'ctx_rh_S_temporal_sup',
#   'index': 29},
#  'RH9': {'correlation': 0.4038729733273223,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 30},
#  'RH10': {'correlation': 0.38791090775680687,
#   'region': 'ctx_rh_G_temporal_middle',
#   'index': 31},
#  'RI1': {'correlation': 0.694073107689542,
#   'region': 'ctx_rh_Lat_Fis-post',
#   'index': 32},
#  'RI2': {'correlation': 0.7070198078922081,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 33},
#  'RI3': {'correlation': 0.657330461154084,
#   'region': 'ctx_rh_G_temp_sup-G_T_transv',
#   'index': 34},
#  'RI4': {'correlation': 0.5927101201926073,
#   'region': 'ctx_rh_G_temp_sup-Plan_tempo',
#   'index': 35},
#  'RI5': {'correlation': 0.5598874359890754,
#   'region': 'ctx_rh_G_temp_sup-Plan_tempo',
#   'index': 36},
#  'RI6': {'correlation': 0.556210068650329,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 37},
#  'RI7': {'correlation': 0.48105303264100396,
#   'region': 'ctx_rh_G_temp_sup-Plan_tempo',
#   'index': 38},
#  'RI8': {'correlation': 0.3865508251164537,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 39},
#  'RK1': {'correlation': 0.20294158951850064,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 40},
#  'RK2': {'correlation': 0.12371881945641773,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 41},
#  'RK4': {'correlation': 0.07515199440574642,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 42},
#  'RK5': {'correlation': 0.189332350442192,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 43},
#  'RK6': {'correlation': 0.3002980849045773, 'region': 'Unknown', 'index': 44},
#  'RK7': {'correlation': 0.326246026652886, 'region': 'Unknown', 'index': 45},
#  'RK8': {'correlation': 0.3512744392267098, 'region': 'Unknown', 'index': 46},
#  'RM1': {'correlation': 0.13850912522094946,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 47},
#  'RM2': {'correlation': 0.17107446300033816,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 48},
#  'RM3': {'correlation': 0.3057972964323158,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 49},
#  'RM4': {'correlation': 0.3006149226676698,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 50},
#  'RM5': {'correlation': 0.17081518871595283, 'region': 'Unknown', 'index': 51},
#  'RO1': {'correlation': 0.25627279286951304,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 52},
#  'RO2': {'correlation': 0.3135083601117109,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 53},
#  'RO3': {'correlation': 0.349786652749799,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 54},
#  'RO4': {'correlation': 0.3835138911050488,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 55},
#  'RO5': {'correlation': 0.39746719889108,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 56},
#  'RO6': {'correlation': 0.3978735022940745,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 57},
#  'RO7': {'correlation': 0.37795253039162896,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 58},
#  'RO8': {'correlation': 0.3625227159444206,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 59},
#  'RO9': {'correlation': 0.37089258878190784,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 60},
#  'RO10': {'correlation': 0.33580014032387007,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 61},
#  'RP1': {'correlation': 0.07120439732790691,
#   'region': 'ctx_rh_S_subparietal',
#   'index': 62},
#  'RP2': {'correlation': 0.15289067470236933,
#   'region': 'ctx_rh_S_subparietal',
#   'index': 63},
#  'RP3': {'correlation': 0.25116163396182545,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 64},
#  'RP4': {'correlation': 0.3625600712845815,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 65},
#  'RP5': {'correlation': 0.13930262310162098,
#   'region': 'ctx_rh_S_intrapariet_and_P_trans',
#   'index': 66},
#  'RP6': {'correlation': 0.10805562543150281,
#   'region': 'ctx_rh_S_intrapariet_and_P_trans',
#   'index': 67},
#  'RP7': {'correlation': 0.15344820251123595,
#   'region': 'ctx_rh_S_intrapariet_and_P_trans',
#   'index': 68},
#  'RP8': {'correlation': 0.16264902766117958,
#   'region': 'ctx_rh_S_intrapariet_and_P_trans',
#   'index': 69},
#  'RP9': {'correlation': 0.3420186923134969, 'region': 'Unknown', 'index': 70},
#  'RP10': {'correlation': 0.37941159092401444,
#   'region': 'ctx_rh_S_intrapariet_and_P_trans',
#   'index': 71},
#  'RP11': {'correlation': 0.38461441661264467,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 72},
#  'RP12': {'correlation': 0.3456823284747316,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 73},
#  'RP13': {'correlation': 0.3735818091058033,
#   'region': 'ctx_rh_G_pariet_inf-Angular',
#   'index': 74},
#  'RP14': {'correlation': 0.37189104584156324,
#   'region': 'ctx_rh_G_pariet_inf-Angular',
#   'index': 75},
#  'RP15': {'correlation': 0.14894685320699774,
#   'region': 'Unknown',
#   'index': 76},
#  'RQ1': {'correlation': 0.14484026782332787,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 77},
#  'RQ2': {'correlation': 0.27660241119341294,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 78},
#  'RQ3': {'correlation': 0.3176568238001991, 'region': 'Unknown', 'index': 79},
#  'RQ4': {'correlation': 0.39247331054534956,
#   'region': 'ctx_rh_G_front_sup',
#   'index': 80},
#  'RQ5': {'correlation': 0.4162367593737567, 'region': 'Unknown', 'index': 81},
#  'RS1': {'correlation': 0.09644521594273166, 'region': 'Unknown', 'index': 82},
#  'RS2': {'correlation': 0.1188255448055805, 'region': 'Unknown', 'index': 83},
#  'RS3': {'correlation': 0.23610067636769966,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 84},
#  'RS4': {'correlation': 0.32924914361104585,
#   'region': 'ctx_rh_G_parietal_sup',
#   'index': 85},
#  'RS5': {'correlation': 0.3862412454064216,
#   'region': 'ctx_rh_G_parietal_sup',
#   'index': 86},
#  'RS6': {'correlation': 0.41118954360034815,
#   'region': 'ctx_rh_G_parietal_sup',
#   'index': 87},
#  'RS7': {'correlation': 0.40706611674569565,
#   'region': 'ctx_rh_G_parietal_sup',
#   'index': 88},
#  'RS8': {'correlation': 0.426743853431404,
#   'region': 'ctx_rh_G_parietal_sup',
#   'index': 89},
#  'RT1': {'correlation': 0.21055781036222637,
#   'region': 'Right-Lateral-Ventricle',
#   'index': 90},
#  'RT2': {'correlation': 0.26317568267550495,
#   'region': 'Right-Lateral-Ventricle',
#   'index': 91},
#  'RT3': {'correlation': 0.2989433311180366,
#   'region': 'Right-Lateral-Ventricle',
#   'index': 92},
#  'RT4': {'correlation': 0.38384069007943444,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 93},
#  'RT5': {'correlation': 0.4305858569970978,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 94},
#  'RT6': {'correlation': 0.4243133243817471,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 95},
#  'RT7': {'correlation': 0.39921574313542807,
#   'region': 'ctx_rh_S_temporal_sup',
#   'index': 96},
#  'RT8': {'correlation': 0.34592742250852343,
#   'region': 'ctx_rh_S_temporal_sup',
#   'index': 97},
#  'RT9': {'correlation': 0.2878285468537281,
#   'region': 'ctx_rh_G_temporal_middle',
#   'index': 98},
#  'RT10': {'correlation': 0.26775415570191224,
#   'region': 'ctx_rh_G_temporal_middle',
#   'index': 99},
#  'RT11': {'correlation': 0.24793691058556114,
#   'region': 'ctx_rh_G_temporal_middle',
#   'index': 100},
#  'RT12': {'correlation': 0.11972106402906453,
#   'region': 'Unknown',
#   'index': 101},
#  'RW1': {'correlation': 0.33289267596882927,
#   'region': 'ctx_rh_G_and_S_cingul-Mid-Ant',
#   'index': 102},
#  'RW2': {'correlation': 0.27345034363721354,
#   'region': 'ctx_rh_G_and_S_cingul-Mid-Ant',
#   'index': 103},
#  'RW3': {'correlation': 0.2302721590684493,
#   'region': 'ctx_rh_G_and_S_cingul-Mid-Ant',
#   'index': 104},
#  'RW4': {'correlation': 0.33440419576883235,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 105},
#  'RW5': {'correlation': 0.4364858171037406,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 106},
#  'RW6': {'correlation': 0.4229525572084528,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 107},
#  'RW7': {'correlation': 0.3454915244882553,
#   'region': 'ctx_rh_S_front_sup',
#   'index': 108},
#  'RW8': {'correlation': 0.3761522488947687,
#   'region': 'ctx_rh_S_front_sup',
#   'index': 109},
#  'RW9': {'correlation': 0.3866354597751626,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 110},
#  'RW10': {'correlation': 0.383920467452431,
#   'region': 'ctx_rh_G_front_middle',
#   'index': 111},
#  'RZ1': {'correlation': 0.10793741452915073,
#   'region': 'ctx_rh_S_subparietal',
#   'index': 112},
#  'RZ2': {'correlation': 0.06999967790265252,
#   'region': 'ctx_rh_S_subparietal',
#   'index': 113},
#  'RZ3': {'correlation': 0.07618260291841068,
#   'region': 'ctx_rh_S_cingul-Marginalis',
#   'index': 114},
#  'RZ4': {'correlation': 0.14879832742560295,
#   'region': 'Unknown',
#   'index': 115},
#  'RZ5': {'correlation': 0.2026295532623323,
#   'region': 'ctx_rh_S_cingul-Marginalis',
#   'index': 116},
#  'RZ6': {'correlation': 0.28336467258575354,
#   'region': 'ctx_rh_S_cingul-Marginalis',
#   'index': 117},
#  'RZ7': {'correlation': 0.3915604388764016,
#   'region': 'ctx_rh_S_cingul-Marginalis',
#   'index': 118},
#  'RZ8': {'correlation': 0.3832604421788693,
#   'region': 'Right-Cerebral-White-Matter',
#   'index': 119},
#  'RZ9': {'correlation': 0.3823328115205439,
#   'region': 'ctx_rh_G_and_S_paracentral',
#   'index': 120},
#  'RZ10': {'correlation': 0.3713722555726604,
#   'region': 'Unknown',
#   'index': 121}}

# %%
word_df, length_stats = analyze_word_length_correlation(spectrogram, rec_spec, labels)
# Out:
# Found 95 word onsets
# Processing word 'vijf' (length=4, duration=2.78s)
#   Mean correlation: 0.5439 (using 23 frequency bins)
# Processing word 'naar' (length=4, duration=2.99s)
#   Mean correlation: 0.7778 (using 23 frequency bins)
# Processing word 'braadde' (length=7, duration=3.00s)
#   Mean correlation: 0.8509 (using 23 frequency bins)
# Processing word 'zo' (length=2, duration=3.00s)
#   Mean correlation: 0.8823 (using 23 frequency bins)
# Processing word 'onmiddellijk' (length=12, duration=3.00s)
#   Mean correlation: 0.8651 (using 23 frequency bins)
# Processing word 'verstijfde' (length=10, duration=3.00s)
#   Mean correlation: 0.8219 (using 23 frequency bins)
# Processing word 'door' (length=4, duration=3.00s)
#   Mean correlation: 0.6156 (using 23 frequency bins)
# Processing word 'tien' (length=4, duration=3.00s)
#   Mean correlation: 0.6912 (using 23 frequency bins)
# Processing word '12' (length=2, duration=3.00s)
#   Mean correlation: 0.8136 (using 23 frequency bins)
# Processing word 'hem' (length=3, duration=3.01s)
#   Mean correlation: 0.8140 (using 23 frequency bins)
# Processing word 'tuwiet' (length=6, duration=3.01s)
#   Mean correlation: 0.7668 (using 23 frequency bins)
# Processing word 'nachtegalen' (length=11, duration=3.00s)
#   Mean correlation: 0.8498 (using 23 frequency bins)
# Processing word 'zijn' (length=4, duration=3.01s)
#   Mean correlation: 0.5794 (using 23 frequency bins)
# Processing word 'wat' (length=3, duration=3.00s)
#   Mean correlation: 0.3915 (using 23 frequency bins)
# Processing word 'vak' (length=3, duration=3.01s)
#   Mean correlation: 0.6862 (using 23 frequency bins)
# Processing word 'dauwdruppel' (length=11, duration=3.00s)
#   Mean correlation: 0.7349 (using 23 frequency bins)
# Processing word 'tussen' (length=6, duration=3.01s)
#   Mean correlation: 0.7448 (using 23 frequency bins)
# Processing word 'zei' (length=3, duration=3.00s)
#   Mean correlation: 0.9002 (using 23 frequency bins)
# Processing word 'ze' (length=2, duration=3.01s)
#   Mean correlation: 0.7734 (using 23 frequency bins)
# Processing word 'dan' (length=3, duration=3.01s)
#   Mean correlation: 0.8367 (using 23 frequency bins)
# Processing word 'deur' (length=4, duration=3.00s)
#   Mean correlation: 0.8398 (using 23 frequency bins)
# Processing word 'bij' (length=3, duration=3.01s)
#   Mean correlation: 0.7871 (using 23 frequency bins)
# Processing word 'erheen' (length=6, duration=3.01s)
#   Mean correlation: 0.7969 (using 23 frequency bins)
# Processing word 'in' (length=2, duration=3.00s)
#   Mean correlation: 0.6730 (using 23 frequency bins)
# Processing word 'helemaal' (length=8, duration=3.01s)
#   Mean correlation: 0.8284 (using 23 frequency bins)
# Processing word '`s' (length=2, duration=3.01s)
#   Mean correlation: 0.7599 (using 23 frequency bins)
# Processing word 'lij' (length=3, duration=3.00s)
#   Mean correlation: 0.8266 (using 23 frequency bins)
# Processing word 'zonlicht' (length=8, duration=3.01s)
#   Mean correlation: 0.6735 (using 23 frequency bins)
# Processing word 'of' (length=2, duration=3.00s)
#   Mean correlation: 0.7376 (using 23 frequency bins)
# Processing word 'mijn' (length=4, duration=3.01s)
#   Mean correlation: 0.4366 (using 23 frequency bins)
# Processing word 'een' (length=3, duration=3.00s)
#   Mean correlation: 0.6966 (using 23 frequency bins)
# Processing word 'donkere' (length=7, duration=3.01s)
#   Mean correlation: 0.7861 (using 23 frequency bins)
# Processing word 'hij' (length=3, duration=3.00s)
#   Mean correlation: 0.8028 (using 23 frequency bins)
# Processing word 'de' (length=2, duration=3.01s)
#   Mean correlation: 0.7149 (using 23 frequency bins)
# Processing word 'zeven' (length=5, duration=3.00s)
#   Mean correlation: 0.7743 (using 23 frequency bins)
# Processing word 'van' (length=3, duration=3.01s)
#   Mean correlation: 0.8089 (using 23 frequency bins)
# Processing word 'direct' (length=6, duration=3.01s)
#   Mean correlation: 0.8144 (using 23 frequency bins)
# Processing word 'met' (length=3, duration=3.00s)
#   Mean correlation: 0.7227 (using 23 frequency bins)
# Processing word 'bak' (length=3, duration=3.01s)
#   Mean correlation: 0.7325 (using 23 frequency bins)
# Processing word 'het' (length=3, duration=3.00s)
#   Mean correlation: 0.4551 (using 23 frequency bins)
# Processing word 'smeekte' (length=7, duration=3.01s)
#   Mean correlation: 0.5169 (using 23 frequency bins)
# Processing word 'was' (length=3, duration=3.00s)
#   Mean correlation: 0.6675 (using 23 frequency bins)
# Processing word 'kin' (length=3, duration=3.01s)
#   Mean correlation: 0.7499 (using 23 frequency bins)
# Processing word 'schold' (length=6, duration=3.01s)
#   Mean correlation: 0.7009 (using 23 frequency bins)
# Processing word 'al' (length=2, duration=3.00s)
#   Mean correlation: 0.5966 (using 23 frequency bins)
# Processing word 'twee' (length=4, duration=3.01s)
#   Mean correlation: 0.8400 (using 23 frequency bins)
# Processing word 'daarna' (length=6, duration=3.00s)
#   Mean correlation: 0.8179 (using 23 frequency bins)
# Processing word 'uit' (length=3, duration=3.01s)
#   Mean correlation: 0.7224 (using 23 frequency bins)
# Processing word 'doodsbang' (length=9, duration=3.00s)
#   Mean correlation: 0.7184 (using 23 frequency bins)
# Processing word 'om' (length=2, duration=3.01s)
#   Mean correlation: 0.6966 (using 23 frequency bins)
# Processing word 'er' (length=2, duration=3.00s)
#   Mean correlation: 0.7913 (using 23 frequency bins)
# Processing word 'verdwaald' (length=9, duration=3.01s)
#   Mean correlation: 0.8859 (using 23 frequency bins)
# Processing word 'struik' (length=6, duration=3.00s)
#   Mean correlation: 0.7529 (using 23 frequency bins)
# Processing word 'spreuk' (length=6, duration=3.01s)
#   Mean correlation: 0.7233 (using 23 frequency bins)
# Processing word 'vlakbij' (length=7, duration=3.00s)
#   Mean correlation: 0.7495 (using 23 frequency bins)
# Processing word 'zich' (length=4, duration=3.01s)
#   Mean correlation: 0.7717 (using 23 frequency bins)
# Processing word 'verlost' (length=7, duration=3.00s)
#   Mean correlation: 0.7319 (using 23 frequency bins)
# Processing word 'mij' (length=3, duration=3.01s)
#   Mean correlation: 0.6785 (using 23 frequency bins)
# Processing word 'meisjes' (length=7, duration=3.01s)
#   Mean correlation: 0.7283 (using 23 frequency bins)
# Processing word 'sterkste' (length=8, duration=3.00s)
#   Mean correlation: 0.6893 (using 23 frequency bins)
# Processing word 'sok' (length=3, duration=3.01s)
#   Mean correlation: 0.7171 (using 23 frequency bins)
# Processing word 'drie' (length=4, duration=3.00s)
#   Mean correlation: 0.7822 (using 23 frequency bins)
# Processing word 'uittrekken' (length=10, duration=3.01s)
#   Mean correlation: 0.7256 (using 23 frequency bins)
# Processing word 'vier' (length=4, duration=3.01s)
#   Mean correlation: 0.7083 (using 23 frequency bins)
# Processing word 'dit' (length=3, duration=3.00s)
#   Mean correlation: 0.5915 (using 23 frequency bins)
# Processing word 'zou' (length=3, duration=3.00s)
#   Mean correlation: 0.8095 (using 23 frequency bins)
# Processing word 'noordenwind' (length=11, duration=3.01s)
#   Mean correlation: 0.7562 (using 23 frequency bins)
# Processing word 'mooi' (length=4, duration=3.00s)
#   Mean correlation: 0.6049 (using 23 frequency bins)
# Processing word 'nu' (length=2, duration=3.01s)
#   Mean correlation: 0.7182 (using 23 frequency bins)
# Processing word 'voor' (length=4, duration=3.01s)
#   Mean correlation: 0.7404 (using 23 frequency bins)
# Processing word 'dakker' (length=6, duration=3.00s)
#   Mean correlation: 0.6279 (using 23 frequency bins)
# Processing word 'vogeltje' (length=8, duration=3.01s)
#   Mean correlation: 0.6165 (using 23 frequency bins)
# Processing word 'kasteel' (length=7, duration=3.01s)
#   Mean correlation: 0.7870 (using 23 frequency bins)
# Processing word '11' (length=2, duration=3.00s)
#   Mean correlation: 0.7031 (using 23 frequency bins)
# Processing word 'je' (length=2, duration=3.01s)
#   Mean correlation: 0.7953 (using 23 frequency bins)
# Processing word 'haar' (length=4, duration=3.00s)
#   Mean correlation: 0.7581 (using 23 frequency bins)
# Processing word 'bloedrode' (length=9, duration=3.00s)
#   Mean correlation: 0.8317 (using 23 frequency bins)
# Processing word 'te' (length=2, duration=3.01s)
#   Mean correlation: 0.7202 (using 23 frequency bins)
# Processing word 'een' (length=3, duration=3.01s)
#   Mean correlation: 0.7421 (using 23 frequency bins)
# Processing word 'negen' (length=5, duration=3.00s)
#   Mean correlation: 0.7837 (using 23 frequency bins)
# Processing word 'hun' (length=3, duration=3.01s)
#   Mean correlation: 0.7877 (using 23 frequency bins)
# Processing word 'bakker' (length=6, duration=3.00s)
#   Mean correlation: 0.6599 (using 23 frequency bins)
# Processing word 'alsof' (length=5, duration=3.01s)
#   Mean correlation: 0.7128 (using 23 frequency bins)
# Processing word 'geen' (length=4, duration=3.01s)
#   Mean correlation: 0.7435 (using 23 frequency bins)
# Processing word 'stiekem' (length=7, duration=3.00s)
#   Mean correlation: 0.6966 (using 23 frequency bins)
# Processing word 'dat' (length=3, duration=3.01s)
#   Mean correlation: 0.3643 (using 23 frequency bins)
# Processing word 'had' (length=3, duration=3.01s)
#   Mean correlation: 0.7133 (using 23 frequency bins)
# Processing word 'helft' (length=5, duration=3.00s)
#   Mean correlation: 0.8150 (using 23 frequency bins)
# Processing word 'ook' (length=3, duration=3.01s)
#   Mean correlation: 0.7471 (using 23 frequency bins)
# Processing word 'moment' (length=6, duration=3.00s)
#   Mean correlation: 0.4701 (using 23 frequency bins)
# Processing word 'groen' (length=5, duration=3.01s)
#   Mean correlation: 0.5784 (using 23 frequency bins)
# Processing word 'veel' (length=4, duration=3.00s)
#   Mean correlation: 0.8067 (using 23 frequency bins)
# Processing word 'die' (length=3, duration=3.01s)
#   Mean correlation: 0.7783 (using 23 frequency bins)
# Processing word 'nog' (length=3, duration=3.01s)
#   Mean correlation: 0.6514 (using 23 frequency bins)
# Processed 94 valid word segments
#
# Word Length Statistics:
#        correlation                  \
#               mean       std count
# length
# 2         0.741155  0.069425    14
# 3         0.710421  0.129114    27
# 4         0.702503  0.115443    16
# 5         0.732832  0.093954     5
# 6         0.715992  0.101512    11
# 7         0.730905  0.098506     8
# 8         0.701928  0.089949     4
# 9         0.812033  0.085452     3
# 10        0.773753  0.068132     2
# 11        0.780307  0.061161     3
# 12        0.865115       NaN     1
#
#                                                      word duration_seconds
#                                                  <lambda>             mean
# length
# 2       11, 12, `s, al, de, er, in, je, nu, of, om, te...         3.005000
# 3       bak, bij, dan, dat, die, dit, een, had, hem, h...         3.006296
# 4       deur, door, drie, geen, haar, mijn, mooi, naar...         2.990000
# 5                       alsof, groen, helft, negen, zeven         3.004000
# 6       bakker, daarna, dakker, direct, erheen, moment...         3.005455
# 7       braadde, donkere, kasteel, meisjes, smeekte, s...         3.005000
# 8                  helemaal, sterkste, vogeltje, zonlicht         3.007500
# 9                         bloedrode, doodsbang, verdwaald         3.003333
# 10                                 uittrekken, verstijfde         3.005000
# 11                  dauwdruppel, nachtegalen, noordenwind         3.003333
# 12                                           onmiddellijk         3.000000

# %%
def extract_word_list(words):
    """
    Extract a list of unique words and their frequencies from the words array
    
    Parameters:
    -----------
    words : array
        Array of word labels at each time point
    
    Returns:
    --------
    word_list : pandas DataFrame
        DataFrame with columns 'word', 'count', 'length', and 'frequency'
    """

    # Convert numbers 1-10 to Dutch words
    dutch_numbers = {
        '1': 'een', '2': 'twee', '3': 'drie', '4': 'vier', '5': 'vijf',
        '6': 'zes', '7': 'zeven', '8': 'acht', '9': 'negen', '10': 'tien'
    }
    
    # Function to convert any numeric strings to Dutch words
    def convert_to_dutch(word):
        if word in dutch_numbers:
            return dutch_numbers[word]
        # Numbers 1-10
        if isinstance(word, str) and word.isdigit() and int(word) <= 10 and int(word) >= 1:
            return dutch_numbers[word]
        return word
    
    # Find word onsets (when words change)
    word_onsets = []
    current_word = ""
    
    for i, word in enumerate(words):
        # Ensure word is a string
        if not isinstance(word, str):
            word = str(word).strip()
            
        # Skip empty strings
        if word == "":
            continue
            
        # Convert numbers to Dutch words
        word = convert_to_dutch(word)
        
        # Detect word changes (onsets)
        if word != current_word:
            word_onsets.append((i, word))
            current_word = word
    
    print(f"Found {len(word_onsets)} word onsets")
    
    # Count word frequencies
    word_counts = {}
    for _, word in word_onsets:
        word_counts[word] = word_counts.get(word, 0) + 1
    
    # Create DataFrame
    word_list = pd.DataFrame({
        'word': list(word_counts.keys()),
        'count': list(word_counts.values()),
        'length': [len(w) for w in word_counts.keys()]
    })
    
    # Calculate frequency (percentage)
    total_words = len(word_onsets)
    word_list['frequency'] = word_list['count'] / total_words * 100
    
    # Sort by count (descending)
    word_list = word_list.sort_values('count', ascending=False).reset_index(drop=True)
    
    print(f"Found {len(word_list)} unique words")
    print(f"Top 10 most frequent words:")
    print(word_list.head(10))
    
    return word_list

# %%
# Manually create pronunciation dictionary
manual_dict = {
    'een': 'en',
    'vijf': 'vɛif',
    'sok': 'sɔk',
    'nu': 'ny',
    'mooi': 'moj',
    'noordenwind': 'nordənwɪnt',
    'zou': 'ˈzʏlə(n)',
    'dit': 'dɪt',
    'vier': 'vir',
    'uittrekken': 'ˈœytrɛkə(n)',
    'drie': 'dri',
    'sterkste': 'stɛrkstə',
    'dakker': 'dakɛr',
    'meisjes': 'mɛiʃəs',
    'mij': 'mɛi',
    'verlost': 'vərˈlɔst',
    'zich': 'zɪx',
    'vlakbij': "'vlɑg'bɛi",
    'spreuk': 'sprøk',
    'struik': 'strœyk',
    'verdwaald': 'vərˈdwalt',
    'er': 'ɛr',
    'voor': 'vor',
    'vogeltje': 'voxəlcə',
    'doodsbang': 'ˈdotsbɑŋ',
    'stiekem': 'ˈstikəm',
    'nog': 'nɔx',
    'die': 'di',
    'veel': 'vel',
    'groen': 'xrun',
    'moment': 'moˈmɛnt',
    'ook': 'ok',
    'helft': 'hɛlft',
    'had': 'hɑt',
    'dat': 'dɑt',
    'geen': 'xen',
    'kasteel': 'kɑsˈtel',
    'alsof': 'ɑlsˈɔf',
    'bakker': 'ˈbɑkər',
    'hun': 'hʏn',
    'negen': 'ˈnexə(n)',
    'te': 'tə',
    'bloedrode': 'blutrodə',
    'haar': 'har',
    'je': 'jə',
    'elf': 'ɛlf',
    'om': 'ɔm',
    'uit': 'œyt',
    'naar': 'nar',
    'zijn': 'zɛin',
    'bij': 'bɛi',
    'deur': 'dɵ:r',
    'dan': 'dɑn',
    'ze': 'zɛ',
    'zei': 'zɛi',
    'tussen': 'ˈtʏsə(n)',
    'dauwdruppel': 'dɑuˈdrʏpəl',
    'vak': 'vɑk',
    'wat': 'wɑt',
    'nachtegalen': 'ˈnɑxtəxal',
    'daarna': 'darˈna',
    'hem': 'hɛm',
    'twaalf': 'twalf',
    'tien': 'tin',
    'door': 'dor',
    'verstijfde': "vər'stɛivə(n)",
    'onmiddellijk': 'ɔnˈmɪdələk',
    'zo': 'zo',
    'braadde': 'ˈbradə',
    'erheen': "ɛr'hen",
    'in': 'ɪn',
    'helemaal': 'ˈheləmal',
    'twee': 'twe',
    'al': 'ɑl',
    'schold': 'ˈsxold',
    'kin': 'kɪn',
    'was': 'wɑs',
    'smeekte': 'ˈsmektə(n)',
    'het': 'hɛt',
    'bak': 'bɑk',
    'met': 'mɛt',
    'direct': 'diˈrɛkt',
    'van': 'vɑn',
    'zeven': 'ˈzevə(n)',
    'de': 'də',
    'hij': 'hɛi',
    'donkere': 'ˈdɔŋkərə',
    'mijn': 'mɛin',
    'of': 'ɔf',
    'zonlicht': 'ˈzɔnlɪxt',
    'lij': 'lɛi',
    'zevenduizend': 'ˈzevə(n)ˈdœyzənt'
}

# %%
from sklearn.preprocessing import StandardScaler

# %%
def run_existing_model(save_results=True, force_rerun=False):
    """
    Run the existing spectrogram reconstruction model,
    or load existing results if available
    
    Parameters:
    -----------
    save_results : bool
        Whether to save the results to disk
    force_rerun : bool
        Whether to force rerunning the model even if results exist
        
    Returns:
    --------
    all_results : dict
        Dictionary with results for all participants
    """
    feat_path = './features'
    result_path = './results'
    
    # Create results directory if it doesn't exist
    if save_results:
        os.makedirs(result_path, exist_ok=True)
    
    pts = ['sub-%02d'%i for i in range(1,11)]
    
    # Store results for each participant
    participant_results = {}
    
    # Check if we need to run the model at all
    all_results_exist = True
    missing_participants = []
    
    if not force_rerun:
        for pt in pts:
            # Check if reconstructed spectrogram exists
            spec_path = os.path.join(result_path, f'{pt}_predicted_spec.npy')
            if not os.path.exists(spec_path):
                all_results_exist = False
                missing_participants.append(pt)
    else:
        all_results_exist = False
        missing_participants = pts
    
    # If all results exist, just load them
    if all_results_exist:
        print("All results already exist. Loading from disk...")
        
        for pt in pts:
            # Load the original and reconstructed spectrograms
            try:
                spectrogram = np.load(os.path.join(feat_path, f'{pt}_spec.npy'))
                rec_spec = np.load(os.path.join(result_path, f'{pt}_predicted_spec.npy'))
                
                # Calculate correlations
                correlations = []
                for specBin in range(spectrogram.shape[1]):
                    r, _ = pearsonr(spectrogram[:, specBin], rec_spec[:, specBin])
                    correlations.append(r)
                
                mean_correlation = np.mean(correlations)
                print(f"  {pt} reconstruction correlation: {mean_correlation:.4f}")
                
                # Store results
                participant_results[pt] = {
                    'reconstructed_spec': rec_spec,
                    'correlations': np.array(correlations),
                    'mean_correlation': mean_correlation
                }
                
                # Try to load random baseline if it exists
                try:
                    randomControl = np.load(os.path.join(result_path, 'randomResults.npy'))
                    participant_results[pt]['random_baseline'] = np.mean(randomControl[pts.index(pt), :, :])
                except:
                    participant_results[pt]['random_baseline'] = None
            
            except Exception as e:
                print(f"  Error loading results for {pt}: {e}")
        
        return participant_results
    
    # Otherwise, run the model for missing participants
    print(f"Need to run model for {len(missing_participants)} participants: {missing_participants}")
    
    # First load any existing results
    if not force_rerun:
        for pt in pts:
            if pt not in missing_participants:
                try:
                    # Load existing results
                    spectrogram = np.load(os.path.join(feat_path, f'{pt}_spec.npy'))
                    rec_spec = np.load(os.path.join(result_path, f'{pt}_predicted_spec.npy'))
                    
                    # Calculate correlations
                    correlations = []
                    for specBin in range(spectrogram.shape[1]):
                        r, _ = pearsonr(spectrogram[:, specBin], rec_spec[:, specBin])
                        correlations.append(r)
                    
                    mean_correlation = np.mean(correlations)
                    print(f"  Loaded existing results for {pt}: {mean_correlation:.4f}")
                    
                    # Store results
                    participant_results[pt] = {
                        'reconstructed_spec': rec_spec,
                        'correlations': np.array(correlations),
                        'mean_correlation': mean_correlation
                    }
                    
                    # Try to load random baseline if it exists
                    try:
                        randomControl = np.load(os.path.join(result_path, 'randomResults.npy'))
                        participant_results[pt]['random_baseline'] = np.mean(randomControl[pts.index(pt), :, :])
                    except:
                        participant_results[pt]['random_baseline'] = None
                
                except Exception as e:
                    print(f"  Error loading results for {pt}: {e}")
                    missing_participants.append(pt)
    
    # Run the model for missing participants
    if missing_participants:
        print("Running model for missing participants...")
        
        winLength = 0.05
        frameshift = 0.01
        audiosr = 16000

        nfolds = 10
        kf = KFold(nfolds, shuffle=False)
        est = LinearRegression(n_jobs=5)
        pca = PCA()
        numComps = 50
        
        # Initialize matrices for correlation results and explained variance
        # (only for participants we're actually computing)
        allRes = np.zeros((len(missing_participants), nfolds, 23))
        explainedVariance = np.zeros((len(missing_participants), nfolds))
        numRands = 1000
        randomControl = np.zeros((len(missing_participants), numRands, 23))
        
        # Try to load existing overall results if we're not forcing a rerun
        if not force_rerun:
            try:
                existingRes = np.load(os.path.join(result_path, 'linearResults.npy'))
                existingVar = np.load(os.path.join(result_path, 'explainedVariance.npy'))
                existingRand = np.load(os.path.join(result_path, 'randomResults.npy'))
            except:
                existingRes = None
                existingVar = None
                existingRand = None
        else:
            existingRes = None
            existingVar = None
            existingRand = None

        for i, pt in enumerate(missing_participants):
            print(f"Processing {pt} with existing reconstruction model...")
            pt_idx = pts.index(pt)  # Index in the full list
            
            # Load the data
            spectrogram = np.load(os.path.join(feat_path, f'{pt}_spec.npy'))
            data = np.load(os.path.join(feat_path, f'{pt}_feat.npy'))
            
            # Initialize an empty spectrogram to save the reconstruction to
            rec_spec = np.zeros(spectrogram.shape)
            
            # Save the correlation coefficients for each fold
            rs = np.zeros((nfolds, spectrogram.shape[1]))
            
            for k, (train, test) in enumerate(kf.split(data)):
                # Z-Normalize with mean and std from the training data
                mu = np.mean(data[train, :], axis=0)
                std = np.std(data[train, :], axis=0)
                trainData = (data[train, :] - mu) / std
                testData = (data[test, :] - mu) / std

                # Fit PCA to training data
                pca.fit(trainData)
                
                # Get percentage of explained variance by selected components
                explainedVariance[i, k] = np.sum(pca.explained_variance_ratio_[:numComps])
                
                # Transform data into component space
                trainData = np.dot(trainData, pca.components_[:numComps, :].T)
                testData = np.dot(testData, pca.components_[:numComps, :].T)
                
                # Fit the regression model
                est.fit(trainData, spectrogram[train, :])
                
                # Predict the reconstructed spectrogram for the test data
                rec_spec[test, :] = est.predict(testData)

                # Evaluate reconstruction of this fold
                for specBin in range(spectrogram.shape[1]):
                    if np.any(np.isnan(rec_spec)):
                        print(f'{pt} has {np.sum(np.isnan(rec_spec))} broken samples in reconstruction')
                    r, p = pearsonr(spectrogram[test, specBin], rec_spec[test, specBin])
                    rs[k, specBin] = r

            # Show evaluation result
            mean_correlation = np.mean(rs)
            print(f'{pt} has mean correlation of {mean_correlation:.4f}')
            allRes[i, :, :] = rs

            # Estimate random baseline
            pt_random_baseline = []
            for randRound in range(numRands):
                # Choose a random splitting point at least 10% of the dataset size away
                splitPoint = np.random.choice(np.arange(int(spectrogram.shape[0]*0.1), int(spectrogram.shape[0]*0.9)))
                
                # Swap the dataset on the splitting point 
                shuffled = np.concatenate((spectrogram[splitPoint:, :], spectrogram[:splitPoint, :]))
                
                # Calculate the correlations
                for specBin in range(spectrogram.shape[1]):
                    r, p = pearsonr(spectrogram[:, specBin], shuffled[:, specBin])
                    randomControl[i, randRound, specBin] = r
                    pt_random_baseline.append(r)
            
            # Store participant results
            participant_results[pt] = {
                'reconstructed_spec': rec_spec,
                'correlations': rs,
                'mean_correlation': mean_correlation,
                'random_baseline': np.mean(pt_random_baseline)
            }
            
            # Save reconstructed spectrogram
            if save_results:
                np.save(os.path.join(result_path, f'{pt}_predicted_spec.npy'), rec_spec)

        # Merge with existing results if available
        if save_results:
            # Create full result arrays
            fullRes = np.zeros((len(pts), nfolds, 23))
            fullVar = np.zeros((len(pts), nfolds))
            fullRand = np.zeros((len(pts), numRands, 23))
            
            # Fill with existing results if available
            if existingRes is not None and existingRes.shape == fullRes.shape:
                fullRes = existingRes
            if existingVar is not None and existingVar.shape == fullVar.shape:
                fullVar = existingVar
            if existingRand is not None and existingRand.shape == fullRand.shape:
                fullRand = existingRand
            
            # Update with new results
            for i, pt in enumerate(missing_participants):
                pt_idx = pts.index(pt)
                fullRes[pt_idx, :, :] = allRes[i, :, :]
                fullVar[pt_idx, :] = explainedVariance[i, :]
                fullRand[pt_idx, :, :] = randomControl[i, :, :]
            
            # Save merged results
            np.save(os.path.join(result_path, 'linearResults.npy'), fullRes)
            np.save(os.path.join(result_path, 'explainedVariance.npy'), fullVar)
            np.save(os.path.join(result_path, 'randomResults.npy'), fullRand)
    
    return participant_results

# %%
def train_phonetic_model(participant, pca_components=50, test_size=0.2):
    """
    Train a phonetic prediction model
    
    Parameters:
    -----------
    participant : str
        Participant ID
    pca_components : int
        Number of PCA components to use
    test_size : float
        Proportion of data to use for testing
        
    Returns:
    --------
    model_info : dict
        Dictionary with model and results
    """
    print(f"Training phonetic model for {participant}...")
    
    # Paths
    feat_path = './features'
    
    # Load data
    features = np.load(os.path.join(feat_path, f'{participant}_feat.npy'))
    words = np.load(os.path.join(feat_path, f'{participant}_procWords.npy'))
    
    # Split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        features, words, test_size=test_size, random_state=42, 
        stratify=words if len(set(words)) > 1 else None
    )
    
    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Apply PCA
    pca = PCA(n_components=pca_components)
    X_train_pca = pca.fit_transform(X_train_scaled)
    X_test_pca = pca.transform(X_test_scaled)
    
    print(f"  Reduced features from {features.shape[1]} to {pca_components} dimensions")
    print(f"  Explained variance: {sum(pca.explained_variance_ratio_):.4f}")
    
    # Train model
    model = LogisticRegression(max_iter=5000, solver='saga', multi_class='multinomial')
    model.fit(X_train_pca, y_train)
    
    # Evaluate
    train_pred = model.predict(X_train_pca)
    test_pred = model.predict(X_test_pca)
    
    train_accuracy = accuracy_score(y_train, train_pred)
    test_accuracy = accuracy_score(y_test, test_pred)
    
    print(f"  Training accuracy: {train_accuracy:.4f}")
    print(f"  Testing accuracy: {test_accuracy:.4f}")
    
    # Map to phonetic representations
    phonetic_test_pred = []
    phonetic_test_true = []
    
    for pred_word, true_word in zip(test_pred, y_test):
        pred_phonetic = manual_dict.get(pred_word, "Unknown")
        true_phonetic = manual_dict.get(true_word, "Unknown")
        
        phonetic_test_pred.append(pred_phonetic)
        phonetic_test_true.append(true_phonetic)
    
    # Calculate phonetic metrics
    phonetic_matches = sum(p == t for p, t in zip(phonetic_test_pred, phonetic_test_true) 
                         if p != "Unknown" and t != "Unknown")
    phonetic_total = sum(1 for p, t in zip(phonetic_test_pred, phonetic_test_true) 
                        if p != "Unknown" and t != "Unknown")
    
    phonetic_accuracy = phonetic_matches / phonetic_total if phonetic_total > 0 else 0
    phonetic_coverage = phonetic_total / len(test_pred)
    
    print(f"  Phonetic accuracy: {phonetic_accuracy:.4f}")
    print(f"  Phonetic coverage: {phonetic_coverage:.4f}")
    
    return {
        'model': model,
        'scaler': scaler,
        'pca': pca,
        'train_accuracy': train_accuracy,
        'test_accuracy': test_accuracy,
        'phonetic_accuracy': phonetic_accuracy,
        'phonetic_coverage': phonetic_coverage,
        'X_test': X_test,
        'y_test': y_test,
        'test_pred': test_pred
    }

def compare_approaches(run_existing=True):
    """
    Compare the existing reconstruction model with the phonetic approach
    
    Parameters:
    -----------
    run_existing : bool
        Whether to run the existing model or just load its results
        
    Returns:
    --------
    results : dict
        Dictionary with comparison results
    """
    feat_path = './features'
    result_path = './results'
    
    # List of participants
    participants = ['sub-%02d'%i for i in range(1,11)]
    
    # Get existing model results
    if run_existing:
        print("Running existing reconstruction model...")
        existing_results = run_existing_model(save_results=True)
    else:
        # Try to load existing results
        print("Loading existing reconstruction results...")
        existing_results = {}
        
        for participant in participants:
            try:
                # Load original and reconstructed spectrograms
                spectrogram = np.load(os.path.join(feat_path, f'{participant}_spec.npy'))
                rec_spec = np.load(os.path.join(result_path, f'{participant}_predicted_spec.npy'))
                
                # Calculate correlations
                correlations = []
                for specBin in range(spectrogram.shape[1]):
                    r, _ = pearsonr(spectrogram[:, specBin], rec_spec[:, specBin])
                    correlations.append(r)
                
                mean_correlation = np.mean(correlations)
                print(f"  {participant} reconstruction correlation: {mean_correlation:.4f}")
                
                existing_results[participant] = {
                    'reconstructed_spec': rec_spec,
                    'mean_correlation': mean_correlation
                }
            except FileNotFoundError:
                print(f"  Could not find results for {participant}. Run with run_existing=True to generate.")
    
    # Train phonetic models
    phonetic_results = {}
    
    for participant in participants:
        if participant in existing_results:
            # Train phonetic model
            phonetic_model = train_phonetic_model(participant)
            phonetic_results[participant] = phonetic_model
    
    # Compare results
    comparison = {}
    
    print("\n=== Comparison Results ===\n")
    print("| Participant | Reconstruction | Word Accuracy | Phonetic Accuracy |")
    print("|-------------|---------------|--------------|-------------------|")
    
    for participant in participants:
        if participant in existing_results and participant in phonetic_results:
            recon_corr = existing_results[participant]['mean_correlation']
            word_acc = phonetic_results[participant]['test_accuracy']
            phon_acc = phonetic_results[participant]['phonetic_accuracy']
            
            print(f"| {participant} | {recon_corr:.4f} | {word_acc:.4f} | {phon_acc:.4f} |")
            
            comparison[participant] = {
                'reconstruction_correlation': recon_corr,
                'word_accuracy': word_acc,
                'phonetic_accuracy': phon_acc,
                'phonetic_coverage': phonetic_results[participant]['phonetic_coverage']
            }
    
    # Calculate averages
    if comparison:
        avg_recon = np.mean([r['reconstruction_correlation'] for r in comparison.values()])
        avg_word = np.mean([r['word_accuracy'] for r in comparison.values()])
        avg_phon = np.mean([r['phonetic_accuracy'] for r in comparison.values()])
        avg_cov = np.mean([r['phonetic_coverage'] for r in comparison.values()])
        
        print("\nAverages:")
        print(f"  Reconstruction Correlation: {avg_recon:.4f}")
        print(f"  Word Accuracy: {avg_word:.4f}")
        print(f"  Phonetic Accuracy: {avg_phon:.4f}")
        print(f"  Phonetic Coverage: {avg_cov:.4f}")
        
        comparison['average'] = {
            'reconstruction_correlation': avg_recon,
            'word_accuracy': avg_word,
            'phonetic_accuracy': avg_phon,
            'phonetic_coverage': avg_cov
        }
    
    # Return all results
    return {
        'existing_results': existing_results,
        'phonetic_results': phonetic_results,
        'comparison': comparison
    }

def run_allophone_model(participant, pca_components=50, test_size=0.2):
    """
    Train an allophone-based model (treating phonemes as the target)
    
    Parameters:
    -----------
    participant : str
        Participant ID
    pca_components : int
        Number of PCA components to use
    test_size : float
        Proportion of data to use for testing
        
    Returns:
    --------
    model_info : dict
        Dictionary with model and results
    """
    print(f"Training allophone model for {participant}...")
    
    # Paths
    feat_path = './features'
    
    # Load data
    features = np.load(os.path.join(feat_path, f'{participant}_feat.npy'))
    words = np.load(os.path.join(feat_path, f'{participant}_procWords.npy'))
    
    # Create phoneme labels
    phoneme_labels = []
    unknown_count = 0
    
    for word in words:
        if word in manual_dict:
            phoneme = manual_dict[word]  # Get the phonetic representation
        else:
            phoneme = "UNK"
            unknown_count += 1
        phoneme_labels.append(phoneme)
    
    phoneme_labels = np.array(phoneme_labels)
    print(f"  Created phoneme labels ({unknown_count} unknown words)")
    print(f"  Unique phoneme labels: {len(set(phoneme_labels))}")
    
    # Split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        features, phoneme_labels, test_size=test_size, random_state=42
    )
    
    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Apply PCA
    pca = PCA(n_components=pca_components)
    X_train_pca = pca.fit_transform(X_train_scaled)
    X_test_pca = pca.transform(X_test_scaled)
    
    # Train model
    model = LogisticRegression(max_iter=5000, solver='saga', multi_class='multinomial')
    model.fit(X_train_pca, y_train)
    
    # Evaluate
    train_pred = model.predict(X_train_pca)
    test_pred = model.predict(X_test_pca)
    
    train_accuracy = accuracy_score(y_train, train_pred)
    test_accuracy = accuracy_score(y_test, test_pred)
    
    print(f"  Training accuracy: {train_accuracy:.4f}")
    print(f"  Testing accuracy: {test_accuracy:.4f}")
    
    return {
        'model': model,
        'scaler': scaler,
        'pca': pca,
        'train_accuracy': train_accuracy,
        'test_accuracy': test_accuracy,
        'X_test': X_test,
        'y_test': y_test,
        'test_pred': test_pred,
        'unique_phonemes': len(set(phoneme_labels))
    }

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
# Main function to run all experiments
def run_all_experiments():
    """
    Run all experiments and compare approaches
    """
    print("=== Running All Speech Prosthetics Experiments ===\n")
    
    # Compare the existing approach with the phonetic word-based approach
    print("\n=== Comparing Existing Model vs. Phonetic Word-Based Approach ===\n")
    word_comparison = compare_approaches(run_existing=True)
    
    # Run allophone-based models
    print("\n=== Running Allophone-Based Models ===\n")
    allophone_results = {}
    
    participants = ['sub-%02d'%i for i in range(1,11)]
    
    for participant in participants:
        allophone_model = run_allophone_model(participant)
        allophone_results[participant] = allophone_model
    
    # Compare word-based and allophone-based approaches
    print("\n=== Comparing Word-Based vs. Allophone-Based Approaches ===\n")
    print("| Participant | Word Accuracy | Allophone Accuracy |")
    print("|-------------|--------------|-------------------|")
    
    word_vs_allophone = {}
    
    for participant in participants:
        if participant in word_comparison['phonetic_results'] and participant in allophone_results:
            word_acc = word_comparison['phonetic_results'][participant]['test_accuracy']
            allophone_acc = allophone_results[participant]['test_accuracy']
            
            print(f"| {participant} | {word_acc:.4f} | {allophone_acc:.4f} |")
            
            word_vs_allophone[participant] = {
                'word_accuracy': word_acc,
                'allophone_accuracy': allophone_acc
            }
    
    # Calculate averages
    if word_vs_allophone:
        avg_word = np.mean([r['word_accuracy'] for r in word_vs_allophone.values()])
        avg_allophone = np.mean([r['allophone_accuracy'] for r in word_vs_allophone.values()])
        
        print("\nAverages:")
        print(f"  Word-Based Accuracy: {avg_word:.4f}")
        print(f"  Allophone-Based Accuracy: {avg_allophone:.4f}")
        
        word_vs_allophone['average'] = {
            'word_accuracy': avg_word,
            'allophone_accuracy': avg_allophone
        }
    
    return {
        'word_comparison': word_comparison,
        'allophone_results': allophone_results,
        'word_vs_allophone': word_vs_allophone
    }

# Run all experiments
results = run_all_experiments()
# Out:
# === Running All Speech Prosthetics Experiments ===
#
#
# === Comparing Existing Model vs. Phonetic Word-Based Approach ===
#
# Running existing reconstruction model...
# All results already exist. Loading from disk...
#   sub-01 reconstruction correlation: 0.4835
#   sub-02 reconstruction correlation: 0.6243
#   sub-03 reconstruction correlation: 0.8322
#   sub-04 reconstruction correlation: 0.7774
#   sub-05 reconstruction correlation: 0.5283
#   sub-06 reconstruction correlation: 0.8587
#   sub-07 reconstruction correlation: 0.6918
#   sub-08 reconstruction correlation: 0.7051
#   sub-09 reconstruction correlation: 0.6451
#   sub-10 reconstruction correlation: 0.6745
# Training phonetic model for sub-01...
#   Reduced features from 1143 to 50 dimensions
#   Explained variance: 0.7153
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 66
#      59     return {
#      60         'word_comparison': word_comparison,
#      61         'allophone_results': allophone_results,
#      62         'word_vs_allophone': word_vs_allophone
#      63     }
#      65 # Run all experiments
# ---> 66 results = run_all_experiments()
#
# Cell In[17], line 14, in run_all_experiments()
#      12 # Compare the existing approach with the phonetic word-based approach
#      13 print("\n=== Comparing Existing Model vs. Phonetic Word-Based Approach ===\n")
# ---> 14 word_comparison = compare_approaches(run_existing=True)
#      16 # Run allophone-based models
#      17 print("\n=== Running Allophone-Based Models ===\n")
#
# Cell In[10], line 154, in compare_approaches(run_existing)
#     151 for participant in participants:
#     152     if participant in existing_results:
#     153         # Train phonetic model
# --> 154         phonetic_model = train_phonetic_model(participant)
#     155         phonetic_results[participant] = phonetic_model
#     157 # Compare results
#
# Cell In[10], line 55, in train_phonetic_model(participant, pca_components, test_size)
#      52 train_pred = model.predict(X_train_pca)
#      53 test_pred = model.predict(X_test_pca)
# ---> 55 train_accuracy = accuracy_score(y_train, train_pred)
#      56 test_accuracy = accuracy_score(y_test, test_pred)
#      58 print(f"  Training accuracy: {train_accuracy:.4f}")
#
# NameError: name 'accuracy_score' is not defined

# %%
def describe_data_simple(data_path='./features'):
    """
    Simple description of speech prosthetics data
    """
    import os
    import numpy as np
    
    # Get list of files
    files = os.listdir(data_path)
    
    # Find participants
    participants = set()
    for file in files:
        if file.endswith('.npy'):
            participant = file.split('_')[0]
            participants.add(participant)
    
    print(f"Found {len(participants)} participants: {', '.join(sorted(participants))}")
    
    # Check data for one participant
    if participants:
        participant = sorted(participants)[0]
        print(f"\nChecking data for participant {participant}:")
        
        # Load feature data
        try:
            features = np.load(os.path.join(data_path, f'{participant}_feat.npy'))
            print(f"  Features shape: {features.shape}")
            print(f"  Feature example (first 3 values): {features[0, :3]}")
        except Exception as e:
            print(f"  Error loading features: {e}")
        
        # Load spectrogram
        try:
            spectrogram = np.load(os.path.join(data_path, f'{participant}_spec.npy'))
            print(f"  Spectrogram shape: {spectrogram.shape}")
        except Exception as e:
            print(f"  Error loading spectrogram: {e}")
        
        # Load words
        try:
            words = np.load(os.path.join(data_path, f'{participant}_procWords.npy'))
            print(f"  Word array shape: {words.shape}")
            unique_words = len(set(words))
            print(f"  Unique words: {unique_words}")
            print(f"  First 5 words: {words[:5]}")
        except Exception as e:
            print(f"  Error loading words: {e}")
        
        # Check feature names
        try:
            feature_names = np.load(os.path.join(data_path, f'{participant}_feat_names.npy'))
            print(f"  Feature names: {len(feature_names)} names")
        except Exception as e:
            print(f"  Error loading feature names: {e}")
    
    # Check feature dimensions for all participants
    print("\nFeature dimensions by participant:")
    feature_dims = {}
    
    for participant in sorted(participants):
        try:
            features = np.load(os.path.join(data_path, f'{participant}_feat.npy'))
            feature_dims[participant] = features.shape[1]
            print(f"  {participant}: {features.shape[1]} features, {features.shape[0]} samples")
        except Exception as e:
            print(f"  {participant}: Error - {e}")


# Run the simple data description
describe_data_simple()
# Out:
# Found 10 participants: sub-01, sub-02, sub-03, sub-04, sub-05, sub-06, sub-07, sub-08, sub-09, sub-10
#
# Checking data for participant sub-01:
#   Features shape: (29985, 1143)
#   Feature example (first 3 values): [2.22035436 2.73808935 2.85690161]
#   Spectrogram shape: (29985, 23)
#   Word array shape: (29985,)
#   Unique words: 101
#   First 5 words: ['helft' 'helft' 'helft' 'helft' 'helft']
#   Feature names: 1143 names
#
# Feature dimensions by participant:
#   sub-01: 1143 features, 29985 samples
#   sub-02: 1143 features, 29985 samples
#   sub-03: 1143 features, 29986 samples
#   sub-04: 1035 features, 29986 samples
#   sub-05: 540 features, 29984 samples
#   sub-06: 1143 features, 29993 samples
#   sub-07: 1143 features, 29991 samples
#   sub-08: 486 features, 29992 samples
#   sub-09: 1053 features, 29993 samples
#   sub-10: 1098 features, 28460 samples
#
# WARNING: Feature dimensions differ across participants.
# You'll need to handle this in your model by either:
# 1. Training separate models for each participant, or
# 2. Using only the common dimensions, or
# 3. Applying dimensionality reduction

# %%
# Out:
# Processing sub-01...
# Processing sub-02...
# Processing sub-03...
# Processing sub-04...
# Processing sub-05...
# Processing sub-06...
# Processing sub-07...
# Processing sub-08...
# Processing sub-09...
# Processing sub-10...
# Data summary report saved to: ./features\data_visualization\data_summary.md
#
# =============================================
# SPEECH PROSTHETICS DATA DESCRIPTION
# =============================================
#
# Number of participants: 10
#
# Feature dimensions across participants: [1143, 1143, 1143, 1035, 540, 1143, 1143, 486, 1053, 1098]
#
# WARNING: Feature dimensions differ across participants!
# This will cause issues when trying to combine data.
# Options to address this:
# 1. Use only common dimensions across participants
# 2. Train separate models for each participant
# 3. Use dimensionality reduction (PCA) to create consistent feature size
#
# Total words: 298355
# Unique words: 140
#
# Top 10 most frequent words:
#   : 99428
#   nachtegalen: 2002
#   dan: 2001
#   naar: 2001
#   met: 2000
#   vogeltje: 1979
#   wel: 1804
#   kin: 1803
#   groen: 1803
#   alsof: 1803
#
# Participant details:
#   sub-01: 29985 samples, 1143 features, 101 unique words
#   sub-02: 29985 samples, 1143 features, 101 unique words
#   sub-03: 29986 samples, 1143 features, 101 unique words
#   sub-04: 29986 samples, 1035 features, 101 unique words
#   sub-05: 29984 samples, 540 features, 101 unique words
#   sub-06: 29993 samples, 1143 features, 101 unique words
#   sub-07: 29991 samples, 1143 features, 101 unique words
#   sub-08: 29992 samples, 486 features, 101 unique words
#   sub-09: 29993 samples, 1053 features, 101 unique words
#   sub-10: 28460 samples, 1098 features, 96 unique words
#
# =============================================
# RECOMMENDED APPROACH
# =============================================
#
# Based on the feature dimension mismatch, here's the recommended approach:
# 1. Train SEPARATE models for each participant
# 2. Use PCA to reduce feature dimensionality to a consistent size
# 3. Create a phonetic prediction pipeline for each participant
# 4. Evaluate performance separately and then aggregate results
#
# Creating sample visualizations for participant sub-01...
# Sample visualizations for sub-01 saved to: ./features\sample_visualization

# %%
# #restore original sound
# path_bids = r'./SingleWordProductionDutch-iBIDS'
# output_path = r'./original_audio'
# os.makedirs(output_path, exist_ok=True)

# participants = pd.read_csv(os.path.join(path_bids, 'participants.tsv'), delimiter='\t')

# for participant in participants['participant_id']:
#     # Load NWB file
#     io = NWBHDF5IO(os.path.join(path_bids, participant, 'ieeg', f'{participant}_task-wordProduction_ieeg.nwb'), 'r')
#     nwbfile = io.read()
    
#     # Get original audio
#     audio = nwbfile.acquisition['Audio'].data[:]
#     audio_sr = 48000  # Original sampling rate
    
#     # Scale audio to 16-bit range
#     scaled_audio = np.int16(audio/np.max(np.abs(audio)) * 32767)
    
#     # Save as WAV file
#     wavfile.write(os.path.join(output_path, f'{participant}_original_audio.wav'), audio_sr, scaled_audio)
    
#     io.close()
#     print(f"Extracted original audio for {participant}")
